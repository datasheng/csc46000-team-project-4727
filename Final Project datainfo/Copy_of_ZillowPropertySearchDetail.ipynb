# %%
def get_listings(api_key, listing_url):
    url = "https://app.scrapeak.com/v1/scrapers/zillow/listing"

    querystring = {
        "api_key": api_key,
        "url":listing_url
    }

    return requests.request("GET", url, params=querystring)

def get_property_detail(api_key, zpid):
    url = "https://app.scrapeak.com/v1/scrapers/zillow/property"

    querystring = {
        "api_key": api_key,
        "zpid":zpid
    }

    return requests.request("GET", url, params=querystring)

def get_zpid(api_key, street, city, state, zip_code=None):
    url = "https://app.scrapeak.com/v1/scrapers/zillow/zpidByAddress"

    querystring = {
        "api_key": api_key,
        "street": street,
        "city": city,
        "state": state,
        "zip_code":zip_code
    }

    return requests.request("GET", url, params=querystring)

# %% [markdown]
# # Zillow Property Search
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/drive/1afLUQVYLIhv0vDB-GNuYgxfZrJhTzSM5?usp=sharing)
#
# ## Overview
# | Detail Tag            | Information                                                                                        |
# |-----------------------|----------------------------------------------------------------------------------------------------|
# | Originally Created By | Ariel Herrera arielherrera@analyticsariel.com |
# | External References   | API |
# | Input Datasets        | Source name |
# | Output Datasets       | Source name |
# | Input Data Source     | Pandas DataFrame |
# | Output Data Source    | Pandas DataFrame |
#
# ## History
# | Date         | Developed By  | Reason                                                |
# |--------------|---------------|-------------------------------------------------------|
# | 22nd Jan 2022 | Ariel Herrera | Create notebook. |
#
# ## Getting Started
# 1. Copy this notebook -> File -> Save a Copy in Drive
# 2. Directions
#
# ## Useful Resources
# - [Google Colab Cheat Sheet](https://towardsdatascience.com/cheat-sheet-for-google-colab-63853778c093)

# %% [markdown]
# ## <font color="blue">Install Packages</font>

# %% [markdown]
# ## <font color="blue">Imports</font>

# %%
from google.colab import output, drive, files # specific to Google Colab
import pandas as pd
import numpy as np
import plotly.express as px
import requests
import warnings

# settings
warnings.filterwarnings("ignore")
pd.set_option("display.max_columns", None)

# %% [markdown]
# ## <font color="blue">Functions</font>

# %%
def get_listings(api_key, listing_url):
    url = "https://app.scrapeak.com/v1/scrapers/zillow/listing"

    querystring = {
        "api_key": api_key,
        "url":listing_url
    }

    return requests.request("GET", url, params=querystring)

def get_property_detail(api_key, zpid):
    url = "https://app.scrapeak.com/v1/scrapers/zillow/property"

    querystring = {
        "api_key": api_key,
        "zpid":zpid
    }

    return requests.request("GET", url, params=querystring)

def get_zpid(api_key, street, city, state, zip_code=None):
    url = "https://app.scrapeak.com/v1/scrapers/zillow/zpidByAddress"

    querystring = {
        "api_key": api_key,
        "street": street,
        "city": city,
        "state": state,
        "zip_code":zip_code
    }

    return requests.request("GET", url, params=querystring)

# %% [markdown]
# ## <font color="blue">Locals & Constants</font>

# %%
############
# OPTIONAL #
############

# mount drive
drive.mount("/content/drive", force_remount=False)

# data location
file_dir = "/content/drive/My Drive/Colab Data/input/" # optional
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# read in api key file
# df_api_keys = pd.read_csv(file_dir + "api_keys.csv")

# get keys
api_key = 'e3349076-2e0b-4c7e-81d2-fc0790390649'

# %% [markdown]
# ## <font color="blue">Data</font>

# %% [markdown]
# ### <font color="green">1. Property Listings For Sale</font>

# %%
# zillow search url
#listing_url = "https://www.zillow.com/manhattan-new-york-ny/?category=SEMANTIC&searchQueryState=%7B%22isMapVisible%22%3Atrue%2C%22mapBounds%22%3A%7B%22north%22%3A40.877483%2C%22south%22%3A40.683935%2C%22east%22%3A-73.910408%2C%22west%22%3A-74.047237%7D%2C%22usersSearchTerm%22%3A%22Manhattan%20NY%20homes%22%2C%22filterState%22%3A%7B%22sort%22%3A%7B%22value%22%3A%22globalrelevanceex%22%7D%2C%22sche%22%3A%7B%22value%22%3Afalse%7D%2C%22schm%22%3A%7B%22value%22%3Afalse%7D%2C%22schc%22%3A%7B%22value%22%3Afalse%7D%2C%22schu%22%3A%7B%22value%22%3Afalse%7D%2C%22schp%22%3A%7B%22value%22%3Afalse%7D%2C%22schr%22%3A%7B%22value%22%3Afalse%7D%2C%22schh%22%3A%7B%22value%22%3Afalse%7D%7D%2C%22isListVisible%22%3Atrue%2C%22category%22%3A%22cat1%22%2C%22mapZoom%22%3A12%2C%22regionSelection%22%3A%5B%7B%22regionId%22%3A12530%2C%22regionType%22%3A17%7D%5D%7D"
listing_url = 'https://www.zillow.com/chicago-il/?category=SEMANTIC&searchQueryState=%7B%22isMapVisible%22%3Atrue%2C%22mapBounds%22%3A%7B%22north%22%3A42.042916938040854%2C%22south%22%3A41.62442343874204%2C%22east%22%3A-87.33025437792969%2C%22west%22%3A-88.13362962207032%7D%2C%22mapZoom%22%3A11%2C%22usersSearchTerm%22%3A%22Chicago%20IL%20homes%22%2C%22filterState%22%3A%7B%22sort%22%3A%7B%22value%22%3A%22globalrelevanceex%22%7D%2C%22sche%22%3A%7B%22value%22%3Afalse%7D%2C%22schm%22%3A%7B%22value%22%3Afalse%7D%2C%22schh%22%3A%7B%22value%22%3Afalse%7D%2C%22schp%22%3A%7B%22value%22%3Afalse%7D%2C%22schr%22%3A%7B%22value%22%3Afalse%7D%2C%22schc%22%3A%7B%22value%22%3Afalse%7D%2C%22schu%22%3A%7B%22value%22%3Afalse%7D%7D%2C%22isListVisible%22%3Atrue%2C%22regionSelection%22%3A%5B%7B%22regionId%22%3A17426%2C%22regionType%22%3A6%7D%5D%2C%22category%22%3A%22cat1%22%7D'
# get listings
listing_response = get_listings(api_key, listing_url)

# %%
# view all keys
listing_response.json().keys()
# Out:
# dict_keys(['is_success', 'data', 'message', 'info'])

# %%
# check if request is successful
listing_response.json()["is_success"]
# Out:
# True

# %%
listing_response.json()['data']
# Out:
# {'user': {'isLoggedIn': False,
#   'hasHousingConnectorPermission': False,
#   'savedHomesCount': 0,
#   'personalizedSearchTraceID': '693777e0000000000c241b035121d461',
#   'guid': 'd1bb6194-19b4-4f03-97fc-62958721ba5e',
#   'zuid': '',
#   'isBot': False,
#   'email': '',
#   'displayName': '',
#   'isAgent': False,
#   'phoneNumber': ''},
#  'mapState': {'customRegionPolygonWkt': None,
#   'schoolPolygonWkt': None,
#   'isCurrentLocationSearch': False,
#   'userPosition': {'lat': None, 'lon': None}},
#  'regionState': {'regionInfo': [{'regionId': 17426,
#     'regionType': 6,
#     'regionName': 'Chicago',
#     'displayName': 'Chicago IL',
#     'isPointRegion': False}],
#   'regionBounds': {'north': 42.02313,
#    'south': 41.644334,
#    'east': -87.52364,
#    'west': -87.940244}},
#  'searchPageSeoObject': {'baseUrl': '/chicago-il/',
#   'windowTitle': 'Chicago IL Real Estate - Chicago IL Homes For Sale | Zillow',
#   'metaDescription': 'Zillow has 5365 homes for sale in Chicago IL. View listing photos, review sales history, and use our detailed real estate filters to find the perfect place.'},
#  'requestId': 9,
#  'cat1': {'searchResults': {'listResults': [{'zpid': '65548280',
#      'palsId': '17001_12521575',
#      'id': '65548280',
#      'rawHomeStatusCd': 'ForSale',
#      'marketingStatusSimplifiedCd': 'For Sale by Agent',
#      'imgSrc': 'https://photos.zillowstatic.com/fp/acb5ca10a69ef74fe3fd944d2e04e28c-p_e.jpg',
#      'hasImage': True,
#      'detailUrl': 'https://www.zillow.com/homedetails/1801-W-Addison-St-APT-1E-Chicago-IL-60613/65548280_zpid/',
#      'statusType': 'FOR_SALE',
#      'statusText': 'New',
#      'countryCurrency': '$',
#      'price': '$475,000',
#      'unformattedPrice': 475000,
#      'address': '1801 W Addison St APT 1E, Chicago, IL 60613',
#      'addressStreet': '1801 W Addison St APT 1E',
#      'addressCity': 'Chicago',
#      'addressState': 'IL',
#      'addressZipcode': '60613',
#      'isUndisclosedAddress': False,
#      'shouldShowRequestOnPrice': False,
#      'beds': 2,
#      'baths': 2.0,
#      'area': 1350,
#      'latLong': {'latitude': 41.946644, 'longitude': -87.674385},
#      'isZillowOwned': False,
#      'flexFieldText': 'Showcase',
#      'contentType': 'showcase',
#      'hdpData': {'homeInfo': {'zpid': 65548280,
#        'streetAddress': '1801 W Addison St APT 1E',
#        'zipcode': '60613',
#        'city': 'Chicago',
#        'state': 'IL',
#        'latitude': 41.946644,
#        'longitude': -87.674385,
#        'price': 475000.0,
#        'bathrooms': 2.0,
#        'bedrooms': 2.0,
#        'livingArea': 1350.0,
#        'homeType': 'CONDO',
#        'homeStatus': 'FOR_SALE',
#        'daysOnZillow': 5,
#        'isFeatured': False,
#        'shouldHighlight': False,
#        'listing_sub_type': {'is_FSBA': True},
#        'isUnmappable': False,
#        'isPreforeclosureAuction': False,
#        'homeStatusForHDP': 'FOR_SALE',
#        'priceForHDP': 475000.0,
#        'timeOnZillow': 446454000,
#        'isNonOwnerOccupied': True,
#        'isPremierBuilder': False,
#        'isZillowOwned': False,
#        'currency': 'USD',
#        'country': 'USA',
#        'taxAssessedValue': 402920.0,
#        'unit': 'Apt 1E',
#        'isShowcaseListing': True}},
#      'isSaved': False,
#      'isUserClaimingOwner': False,
#      'isUserConfirmedClaim': False,
#      'pgapt': 'ForSale',
#      'sgapt': 'For Sale (Broker)',
#      'shouldShowZestimateAsPrice': False,
#      'has3DModel': True,
#      'hasVideo': False,
#      'isHomeRec': False,
#      'hasAdditionalAttributions': True,
#      'isFeaturedListing': False,
#      'isShowcaseListing': True,
#      'list': True,
#      'relaxed': False,
#      'brokerName': 'Compass',
#      'carouselPhotosComposable': {'baseUrl': 'https://photos.zillowstatic.com/fp/{photoKey}-p_e.jpg',
#       'communityBaseUrl': None,
#       'photoData': [{'photoKey': 'acb5ca10a69ef74fe3fd944d2e04e28c'},
#        {'photoKey': 'd1560b899929c344363193ec9c45c957'},
#        {'photoKey': '70fffbdfcee24bf88f92746b1732ec74'},
#        {'photoKey': 'bbe360e68599e76fdb912ccacd75e116'},
#        {'photoKey': '6cafb7bcec8c5f46126633c13fc6da02'},
#        {'photoKey': 'b097ff9efe67044a5faf7475c1d4e0c9'},
#        {'photoKey': '6806436a398872648afd35b5267d917b'},
#        {'photoKey': 'f36b1ea72b96ff7865037dd5f43202d2'},
#        {'photoKey': '979cc950f11647cb998a858068c02f32'},
#        {'photoKey': '06c4fb1d60aeb80c65711345dd3b015c'},
#        {'photoKey': '89b607cd861ed9b05c711a3f58432ab6'},
#        {'photoKey': '306d12b481e2991f334895d14226437b'},
#        {'photoKey': '4c1861b81f9b4bcf744d96aeabc90be5'},
#        {'photoKey': '8539f651990f61901a53aea0d559282a'},
#        {'photoKey': '44c7d1a55bc3252603c9f77b595b3766'},
#        {'photoKey': '085a9d2cc9ef2099370a95c774cf4acb'},
#        {'photoKey': 'a4eee1346721f4380bc87dfe76eb81fb'},
#        {'photoKey': 'f26d31a97ef8b86901cc5d66b0d9536c'},
#        {'photoKey': '8802578d07d138d7dd3812b676999aa1'},
#        {'photoKey': '6eba411d6c3db4a59a13738861ba4555'},
#        {'photoKey': 'b62a1cfa0c62c36ca093104120f53d0f'},
#        {'photoKey': 'd1e067660ba217b71dd499cb2aa359ae'}],
#       'communityPhotoData': None,
#       'isStaticUrls': False},
#      'isPaidBuilderNewConstruction': False},
#     {'zpid': '441111929',
#      'palsId': '17001_12518189',
#      'id': '441111929',
#      'rawHomeStatusCd': 'ForSale',
#      'marketingStatusSimplifiedCd': 'For Sale by Agent',
#      'imgSrc': 'https://photos.zillowstatic.com/fp/fee61d003178d968d58301b4a2249945-p_e.jpg',
#      'hasImage': True,
#      'detailUrl': 'https://www.zillow.com/homedetails/3057-E-79th-Pl-Chicago-IL-60617/441111929_zpid/',
#      'statusType': 'FOR_SALE',
#      'statusText': 'New',
#      'countryCurrency': '$',
#      'price': '$149,900',
#      'unformattedPrice': 149900,
#      'address': '3057 E 79th Pl, Chicago, IL 60617',
#      'addressStreet': '3057 E 79th Pl',
#      'addressCity': 'Chicago',
#      'addressState': 'IL',
#      'addressZipcode': '60617',
#      'isUndisclosedAddress': False,
#      'shouldShowRequestOnPrice': False,
#      'beds': 8,
#      'baths': 4.0,
#      'latLong': {'latitude': 41.7508, 'longitude': -87.54944},
#      'isZillowOwned': False,
#      'flexFieldText': 'Showcase',
#      'contentType': 'showcase',
#      'hdpData': {'homeInfo': {'zpid': 441111929,
#        'streetAddress': '3057 E 79th Pl',
#        'zipcode': '60617',
#        'city': 'Chicago',
#        'state': 'IL',
#        'latitude': 41.7508,
#        'longitude': -87.54944,
#        'price': 149900.0,
#        'bathrooms': 4.0,
#        'bedrooms': 8.0,
#        'homeType': 'MULTI_FAMILY',
#        'homeStatus': 'FOR_SALE',
#        'daysOnZillow': 4,
#        'isFeatured': False,
#        'shouldHighlight': False,
#        'listing_sub_type': {'is_FSBA': True},
#        'isUnmappable': False,
#        'isPreforeclosureAuction': False,
#        'homeStatusForHDP': 'FOR_SALE',
#        'priceForHDP': 149900.0,
#        'timeOnZillow': 363364000,
#        'isNonOwnerOccupied': True,
#        'isPremierBuilder': False,
#        'isZillowOwned': False,
#        'currency': 'USD',
#        'country': 'USA',
#        'taxAssessedValue': 130000.0,
#        'lotAreaValue': 4125.0,
#        'lotAreaUnit': 'sqft',
#        'isShowcaseListing': True}},
#      'isSaved': False,
#      'isUserClaimingOwner': False,
#      'isUserConfirmedClaim': False,
#      'pgapt': 'ForSale',
#      'sgapt': 'For Sale (Broker)',
#      'shouldShowZestimateAsPrice': False,
#      'has3DModel': True,
#      'hasVideo': False,
#      'isHomeRec': False,
#      'hasAdditionalAttributions': True,
#      'isFeaturedListing': False,
#      'isShowcaseListing': True,
#      'list': True,
#      'relaxed': False,
#      'brokerName': 'Redfin Corporation',
#      'carouselPhotosComposable': {'baseUrl': 'https://photos.zillowstatic.com/fp/{photoKey}-p_e.jpg',
#       'communityBaseUrl': None,
#       'photoData': [{'photoKey': 'fee61d003178d968d58301b4a2249945'},
#        {'photoKey': '746f37370be902f79e64dc4caf770704'},
#        {'photoKey': '484591ba740df3d4d614d701d3318bc7'},
#        {'photoKey': '83a334ae35010b4ab7ff491aa2b8856e'},
#        {'photoKey': 'b977e8ca76ba8299b3819aa98afea262'},
#        {'photoKey': 'fbbac5eae307060f6279a21a3e234be7'},
#        {'photoKey': 'f3711a6450d11bc229993a9af1b9a589'},
#        {'photoKey': '4bf45c39fe8ca44c8e4a70f5945f72e0'},
#        {'photoKey': '1440bc462f6637086424fa261af0d923'},
#        {'photoKey': '96f80b995d902227625c6e11aece067d'},
#        {'photoKey': 'd305946d562e42348ab897603b918c61'},
#        {'photoKey': 'd81410b36b0995810d2db57aa15ca7f9'},
#        {'photoKey': '1c45caee5c254a7e7b52301a633ae048'},
#        {'photoKey': 'e58d38a9b51deeecdb1efe959bcf8d2f'},
#        {'photoKey': '7e43ade7e4e9109e3b480c8183a9bdad'},
#        {'photoKey': '304766e3b4a32d6ec0507a451bfc23e2'},
#        {'photoKey': '286cbd18d0f05847f951738cbc833838'},
#        {'photoKey': '5dd9f322585f534113cca47ae13f1632'},
#        {'photoKey': '55dffc94d8fc8190913743e6d04602d3'},
#        {'photoKey': '63568d8deaacf77cea84bfbfb8f7434f'},
#        {'photoKey': '31a58cfabc5192bca007d147093dd5aa'},
#        {'photoKey': '67ce2fb0c3808140caaba9e51d3fda36'},
#        {'photoKey': 'bc0f90ca478fd80afcd260432b916d8d'},
#        {'photoKey': '6ec0ebdff0cbdd7edc5faa14505038da'},
#        {'photoKey': '63a77838466e89ef5b02caf88d777c24'},
#        {'photoKey': 'a057eaa1fb4e6ca3fbfbc9731fce09af'},
#        {'photoKey': '18c95f788e95116e9e24fa4b5d8147e1'},
#        {'photoKey': 'bfc8e8ce921d7f0aadf361b478645b03'},
#        {'photoKey': 'f5705ab037bc4ec10802c78d23563675'},
#        {'photoKey': '19ed022a2a02db68e12655ee6b25d57b'},
#        {'photoKey': '26db078e096191d7ac17a50b42c1963e'}],
#       'communityPhotoData': None,
#       'isStaticUrls': False},
#      'isPaidBuilderNewConstruction': False},
#     {'zpid': '3577740',
#      'palsId': '17001_12519153',
#      'id': '3577740',
#      'rawHomeStatusCd': 'ForSale',
#      'marketingStatusSimplifiedCd': 'For Sale by Agent',
#      'imgSrc': 'https://photos.zillowstatic.com/fp/97efafd9c5bd5fbe735cd2490dfacb07-p_e.jpg',
#      'hasImage': True,
#      'detailUrl': 'https://www.zillow.com/homedetails/7457-W-Ardmore-Ave-Chicago-IL-60631/3577740_zpid/',
#      'statusType': 'FOR_SALE',
#      'statusText': 'Active',
#      'countryCurrency': '$',
#      'price': '$500,000',
#      'unformattedPrice': 500000,
#      'address': '7457 W Ardmore Ave, Chicago, IL 60631',
#      'addressStreet': '7457 W Ardmore Ave',
#      'addressCity': 'Chicago',
#      'addressState': 'IL',
#      'addressZipcode': '60631',
#      'isUndisclosedAddress': False,
#      'shouldShowRequestOnPrice': False,
#      'beds': 3,
#      'baths': 2.0,
#      'area': 0,
#      'latLong': {'latitude': 41.984764, 'longitude': -87.81407},
#      'isZillowOwned': False,
#      'flexFieldText': 'Fully finished basement',
#      'contentType': 'homeInsight',
#      'hdpData': {'homeInfo': {'zpid': 3577740,
#        'streetAddress': '7457 W Ardmore Ave',
#        'zipcode': '60631',
#        'city': 'Chicago',
#        'state': 'IL',
#        'latitude': 41.984764,
#        'longitude': -87.81407,
#        'price': 500000.0,
#        'bathrooms': 2.0,
#        'bedrooms': 3.0,
#        'livingArea': 0.0,
#        'homeType': 'SINGLE_FAMILY',
#        'homeStatus': 'FOR_SALE',
#        'daysOnZillow': 7,
#        'isFeatured': False,
#        'shouldHighlight': False,
#        'listing_sub_type': {'is_FSBA': True},
#        'isUnmappable': False,
#        'isPreforeclosureAuction': False,
#        'homeStatusForHDP': 'FOR_SALE',
#        'priceForHDP': 500000.0,
#        'timeOnZillow': 642958000,
#        'isNonOwnerOccupied': True,
#        'isPremierBuilder': False,
#        'isZillowOwned': False,
#        'currency': 'USD',
#        'country': 'USA',
#        'taxAssessedValue': 330000.0,
#        'lotAreaValue': 4950.0,
#        'lotAreaUnit': 'sqft',
#        'isShowcaseListing': False}},
#      'isSaved': False,
#      'isUserClaimingOwner': False,
#      'isUserConfirmedClaim': False,
#      'pgapt': 'ForSale',
#      'sgapt': 'For Sale (Broker)',
#      'shouldShowZestimateAsPrice': False,
#      'has3DModel': False,
#      'hasVideo': False,
#      'isHomeRec': False,
#      'hasAdditionalAttributions': True,
#      'isFeaturedListing': False,
#      'isShowcaseListing': False,
#      'list': True,
#      'relaxed': False,
#      'brokerName': "@properties Christie's International Real Estate",
#      'carouselPhotosComposable': {'baseUrl': 'https://photos.zillowstatic.com/fp/{photoKey}-p_e.jpg',
#       'communityBaseUrl': None,
#       'photoData': [{'photoKey': '97efafd9c5bd5fbe735cd2490dfacb07'},
#        {'photoKey': '6b3f08a3488ff4d1d6d0f896677e3a87'},
#        {'photoKey': 'b8a51cbc628948547fb411bbc7185958'},
#        {'photoKey': 'bd0f75a8dbc3f4d6a3b097f5c52305df'},
#        {'photoKey': '0aaa67071aa98defd4957e0b5bab480e'},
#        {'photoKey': '640774127887fa5e7186579106ace01f'},
#        {'photoKey': '43055f79fbf3b823946d7145bfc60541'},
#        {'photoKey': 'bb20a7cdf2d223a5a7b281fc8d3d40fe'},
#        {'photoKey': '7eb287eec3a20555a2430059ac570f34'},
#        {'photoKey': '61957b8c20fb22a9f55116ff864f9656'},
#        {'photoKey': 'f8405536aac0c72b3c8407d8203fe278'},
#        {'photoKey': '4a05f4a7d99dd0564d21e105c1722ebe'},
#        {'photoKey': '8659b8573dccf5809a20ad38c8ce3917'},
#        {'photoKey': 'e440910a15326b2d9ac7b0cb16327efe'},
#        {'photoKey': 'b8f21d1d59194baea79533b269347d7d'},
#        {'photoKey': 'f00073439fc4399e94327227b6b6734f'},
#        {'photoKey': '6aca79c1043dd844f8ddaaffd229d6cd'},
#        {'photoKey': '08914edb396d35d66c1efaced270d7ba'},
#        {'photoKey': 'd72182a0198218b7d6614cc6b8a30048'},
#        {'photoKey': 'bf35fed7a3cfb1d83ff7bbcafbed4319'},
#        {'photoKey': '0e27801dbb906bf6993e9f7eb6609556'},
#        {'photoKey': '5f058c601528e156189abe7c500f962a'},
#        {'photoKey': '9158ff0b2a320cbc8fd662d855131a9f'},
#        {'photoKey': 'a0561340ba7d95d3cfb8588276fc4b62'},
#        {'photoKey': '48eaa9d57c39d02c2e3cd5f1fd610c33'},
#        {'photoKey': '2627a684d14a95f56f7715af192e9c9f'},
#        {'photoKey': 'b00a01bdd8774d93e8a6b89885bfbd0d'},
#        {'photoKey': '6397ccdbd06cf1ef9b6aba518fe07f11'},
#        {'photoKey': '7d1908644a16bfec97301cfe580ec0a5'},
#        {'photoKey': '1b753337fc10b894d6765562e859b14f'},
#        {'photoKey': 'c154026a00eaa2e86fcb265259e85f3b'},
#        {'photoKey': '57851d01a3c5308e8d352014cb5d66e8'}],
#       'communityPhotoData': None,
#       'isStaticUrls': False},
#      'isPaidBuilderNewConstruction': False},
#     {'zpid': '441034809',
#      'palsId': '17001_12507397',
#      'id': '441034809',
#      'rawHomeStatusCd': 'ForSale',
#      'marketingStatusSimplifiedCd': 'For Sale by Agent',
#      'imgSrc': 'https://photos.zillowstatic.com/fp/1c9248bfd70c8736716e0356e60af141-p_e.jpg',
#      'hasImage': True,
#      'detailUrl': 'https://www.zillow.com/homedetails/548-W-Oakdale-Ave-Chicago-IL-60657/441034809_zpid/',
#      'statusType': 'FOR_SALE',
#      'statusText': 'New',
#      'countryCurrency': '$',
#      'price': '$950,000',
#      'unformattedPrice': 950000,
#      'address': '548 W Oakdale Ave, Chicago, IL 60657',
#      'addressStreet': '548 W Oakdale Ave',
#      'addressCity': 'Chicago',
#      'addressState': 'IL',
#      'addressZipcode': '60657',
#      'isUndisclosedAddress': False,
#      'shouldShowRequestOnPrice': False,
#      'beds': 4,
#      'baths': 4.0,
#      'area': 0,
#      'latLong': {'latitude': 41.93581, 'longitude': -87.64374},
#      'isZillowOwned': False,
#      'flexFieldText': 'High ceilings',
#      'contentType': 'homeInsight',
#      'hdpData': {'homeInfo': {'zpid': 441034809,
#        'streetAddress': '548 W Oakdale Ave',
#        'zipcode': '60657',
#        'city': 'Chicago',
#        'state': 'IL',
#        'latitude': 41.93581,
#        'longitude': -87.64374,
#        'price': 950000.0,
#        'bathrooms': 4.0,
#        'bedrooms': 4.0,
#        'livingArea': 0.0,
#        'homeType': 'SINGLE_FAMILY',
#        'homeStatus': 'FOR_SALE',
#        'daysOnZillow': 4,
#        'isFeatured': False,
#        'shouldHighlight': False,
#        'listing_sub_type': {'is_FSBA': True},
#        'isUnmappable': False,
#        'isPreforeclosureAuction': False,
#        'homeStatusForHDP': 'FOR_SALE',
#        'priceForHDP': 950000.0,
#        'timeOnZillow': 368452000,
#        'isNonOwnerOccupied': True,
#        'isPremierBuilder': False,
#        'isZillowOwned': False,
#        'currency': 'USD',
#        'country': 'USA',
#        'taxAssessedValue': 1120000.0,
#        'lotAreaValue': 3500.0,
#        'lotAreaUnit': 'sqft',
#        'isShowcaseListing': False}},
#      'isSaved': False,
#      'isUserClaimingOwner': False,
#      'isUserConfirmedClaim': False,
#      'pgapt': 'ForSale',
#      'sgapt': 'For Sale (Broker)',
#      'shouldShowZestimateAsPrice': False,
#      'has3DModel': False,
#      'hasVideo': False,
#      'isHomeRec': False,
#      'hasAdditionalAttributions': True,
#      'isFeaturedListing': False,
#      'isShowcaseListing': False,
#      'list': True,
#      'relaxed': False,
#      'brokerName': "Jameson Sotheby's Intl Realty",
#      'carouselPhotosComposable': {'baseUrl': 'https://photos.zillowstatic.com/fp/{photoKey}-p_e.jpg',
#       'communityBaseUrl': None,
#       'photoData': [{'photoKey': '1c9248bfd70c8736716e0356e60af141'},
#        {'photoKey': '9dbf9015497cbd5c5ad27b9711a1b8e7'},
#        {'photoKey': '5f2bc23c40f5d08215b248e6c57744fe'},
#        {'photoKey': '3f7231b8e67fb3145cccaa068b8e4c9a'},
#        {'photoKey': '41d2490796d4b73140ee5c0f950e979e'},
#        {'photoKey': '6de5ab1e428be5cf696b7c5d139301b1'},
#        {'photoKey': '2c1f01ae295ee1f97dd3355e266db107'},
#        {'photoKey': 'c3d76ff7853a7da42f2f2cc16bce2086'},
#        {'photoKey': 'e7021ad1c2ff44ed4b9a766909740351'},
#        {'photoKey': 'f281a63d435311f73fd3909e7715dd38'},
#        {'photoKey': 'c3c5a3ab84b334c11a126cf1fc8a1491'},
#        {'photoKey': '1ee18b720174ab38f64df28ff9433044'},
#        {'photoKey': '31244046bbdd71c4f9615b730f0720e8'},
#        {'photoKey': 'e51b616d74ab14453e0fc0853e22eb55'},
#        {'photoKey': '7388eb13fc81b1d8fc7882016fc5b80e'},
#        {'photoKey': '1d383cafc539578931e33deb11568a3e'},
#        {'photoKey': 'a97c40242c994bbf5438182f9ff2ffdb'},
#        {'photoKey': 'd7bbc00ba93303d41bcb346b4430368a'},
#        {'photoKey': '4723f2cc0c73c5079e4c789d48e86b98'},
#        {'photoKey': 'fe8f486262508c2a2f494bd4cd071f1a'},
#        {'photoKey': '181f68f230ec58246a78c701c831428d'},
#        {'photoKey': 'd6c1e464575d9a87c14d62e026db406f'},
#        {'photoKey': 'f92ded812fd799177a5cdd54421cffa5'}],
#       'communityPhotoData': None,
#       'isStaticUrls': False},
#      'isPaidBuilderNewConstruction': False},
#     {'zpid': '2078946235',
#      'palsId': '17001_12525317',
#      'id': '2078946235',
#      'rawHomeStatusCd': 'ForSale',
#      'marketingStatusSimplifiedCd': 'For Sale by Agent',
#      'imgSrc': 'https://photos.zillowstatic.com/fp/b8a8ff77de8c6892f4757d016bf25d58-p_e.jpg',
#      'hasImage': True,
#      'detailUrl': 'https://www.zillow.com/homedetails/948-W-Sheridan-Rd-2D-Chicago-IL-60613/2078946235_zpid/',
#      'statusType': 'FOR_SALE',
#      'statusText': 'New',
#      'countryCurrency': '$',
#      'price': '$429,900',
#      'unformattedPrice': 429900,
#      'address': '948 W Sheridan Rd #2D, Chicago, IL 60613',
#      'addressStreet': '948 W Sheridan Rd #2D',
#      'addressCity': 'Chicago',
#      'addressState': 'IL',
#      'addressZipcode': '60613',
#      'isUndisclosedAddress': False,
#      'shouldShowRequestOnPrice': False,
#      'beds': 2,
#      'baths': 2.0,
#      'area': 1300,
#      'latLong': {'latitude': 41.95294, 'longitude': -87.65408},
#      'isZillowOwned': False,
#      'flexFieldText': 'Cozy gas fireplace',
#      'contentType': 'homeInsight',
#      'hdpData': {'homeInfo': {'zpid': 2078946235,
#        'streetAddress': '948 W Sheridan Rd #2D',
#        'zipcode': '60613',
#        'city': 'Chicago',
#        'state': 'IL',
#        'latitude': 41.95294,
#        'longitude': -87.65408,
#        'price': 429900.0,
#        'bathrooms': 2.0,
#        'bedrooms': 2.0,
#        'livingArea': 1300.0,
#        'homeType': 'CONDO',
#        'homeStatus': 'FOR_SALE',
#        'daysOnZillow': 4,
#        'isFeatured': False,
#        'shouldHighlight': False,
#        'listing_sub_type': {'is_FSBA': True},
#        'isUnmappable': False,
#        'isPreforeclosureAuction': False,
#        'homeStatusForHDP': 'FOR_SALE',
#        'priceForHDP': 429900.0,
#        'timeOnZillow': 381063000,
#        'isNonOwnerOccupied': True,
#        'isPremierBuilder': False,
#        'isZillowOwned': False,
#        'currency': 'USD',
#        'country': 'USA',
#        'unit': '# 2D',
#        'isShowcaseListing': False}},
#      'isSaved': False,
#      'isUserClaimingOwner': False,
#      'isUserConfirmedClaim': False,
#      'pgapt': 'ForSale',
#      'sgapt': 'For Sale (Broker)',
#      'shouldShowZestimateAsPrice': False,
#      'has3DModel': False,
#      'hasVideo': False,
#      'isHomeRec': False,
#      'hasAdditionalAttributions': True,
#      'isFeaturedListing': False,
#      'isShowcaseListing': False,
#      'list': True,
#      'relaxed': False,
#      'brokerName': "@properties Christie's International Real Estate",
#      'carouselPhotosComposable': {'baseUrl': 'https://photos.zillowstatic.com/fp/{photoKey}-p_e.jpg',
#       'communityBaseUrl': None,
#       'photoData': [{'photoKey': 'b8a8ff77de8c6892f4757d016bf25d58'},
#        {'photoKey': '4843116473d6ec29e0e11fabe1bb9015'},
#        {'photoKey': '7986bb1abec558715ddc53f7e6c9419d'},
#        {'photoKey': '4e2a6b809ad4551e020507fb2363c372'},
#        {'photoKey': 'c87835a63529633217f7de6fc154f238'},
#        {'photoKey': '6af628a83715cd8501bf290f9fb67429'},
#        {'photoKey': '10c1ca167fafd6f26e550c2abf0de9f9'},
#        {'photoKey': '64cc0c0edb3b8c0596effdaaad5ac474'},
#        {'photoKey': '62bd14de68fcb31c649722a351fd2bd2'},
#        {'photoKey': '1fee88a1dad6854659a691606e3308cc'},
#        {'photoKey': '4add7f7eab2b0080af171229b2818c37'},
#        {'photoKey': '25095a4ecd2ee12b08cd0a0918bcb898'},
#        {'photoKey': '7318f79751c8333943ccf4c3163e49b8'},
#        {'photoKey': '8168dcda1cec29782e25660070270c09'},
#        {'photoKey': 'ef783f6ababba505a894234f86c36232'},
#        {'photoKey': 'aba54fb1d069ae7f010b5c58775b64f4'},
#        {'photoKey': '0128234c62a0608198d289b9d9d18b29'},
#        {'photoKey': '4b7df8fc9b4bc09fb3f9024e7d70ac2e'},
#        {'photoKey': 'd2aff4bd80ed578f88e2ca085a85c552'},
#        {'photoKey': 'e99bf3800540f47b8e463da5e85258e3'}],
#       'communityPhotoData': None,
#       'isStaticUrls': False},
#      'isPaidBuilderNewConstruction': False},
#     {'zpid': '3689524',
#      'palsId': '17001_12520884',
#      'id': '3689524',
#      'rawHomeStatusCd': 'ForSale',
#      'marketingStatusSimplifiedCd': 'For Sale by Agent',
#      'imgSrc': 'https://photos.zillowstatic.com/fp/33f42e08d26f793584bf5b69450687f8-p_e.jpg',
#      'hasImage': True,
#      'detailUrl': 'https://www.zillow.com/homedetails/1433-W-Rosemont-Ave-APT-1W-Chicago-IL-60660/3689524_zpid/',
#      'statusType': 'FOR_SALE',
#      'statusText': 'New',
#      'countryCurrency': '$',
#      'price': '$325,000',
#      'unformattedPrice': 325000,
#      'address': '1433 W Rosemont Ave APT 1W, Chicago, IL 60660',
#      'addressStreet': '1433 W Rosemont Ave APT 1W',
#      'addressCity': 'Chicago',
#      'addressState': 'IL',
#      'addressZipcode': '60660',
#      'isUndisclosedAddress': False,
#      'shouldShowRequestOnPrice': False,
#      'beds': 2,
#      'baths': 2.0,
#      'area': 1300,
#      'latLong': {'latitude': 41.996143, 'longitude': -87.6666},
#      'isZillowOwned': False,
#      'flexFieldText': 'Crown molding',
#      'contentType': 'homeInsight',
#      'hdpData': {'homeInfo': {'zpid': 3689524,
#        'streetAddress': '1433 W Rosemont Ave APT 1W',
#        'zipcode': '60660',
#        'city': 'Chicago',
#        'state': 'IL',
#        'latitude': 41.996143,
#        'longitude': -87.6666,
#        'price': 325000.0,
#        'bathrooms': 2.0,
#        'bedrooms': 2.0,
#        'livingArea': 1300.0,
#        'homeType': 'CONDO',
#        'homeStatus': 'FOR_SALE',
#        'daysOnZillow': 4,
#        'isFeatured': False,
#        'shouldHighlight': False,
#        'listing_sub_type': {'is_FSBA': True},
#        'isUnmappable': False,
#        'isPreforeclosureAuction': False,
#        'homeStatusForHDP': 'FOR_SALE',
#        'priceForHDP': 325000.0,
#        'timeOnZillow': 353762000,
#        'isNonOwnerOccupied': True,
#        'isPremierBuilder': False,
#        'isZillowOwned': False,
#        'currency': 'USD',
#        'country': 'USA',
#        'taxAssessedValue': 329990.0,
#        'unit': 'Apt 1W',
#        'isShowcaseListing': False}},
#      'isSaved': False,
#      'isUserClaimingOwner': False,
#      'isUserConfirmedClaim': False,
#      'pgapt': 'ForSale',
#      'sgapt': 'For Sale (Broker)',
#      'shouldShowZestimateAsPrice': False,
#      'has3DModel': False,
#      'hasVideo': False,
#      'isHomeRec': False,
#      'hasAdditionalAttributions': True,
#      'isFeaturedListing': False,
#      'isShowcaseListing': False,
#      'list': True,
#      'relaxed': False,
#      'brokerName': 'Keller Williams Experience',
#      'carouselPhotosComposable': {'baseUrl': 'https://photos.zillowstatic.com/fp/{photoKey}-p_e.jpg',
#       'communityBaseUrl': None,
#       'photoData': [{'photoKey': '33f42e08d26f793584bf5b69450687f8'},
#        {'photoKey': 'a7c3125b4958673d0956902a81fb7030'},
#        {'photoKey': '033274de8f92c0e46614db885d36e21b'},
#        {'photoKey': '940ed1ac17a886ec1e0cca4e5b208395'},
#        {'photoKey': '906fe19232d2d86041c2f6efff1429f7'},
#        {'photoKey': 'c6c7674d7fc4063ce1c0f8b3f6c174ed'},
#        {'photoKey': '9ed0aaf280ff59bf6f60a67c8e5c88dc'},
#        {'photoKey': '3ae837d26e37f85e36109942f00a3fe5'},
#        {'photoKey': 'da7a1ccc5d2202cbf00a9124b6465c2d'},
#        {'photoKey': 'a53a459272df171d5626c104707ecf2b'},
#        {'photoKey': '9c514e0c367f4558ab7a27522e80702d'},
#        {'photoKey': 'b86a513e9dcff674b8b178fc7de6c9ec'},
#        {'photoKey': '9a6e82b3d9ec46a9ec8f0ddab44d667b'},
#        {'photoKey': 'f0d002322c31f3080d1ffa55bf68fc02'},
#        {'photoKey': '2438dedbf468ca935887ca83707a1de3'},
#        {'photoKey': 'eecf1d92397d1f9b93753b2f45d434a6'},
#        {'photoKey': 'e212c980862feb51386dec0b3c4c7eea'},
#        {'photoKey': '41d427c72f005e99cb19520bd0950490'},
#        {'photoKey': 'ee2bd753701ea32515ba520ba70ab5f7'},
#        {'photoKey': 'f92229efbeba81261333c043d1140de3'},
#        {'photoKey': '6253425924fd439d9894ba83165a93da'},
#        {'photoKey': 'cbf2267896dd6205570da252e065c8ea'},
#        {'photoKey': 'fe8f242d74098f4f9e009ad77315dca7'},
#        {'photoKey': 'e490dcd93195a0bad687f801f6ba740b'},
#        {'photoKey': '6a5ae09e667a89d0c6bd9eb5aaf1d1c5'},
#        {'photoKey': '1920360ba9cf7ce9d61ffadf6c9ff881'},
#        {'photoKey': '0ac35f5731c6554060231d1b2db0572d'},
#        {'photoKey': '4939c6ba4e1fb426128ad7124eed810b'},
#        {'photoKey': '474eb34830c45a4da59d3bb38940c0f3'},
#        {'photoKey': 'c2dc7359c54e6622d59720305dbb4a70'},
#        {'photoKey': '250022564f7eb19a57c451893e38d993'},
#        {'photoKey': 'b4cfb6f368fbdccb9d060821915d883d'}],
#       'communityPhotoData': None,
#       'isStaticUrls': False},
#      'isPaidBuilderNewConstruction': False},
#     {'zpid': '58360757',
#      'palsId': '17001_12526030',
#      'id': '58360757',
#      'rawHomeStatusCd': 'ForSale',
#      'marketingStatusSimplifiedCd': 'For Sale by Agent',
#      'imgSrc': 'https://photos.zillowstatic.com/fp/051dcef5e7741b08ad311d95420bbd43-p_e.jpg',
#      'hasImage': True,
#      'detailUrl': 'https://www.zillow.com/homedetails/1956-W-Melrose-St-102-Chicago-IL-60657/58360757_zpid/',
#      'statusType': 'FOR_SALE',
#      'statusText': 'New',
#      'countryCurrency': '$',
#      'price': '$270,000',
#      'unformattedPrice': 270000,
#      'address': '1956 W Melrose St #102, Chicago, IL 60657',
#      'addressStreet': '1956 W Melrose St #102',
#      'addressCity': 'Chicago',
#      'addressState': 'IL',
#      'addressZipcode': '60657',
#      'isUndisclosedAddress': False,
#      'shouldShowRequestOnPrice': False,
#      'beds': 1,
#      'baths': 1.0,
#      'area': 0,
#      'latLong': {'latitude': 41.940628, 'longitude': -87.67809},
#      'isZillowOwned': False,
#      'flexFieldText': 'Beautifully maintained vintage building',
#      'contentType': 'homeInsight',
#      'hdpData': {'homeInfo': {'zpid': 58360757,
#        'streetAddress': '1956 W Melrose St #102',
#        'zipcode': '60657',
#        'city': 'Chicago',
#        'state': 'IL',
#        'latitude': 41.940628,
#        'longitude': -87.67809,
#        'price': 270000.0,
#        'bathrooms': 1.0,
#        'bedrooms': 1.0,
#        'livingArea': 0.0,
#        'homeType': 'CONDO',
#        'homeStatus': 'FOR_SALE',
#        'daysOnZillow': 4,
#        'isFeatured': False,
#        'shouldHighlight': False,
#        'listing_sub_type': {'is_FSBA': True},
#        'isUnmappable': False,
#        'isPreforeclosureAuction': False,
#        'homeStatusForHDP': 'FOR_SALE',
#        'priceForHDP': 270000.0,
#        'timeOnZillow': 371155000,
#        'isNonOwnerOccupied': True,
#        'isPremierBuilder': False,
#        'isZillowOwned': False,
#        'currency': 'USD',
#        'country': 'USA',
#        'taxAssessedValue': 198020.0,
#        'unit': '# 102',
#        'isShowcaseListing': False}},
#      'isSaved': False,
#      'isUserClaimingOwner': False,
#      'isUserConfirmedClaim': False,
#      'pgapt': 'ForSale',
#      'sgapt': 'For Sale (Broker)',
#      'shouldShowZestimateAsPrice': False,
#      'has3DModel': False,
#      'hasVideo': False,
#      'isHomeRec': False,
#      'hasAdditionalAttributions': True,
#      'isFeaturedListing': False,
#      'isShowcaseListing': False,
#      'list': True,
#      'relaxed': False,
#      'brokerName': 'Keller Williams ONEChicago',
#      'carouselPhotosComposable': {'baseUrl': 'https://photos.zillowstatic.com/fp/{photoKey}-p_e.jpg',
#       'communityBaseUrl': None,
#       'photoData': [{'photoKey': '051dcef5e7741b08ad311d95420bbd43'},
#        {'photoKey': '4a7a19042a18c7a651fbf16ac92b2dd1'},
#        {'photoKey': '1ed1bdee16c14432d9f0bfef0231ef8b'},
#        {'photoKey': '464f6d1da8d0c5827ac8fdc967532c71'},
#        {'photoKey': '3ab8595bf30e87dd9af72487d3f64127'},
#        {'photoKey': 'd97cfe0495a42ab80079ecb80d73f475'},
#        {'photoKey': 'd83928d1472655540f3b33f60154c574'},
#        {'photoKey': '99ae870ed8109b8bbd4b3cdcd253ef8d'},
#        {'photoKey': '700e6518a4987180558ec7efc965b7f7'},
#        {'photoKey': 'f61607fce94c22f67a23ec9c4b9f6246'},
#        {'photoKey': 'd7283ee31681087664e714e5a21f8ce0'},
#        {'photoKey': '8061f04329d88de32bd254e9b5ad1975'},
#        {'photoKey': '34c582c429a1d75e1ee4885b056b71bb'}],
#       'communityPhotoData': None,
#       'isStaticUrls': False},
#      'isPaidBuilderNewConstruction': False},
#     {'zpid': '447323646',
#      'palsId': '17001_12502938',
#      'id': '447323646',
#      'rawHomeStatusCd': 'ForSale',
#      'marketingStatusSimplifiedCd': 'For Sale by Agent',
#      'imgSrc': 'https://photos.zillowstatic.com/fp/5c6d6f35a7b7ad851e55749e1b014039-p_e.jpg',
#      'hasImage': True,
#      'detailUrl': 'https://www.zillow.com/homedetails/1838-S-Springfield-Ave-APT-A-Chicago-IL-60623/447323646_zpid/',
#      'statusType': 'FOR_SALE',
#      'statusText': 'Active',
#      'countryCurrency': '$',
#      'price': '$135,000',
#      'unformattedPrice': 135000,
#      'address': '1838 S Springfield Ave APT A, Chicago, IL 60623',
#      'addressStreet': '1838 S Springfield Ave APT A',
#      'addressCity': 'Chicago',
#      'addressState': 'IL',
#      'addressZipcode': '60623',
#      'isUndisclosedAddress': False,
#      'shouldShowRequestOnPrice': False,
#      'beds': 3,
#      'baths': 3.0,
#      'area': 1338,
#      'latLong': {'latitude': 41.856052, 'longitude': -87.72273},
#      'isZillowOwned': False,
#      'flexFieldText': 'Attached townhouse',
#      'contentType': 'homeInsight',
#      'hdpData': {'homeInfo': {'zpid': 447323646,
#        'streetAddress': '1838 S Springfield Ave APT A',
#        'zipcode': '60623',
#        'city': 'Chicago',
#        'state': 'IL',
#        'latitude': 41.856052,
#        'longitude': -87.72273,
#        'price': 135000.0,
#        'bathrooms': 3.0,
#        'bedrooms': 3.0,
#        'livingArea': 1338.0,
#        'homeType': 'CONDO',
#        'homeStatus': 'FOR_SALE',
#        'daysOnZillow': 46,
#        'isFeatured': False,
#        'shouldHighlight': False,
#        'listing_sub_type': {'is_FSBA': True},
#        'isUnmappable': False,
#        'isPreforeclosureAuction': False,
#        'homeStatusForHDP': 'FOR_SALE',
#        'priceForHDP': 135000.0,
#        'timeOnZillow': 3983764000,
#        'isNonOwnerOccupied': True,
#        'isPremierBuilder': False,
#        'isZillowOwned': False,
#        'currency': 'USD',
#        'country': 'USA',
#        'unit': 'Apt A',
#        'isShowcaseListing': False}},
#      'isSaved': False,
#      'isUserClaimingOwner': False,
#      'isUserConfirmedClaim': False,
#      'pgapt': 'ForSale',
#      'sgapt': 'For Sale (Broker)',
#      'shouldShowZestimateAsPrice': False,
#      'has3DModel': False,
#      'hasVideo': False,
#      'isHomeRec': False,
#      'hasAdditionalAttributions': True,
#      'isFeaturedListing': False,
#      'isShowcaseListing': False,
#      'list': True,
#      'relaxed': False,
#      'brokerName': 'RE/MAX Mi Casa',
#      'carouselPhotosComposable': {'baseUrl': 'https://photos.zillowstatic.com/fp/{photoKey}-p_e.jpg',
#       'communityBaseUrl': None,
#       'photoData': [{'photoKey': '5c6d6f35a7b7ad851e55749e1b014039'},
#        {'photoKey': '6039775ab611a9ab5d6a556f25f557b2'},
#        {'photoKey': 'ad9303b5e122654086b7e09430702d34'},
#        {'photoKey': '17ba991647316ada64836732a829b08e'},
#        {'photoKey': 'd164fffd1771c7da5da37355a14eb4d7'},
#        {'photoKey': '9973a8e47ca0e555c15aafd6eb952b50'},
#        {'photoKey': '2e64b941900f83cb5d5391b33f3f64b1'},
#        {'photoKey': '0c4733935545e03c0ec4c1eda35513a3'},
#        {'photoKey': '9fd16085bad91dc7c672bba2646623aa'},
#        {'photoKey': '10d49409480b80c645f2662fb444e8c0'},
#        {'photoKey': '94d0dcc7c8e56f608de600872c2fd979'},
#        {'photoKey': 'f82b4d5568c43cd07c066bf8c936d06a'},
#        {'photoKey': '2f7402c11a9e01d6b6f5c8c6ecc4049d'},
#        {'photoKey': '75ba305c6d3ae9e1f297c990e450c40d'},
#        {'photoKey': 'f062347815d77e9aacb155e61ab71257'},
#        {'photoKey': '20da4c95cfe325b7e7a6dbc573eb2c93'},
#        {'photoKey': '7397658261cf14fd94c3338da6cdb8a5'}],
#       'communityPhotoData': None,
#       'isStaticUrls': False},
#      'isPaidBuilderNewConstruction': False},
#     {'zpid': '3712346',
#      'palsId': '17001_12527689',
#      'id': '3712346',
#      'rawHomeStatusCd': 'ForSale',
#      'marketingStatusSimplifiedCd': 'For Sale by Agent',
#      'imgSrc': 'https://photos.zillowstatic.com/fp/f94b2086bbe3e1f8040a09a87bfb99b0-p_e.jpg',
#      'hasImage': True,
#      'detailUrl': 'https://www.zillow.com/homedetails/921-W-Addison-St-3B-Chicago-IL-60613/3712346_zpid/',
#      'statusType': 'FOR_SALE',
#      'statusText': 'New',
#      'countryCurrency': '$',
#      'price': '$550,000',
#      'unformattedPrice': 550000,
#      'address': '921 W Addison St #3B, Chicago, IL 60613',
#      'addressStreet': '921 W Addison St #3B',
#      'addressCity': 'Chicago',
#      'addressState': 'IL',
#      'addressZipcode': '60613',
#      'isUndisclosedAddress': False,
#      'shouldShowRequestOnPrice': False,
#      'beds': 2,
#      'baths': 2.0,
#      'area': 1650,
#      'latLong': {'latitude': 41.94705, 'longitude': -87.652885},
#      'isZillowOwned': False,
#      'flexFieldText': 'Massive brick wood-burning fireplace',
#      'contentType': 'homeInsight',
#      'hdpData': {'homeInfo': {'zpid': 3712346,
#        'streetAddress': '921 W Addison St #3B',
#        'zipcode': '60613',
#        'city': 'Chicago',
#        'state': 'IL',
#        'latitude': 41.94705,
#        'longitude': -87.652885,
#        'price': 550000.0,
#        'bathrooms': 2.0,
#        'bedrooms': 2.0,
#        'livingArea': 1650.0,
#        'homeType': 'CONDO',
#        'homeStatus': 'FOR_SALE',
#        'daysOnZillow': 4,
#        'isFeatured': False,
#        'shouldHighlight': False,
#        'listing_sub_type': {'is_FSBA': True},
#        'isUnmappable': False,
#        'isPreforeclosureAuction': False,
#        'homeStatusForHDP': 'FOR_SALE',
#        'priceForHDP': 550000.0,
#        'timeOnZillow': 371757000,
#        'isNonOwnerOccupied': True,
#        'isPremierBuilder': False,
#        'isZillowOwned': False,
#        'currency': 'USD',
#        'country': 'USA',
#        'taxAssessedValue': 440110.0,
#        'unit': '# 3B',
#        'isShowcaseListing': False}},
#      'isSaved': False,
#      'isUserClaimingOwner': False,
#      'isUserConfirmedClaim': False,
#      'pgapt': 'ForSale',
#      'sgapt': 'For Sale (Broker)',
#      'shouldShowZestimateAsPrice': False,
#      'has3DModel': False,
#      'hasVideo': False,
#      'isHomeRec': False,
#      'hasAdditionalAttributions': True,
#      'isFeaturedListing': False,
#      'isShowcaseListing': False,
#      'list': True,
#      'relaxed': False,
#      'brokerName': "@properties Christie's International Real Estate",
#      'carouselPhotosComposable': {'baseUrl': 'https://photos.zillowstatic.com/fp/{photoKey}-p_e.jpg',
#       'communityBaseUrl': None,
#       'photoData': [{'photoKey': 'f94b2086bbe3e1f8040a09a87bfb99b0'},
#        {'photoKey': '4ca24553eb2fa53129dc2a9c0ad2ee99'},
#        {'photoKey': 'beaf6d68a023b34633c293cd0b472302'},
#        {'photoKey': '628a0304519a1d38564ffad1db2256f5'},
#        {'photoKey': 'a760db9c25ffa1df69712efd43d81ad3'},
#        {'photoKey': 'd1ceb312156852bcbddd74a897bf6dbd'},
#        {'photoKey': 'd69ad9fb56937c372b19caf83a495809'},
#        {'photoKey': '7423a955e4146878ea08ab4d55af5365'},
#        {'photoKey': 'cdf41f3fc5140c19731d554542dc25cf'},
#        {'photoKey': '0e1ae1c7e140b4f5f261fb4fa696c2ae'},
#        {'photoKey': '1bc5bcfbcdfb76a7e66b9be1ff213c54'},
#        {'photoKey': '1dd909a7aca4ba59df0cc9af9996e45a'},
#        {'photoKey': '338af25ce54fdb7688f4e0d37f2f1cf2'},
#        {'photoKey': '1fb0e881ce21adaddcac1d47916f2b94'},
#        {'photoKey': '198085b4a3a49734ecba1bb8264ac446'},
#        {'photoKey': 'bdb3ec20e51b35f9975ef29bad23fac2'},
#        {'photoKey': '8e37441f65da803c54af0f3923763db4'},
#        {'photoKey': '1e9fee3ca5fce0449e5e10a70b128fdc'},
#        {'photoKey': 'e8f3457d5b70b9b3b7073cf384f2bea9'},
#        {'photoKey': '4562cd79e3a7688bd891173685eb40e1'},
#        {'photoKey': 'b3fbecbc1e16870a2500bd788509ac0c'},
#        {'photoKey': 'a88ca358c264c3cb9fc713f06927b7e5'},
#        {'photoKey': '8cf4e09af7c38437e05eca3204fdb50c'},
#        {'photoKey': 'afc5ff6623e62bd52f4f4bcbc952e9b7'},
#        {'photoKey': '9a49eddc4252f7294902fd2ad90b553e'},
#        {'photoKey': '270412d195dd15bc4e4f1ecb5c4bba10'},
#        {'photoKey': '1c04f71343b3323b4d908467e2b834a9'},
#        {'photoKey': 'af174b0fb0df880635fc9c3c2e728fa4'}],
#       'communityPhotoData': None,
#       'isStaticUrls': False},
#      'isPaidBuilderNewConstruction': False},
#     {'zpid': '2068986948',
#      'palsId': '17001_12525222',
#      'id': '2068986948',
#      'rawHomeStatusCd': 'ForSale',
#      'marketingStatusSimplifiedCd': 'For Sale by Agent',
#      'imgSrc': 'https://photos.zillowstatic.com/fp/d340b25e3130e605f1aaa83bc261d1f4-p_e.jpg',
#      'hasImage': True,
#      'detailUrl': 'https://www.zillow.com/homedetails/733-W-Buckingham-Pl-13-Chicago-IL-60657/2068986948_zpid/',
#      'statusType': 'FOR_SALE',
#      'statusText': 'New',
#      'countryCurrency': '$',
#      'price': '$335,000',
#      'unformattedPrice': 335000,
#      'address': '733 W Buckingham Pl #13, Chicago, IL 60657',
#      'addressStreet': '733 W Buckingham Pl #13',
#      'addressCity': 'Chicago',
#      'addressState': 'IL',
#      'addressZipcode': '60657',
#      'isUndisclosedAddress': False,
#      'shouldShowRequestOnPrice': False,
#      'beds': 1,
#      'baths': 1.0,
#      'latLong': {'latitude': 41.942455, 'longitude': -87.64831},
#      'isZillowOwned': False,
#      'flexFieldText': 'Kitchen with newer appliances',
#      'contentType': 'homeInsight',
#      'hdpData': {'homeInfo': {'zpid': 2068986948,
#        'streetAddress': '733 W Buckingham Pl #13',
#        'zipcode': '60657',
#        'city': 'Chicago',
#        'state': 'IL',
#        'latitude': 41.942455,
#        'longitude': -87.64831,
#        'price': 335000.0,
#        'bathrooms': 1.0,
#        'bedrooms': 1.0,
#        'homeType': 'CONDO',
#        'homeStatus': 'FOR_SALE',
#        'daysOnZillow': 3,
#        'isFeatured': False,
#        'shouldHighlight': False,
#        'listing_sub_type': {'is_FSBA': True},
#        'isUnmappable': False,
#        'isPreforeclosureAuction': False,
#        'homeStatusForHDP': 'FOR_SALE',
#        'priceForHDP': 335000.0,
#        'timeOnZillow': 296452000,
#        'isNonOwnerOccupied': True,
#        'isPremierBuilder': False,
#        'isZillowOwned': False,
#        'currency': 'USD',
#        'country': 'USA',
#        'unit': '# 13',
#        'isShowcaseListing': False}},
#      'isSaved': False,
#      'isUserClaimingOwner': False,
#      'isUserConfirmedClaim': False,
#      'pgapt': 'ForSale',
#      'sgapt': 'For Sale (Broker)',
#      'shouldShowZestimateAsPrice': False,
#      'has3DModel': True,
#      'hasVideo': False,
#      'isHomeRec': False,
#      'hasAdditionalAttributions': True,
#      'isFeaturedListing': False,
#      'isShowcaseListing': False,
#      'list': True,
#      'relaxed': False,
#      'brokerName': "@properties Christie's International Real Estate",
#      'carouselPhotosComposable': {'baseUrl': 'https://photos.zillowstatic.com/fp/{photoKey}-p_e.jpg',
#       'communityBaseUrl': None,
#       'photoData': [{'photoKey': 'd340b25e3130e605f1aaa83bc261d1f4'},
#        {'photoKey': '3c3fc01c573b4e74caaaa1196ae08511'},
#        {'photoKey': '842492f1266a2fbb788c6f8739c6de95'},
#        {'photoKey': '7d062a043f1b16650e77b9b0072c7247'},
#        {'photoKey': 'c16bc4fd2ce7df7f827592e851dda5e1'},
#        {'photoKey': 'a598879ac1221e2afc2f15f90b1eb994'},
#        {'photoKey': '51bee534adf1cb3cec6e0bf3a0b7df9f'},
#        {'photoKey': 'cceddf950fd63b8996e3d39ffded0567'},
#        {'photoKey': '8164be5e66f45a886550b86702ea1146'},
#        {'photoKey': '86c5bb8b04ec7ec73bf4c39048b15b32'},
#        {'photoKey': 'ba980db5268461f2bbc6927e20772fd4'},
#        {'photoKey': 'a22b50eb5c607e553dc6e4d1409dabef'},
#        {'photoKey': '5c6505aac6d9915c42b8fc0ff248f3c4'},
#        {'photoKey': 'c3aa2f334c7622ac6044944e1942e989'},
#        {'photoKey': '514a49324d849d2ad4e5fe39a05d2fed'},
#        {'photoKey': '5b9228a6024d5204975b83fc8c078f04'},
#        {'photoKey': 'c53ae2fb8bccafe3f08ffad2f8295a59'},
#        {'photoKey': '24e563ac28cce63ad5bbd21c58c54312'},
#        {'photoKey': 'f5679d302bcb7c90f2035d353de8cf36'},
#        {'photoKey': 'c43c7e5a5cbe3e0a8d4d912015cfd7d3'},
#        {'photoKey': 'fe27c12c82d2ffd0bf885d943543d463'},
#        {'photoKey': '1d8fbe373a86b593f1136c8583152376'},
#        {'photoKey': 'e5ac36b1960a5008a5ce393866eacf79'},
#        {'photoKey': 'dab752e08b1195e299ef8d2460e8bc5d'},
#        {'photoKey': '71322b5b2be98aaf20677372cd091112'},
#        {'photoKey': 'c8fb7ae85d413f34480077f3e2ab33e4'},
#        {'photoKey': '7ed6fdb79dd690072273c7c38daf7f2f'},
#        {'photoKey': 'eef45e66d44c1e26403b0092172666e8'}],
#       'communityPhotoData': None,
#       'isStaticUrls': False},
#      'isPaidBuilderNewConstruction': False},
#     {'zpid': '60263323',
#      'palsId': '17001_12528756',
#      'id': '60263323',
#      'rawHomeStatusCd': 'ForSale',
#      'marketingStatusSimplifiedCd': 'For Sale by Agent',
#      'imgSrc': 'https://photos.zillowstatic.com/fp/d0ae216fa14876d32b285b267f9759a4-p_e.jpg',
#      'hasImage': True,
#      'detailUrl': 'https://www.zillow.com/homedetails/945-W-Agatite-Ave-APT-2-Chicago-IL-60640/60263323_zpid/',
#      'statusType': 'FOR_SALE',
#      'statusText': 'New',
#      'countryCurrency': '$',
#      'price': '$497,000',
#      'unformattedPrice': 497000,
#      'address': '945 W Agatite Ave APT 2, Chicago, IL 60640',
#      'addressStreet': '945 W Agatite Ave APT 2',
#      'addressCity': 'Chicago',
#      'addressState': 'IL',
#      'addressZipcode': '60640',
#      'isUndisclosedAddress': False,
#      'shouldShowRequestOnPrice': False,
#      'beds': 3,
#      'baths': 2.0,
#      'area': 0,
#      'latLong': {'latitude': 41.962433, 'longitude': -87.65413},
#      'isZillowOwned': False,
#      'flexFieldText': 'Marble-surround gas fireplace',
#      'contentType': 'homeInsight',
#      'hdpData': {'homeInfo': {'zpid': 60263323,
#        'streetAddress': '945 W Agatite Ave APT 2',
#        'zipcode': '60640',
#        'city': 'Chicago',
#        'state': 'IL',
#        'latitude': 41.962433,
#        'longitude': -87.65413,
#        'price': 497000.0,
#        'bathrooms': 2.0,
#        'bedrooms': 3.0,
#        'livingArea': 0.0,
#        'homeType': 'CONDO',
#        'homeStatus': 'FOR_SALE',
#        'daysOnZillow': 2,
#        'isFeatured': False,
#        'shouldHighlight': False,
#        'listing_sub_type': {'is_FSBA': True},
#        'isUnmappable': False,
#        'isPreforeclosureAuction': False,
#        'homeStatusForHDP': 'FOR_SALE',
#        'priceForHDP': 497000.0,
#        'timeOnZillow': 252071000,
#        'isNonOwnerOccupied': True,
#        'isPremierBuilder': False,
#        'isZillowOwned': False,
#        'currency': 'USD',
#        'country': 'USA',
#        'taxAssessedValue': 302990.0,
#        'unit': 'Apt 2',
#        'isShowcaseListing': False}},
#      'isSaved': False,
#      'isUserClaimingOwner': False,
#      'isUserConfirmedClaim': False,
#      'pgapt': 'ForSale',
#      'sgapt': 'For Sale (Broker)',
#      'shouldShowZestimateAsPrice': False,
#      'has3DModel': False,
#      'hasVideo': False,
#      'isHomeRec': False,
#      'hasAdditionalAttributions': True,
#      'isFeaturedListing': False,
#      'isShowcaseListing': False,
#      'list': True,
#      'relaxed': False,
#      'brokerName': "@properties Christie's International Real Estate",
#      'carouselPhotosComposable': {'baseUrl': 'https://photos.zillowstatic.com/fp/{photoKey}-p_e.jpg',
#       'communityBaseUrl': None,
#       'photoData': [{'photoKey': 'd0ae216fa14876d32b285b267f9759a4'},
#        {'photoKey': '7693a7070272d4adc4028f455cb0ccfa'},
#        {'photoKey': '8bdc96be9faf1bc1ce86b68e4a089987'},
#        {'photoKey': '7567c453f2b591a8f60fafdc22bb00a2'},
#        {'photoKey': '2f5cec0d5f2f5bf7173f2605f880a60b'},
#        {'photoKey': '00df1576cb2c531557374142e188b991'},
#        {'photoKey': 'd49b2974c85c541dc44c92177e74c27d'},
#        {'photoKey': 'bccbbf36d26fe4962978ae2460db21de'},
#        {'photoKey': '3d4dd718e8d462e318170c85dbf16d08'},
#        {'photoKey': '5ba9791f2bab26256d6d7c971d70c43b'},
#        {'photoKey': 'a62b50c9d93fe62120e61545178524cd'},
#        {'photoKey': '79036208d4c74e1a1e6e210821d8156a'},
#        {'photoKey': 'da88fa010a4b9cbc843183f64a838fa8'},
#        {'photoKey': '5e5870771341be0b2eb5ddb4bf94eba0'},
#        {'photoKey': 'b9949069c09a37837f7f1469adaad1a9'},
#        {'photoKey': '4f28bc0b4785fb3f88c80578a2b6cbac'},
#        {'photoKey': 'c202b569cb50df1f6da5fa546d6aa4f6'},
#        {'photoKey': 'd397d98d3238d1c0a095a15ab20c53dc'},
#        {'photoKey': '6648dfa28d14a0bf9b58da8ca79be2ef'},
#        {'photoKey': '80e5e090497e847cdf38641f23a5c480'},
#        {'photoKey': '8b2b5a874f21ecaa039e4bfbfa53e72c'},
#        {'photoKey': '2199c50f5de2c5537dc4d4cd14f1decd'}],
#       'communityPhotoData': None,
#       'isStaticUrls': False},
#      'isPaidBuilderNewConstruction': False},
#     {'zpid': '121070356',
#      'palsId': '17001_12495572',
#      'id': '121070356',
#      'rawHomeStatusCd': 'ForSale',
#      'marketingStatusSimplifiedCd': 'For Sale by Agent',
#      'imgSrc': 'https://photos.zillowstatic.com/fp/3553dbb5a7c68197bc51ec195daba10a-p_e.jpg',
#      'hasImage': True,
#      'detailUrl': 'https://www.zillow.com/homedetails/1630-N-Sedgwick-St-APT-2-Chicago-IL-60614/121070356_zpid/',
#      'statusType': 'FOR_SALE',
#      'statusText': 'Active',
#      'countryCurrency': '$',
#      'price': '$579,900',
#      'unformattedPrice': 579900,
#      'address': '1630 N Sedgwick St APT 2, Chicago, IL 60614',
#      'addressStreet': '1630 N Sedgwick St APT 2',
#      'addressCity': 'Chicago',
#      'addressState': 'IL',
#      'addressZipcode': '60614',
#      'isUndisclosedAddress': False,
#      'shouldShowRequestOnPrice': False,
#      'beds': 2,
#      'baths': 2.0,
#      'area': 1400,
#      'latLong': {'latitude': 41.91206, 'longitude': -87.63916},
#      'isZillowOwned': False,
#      'flexFieldText': 'Price cut: $19,100 (11/30)',
#      'contentType': 'priceCut',
#      'hdpData': {'homeInfo': {'zpid': 121070356,
#        'streetAddress': '1630 N Sedgwick St APT 2',
#        'zipcode': '60614',
#        'city': 'Chicago',
#        'state': 'IL',
#        'latitude': 41.91206,
#        'longitude': -87.63916,
#        'price': 579900.0,
#        'datePriceChanged': 1764489600000,
#        'bathrooms': 2.0,
#        'bedrooms': 2.0,
#        'livingArea': 1400.0,
#        'homeType': 'TOWNHOUSE',
#        'homeStatus': 'FOR_SALE',
#        'daysOnZillow': 53,
#        'isFeatured': False,
# ...
#      'statusType': 'FOR_SALE',
#      'statusText': 'New',
#      'price': '$45,000',
#      'priceLabel': '$45K',
#      'address': '6531 S Emerald Ave, Chicago, IL 60621',
#      'addressState': 'IL',
#      'shouldShowRequestOnPrice': False,
#      'lotAreaString': '3,333 sqft',
#      'latLong': {'latitude': 41.775185, 'longitude': -87.64341},
#      'flexFieldText': '10 hours ago',
#      'contentType': 'timeOnInfo',
#      'hdpData': {'homeInfo': {'zpid': 159037232,
#        'streetAddress': '6531 S Emerald Ave',
#        'zipcode': '60621',
#        'city': 'Chicago',
#        'state': 'IL',
#        'latitude': 41.775185,
#        'longitude': -87.64341,
#        'price': 45000.0,
#        'homeType': 'LOT',
#        'homeStatus': 'FOR_SALE',
#        'daysOnZillow': 0,
#        'isFeatured': False,
#        'shouldHighlight': False,
#        'listing_sub_type': {'is_FSBA': True},
#        'isUnmappable': False,
#        'isPreforeclosureAuction': False,
#        'homeStatusForHDP': 'FOR_SALE',
#        'priceForHDP': 45000.0,
#        'timeOnZillow': 38765000,
#        'isNonOwnerOccupied': True,
#        'isPremierBuilder': False,
#        'isZillowOwned': False,
#        'currency': 'USD',
#        'country': 'USA',
#        'taxAssessedValue': 16660.0,
#        'lotAreaValue': 3332.8416,
#        'lotAreaUnit': 'sqft',
#        'isShowcaseListing': False}},
#      'isUserClaimingOwner': False,
#      'isUserConfirmedClaim': False,
#      'pgapt': 'ForSale',
#      'sgapt': 'For Sale (Broker)',
#      'shouldShowZestimateAsPrice': False,
#      'has3DModel': False,
#      'hasVideo': False,
#      'isHomeRec': False,
#      'hasAdditionalAttributions': True,
#      'isFeaturedListing': False,
#      'isShowcaseListing': False,
#      'listingType': '',
#      'isFavorite': False,
#      'visited': False,
#      'brokerName': 'Exit Strategy Realty',
#      'timeOnZillow': 38765000,
#      'isPaidBuilderNewConstruction': False},
#     {'imgSrc': 'https://photos.zillowstatic.com/fp/3eff2bac22fb87e92d5800e9a82fde02-p_e.jpg',
#      'hasImage': True,
#      'detailUrl': '/apartments/chicago-il/marina-city/BckT/',
#      'statusType': 'FOR_SALE',
#      'statusText': 'For Rent',
#      'price': 'From $215,000',
#      'address': '300 N State St, Chicago, IL',
#      'addressState': 'IL',
#      'shouldShowRequestOnPrice': False,
#      'minBeds': 0,
#      'minBaths': 1.0,
#      'minArea': 500,
#      'lotId': 1015009,
#      'latLong': {'latitude': 41.887913, 'longitude': -87.62902},
#      'flexFieldText': 'Modern lighting',
#      'contentType': 'homeInsight',
#      'buildingId': '41.887913--87.62902',
#      'isBuilding': True,
#      'canSaveBuilding': True,
#      'has3DModel': False,
#      'isHomeRec': False,
#      'hasAdditionalAttributions': False,
#      'isFeaturedListing': False,
#      'isShowcaseListing': False,
#      'listingType': '',
#      'isFavorite': False,
#      'timeOnZillow': 360060000,
#      'unitCount': 6,
#      'listPriceIncludesRequiredMonthlyFees': False,
#      'isPaidBuilderNewConstruction': False},
#     {'zpid': '54537296',
#      'palsId': '17001_12523909',
#      'rawHomeStatusCd': 'ForSale',
#      'marketingStatusSimplifiedCd': 'For Sale by Agent',
#      'imgSrc': 'https://photos.zillowstatic.com/fp/b89f4884db3b7dc75f50526dbb174d9f-p_e.jpg',
#      'hasImage': True,
#      'detailUrl': '/homedetails/830-N-Hermitage-Ave-APT-2-Chicago-IL-60622/54537296_zpid/',
#      'statusType': 'FOR_SALE',
#      'statusText': 'Active',
#      'price': '$489,900',
#      'priceLabel': '$490K',
#      'address': '830 N Hermitage Ave APT 2, Chicago, IL 60622',
#      'addressState': 'IL',
#      'shouldShowRequestOnPrice': False,
#      'beds': 2,
#      'baths': 2.0,
#      'area': 1300,
#      'latLong': {'latitude': 41.89691, 'longitude': -87.6713},
#      'flexFieldText': 'Quiet tree lined street',
#      'contentType': 'homeInsight',
#      'hdpData': {'homeInfo': {'zpid': 54537296,
#        'streetAddress': '830 N Hermitage Ave APT 2',
#        'zipcode': '60622',
#        'city': 'Chicago',
#        'state': 'IL',
#        'latitude': 41.89691,
#        'longitude': -87.6713,
#        'price': 489900.0,
#        'bathrooms': 2.0,
#        'bedrooms': 2.0,
#        'livingArea': 1300.0,
#        'homeType': 'CONDO',
#        'homeStatus': 'FOR_SALE',
#        'daysOnZillow': 6,
#        'isFeatured': False,
#        'shouldHighlight': False,
#        'listing_sub_type': {'is_FSBA': True},
#        'isUnmappable': False,
#        'isPreforeclosureAuction': False,
#        'homeStatusForHDP': 'FOR_SALE',
#        'priceForHDP': 489900.0,
#        'timeOnZillow': 550855000,
#        'isNonOwnerOccupied': True,
#        'isPremierBuilder': False,
#        'isZillowOwned': False,
#        'currency': 'USD',
#        'country': 'USA',
#        'taxAssessedValue': 356650.0,
#        'unit': 'Apt 2',
#        'isShowcaseListing': False}},
#      'isUserClaimingOwner': False,
#      'isUserConfirmedClaim': False,
#      'pgapt': 'ForSale',
#      'sgapt': 'For Sale (Broker)',
#      'shouldShowZestimateAsPrice': False,
#      'has3DModel': False,
#      'hasVideo': False,
#      'isHomeRec': False,
#      'hasAdditionalAttributions': True,
#      'isFeaturedListing': False,
#      'isShowcaseListing': False,
#      'listingType': '',
#      'isFavorite': False,
#      'visited': False,
#      'brokerName': "Jameson Sotheby's Intl Realty",
#      'timeOnZillow': 550855000,
#      'isPaidBuilderNewConstruction': False},
#     {'zpid': '4141242',
#      'palsId': '17001_12529683',
#      'rawHomeStatusCd': 'ForSale',
#      'marketingStatusSimplifiedCd': 'For Sale by Agent',
#      'imgSrc': 'https://photos.zillowstatic.com/fp/2da9d3f47ef42377e83244cb536709ab-p_e.jpg',
#      'hasImage': True,
#      'detailUrl': '/homedetails/10626-S-Lowe-Ave-Chicago-IL-60628/4141242_zpid/',
#      'statusType': 'FOR_SALE',
#      'statusText': 'New',
#      'price': '$279,900',
#      'priceLabel': '$280K',
#      'address': '10626 S Lowe Ave, Chicago, IL 60628',
#      'addressState': 'IL',
#      'shouldShowRequestOnPrice': False,
#      'beds': 3,
#      'baths': 2.0,
#      'area': 2000,
#      'latLong': {'latitude': 41.70067, 'longitude': -87.63935},
#      'flexFieldText': '4 hours ago',
#      'contentType': 'timeOnInfo',
#      'hdpData': {'homeInfo': {'zpid': 4141242,
#        'streetAddress': '10626 S Lowe Ave',
#        'zipcode': '60628',
#        'city': 'Chicago',
#        'state': 'IL',
#        'latitude': 41.70067,
#        'longitude': -87.63935,
#        'price': 279900.0,
#        'bathrooms': 2.0,
#        'bedrooms': 3.0,
#        'livingArea': 2000.0,
#        'homeType': 'SINGLE_FAMILY',
#        'homeStatus': 'FOR_SALE',
#        'daysOnZillow': 0,
#        'isFeatured': False,
#        'shouldHighlight': False,
#        'zestimate': 282000,
#        'rentZestimate': 2435,
#        'listing_sub_type': {'is_FSBA': True, 'is_openHouse': True},
#        'openHouse': 'Sat. 1-3pm',
#        'isUnmappable': False,
#        'isPreforeclosureAuction': False,
#        'homeStatusForHDP': 'FOR_SALE',
#        'priceForHDP': 279900.0,
#        'open_house_info': {'open_house_showing': [{'open_house_start': 1765659600000,
#           'open_house_end': 1765666800000}]},
#        'timeOnZillow': 14468000,
#        'isNonOwnerOccupied': True,
#        'isPremierBuilder': False,
#        'isZillowOwned': False,
#        'currency': 'USD',
#        'country': 'USA',
#        'taxAssessedValue': 139990.0,
#        'lotAreaValue': 5602.5,
#        'lotAreaUnit': 'sqft',
#        'isShowcaseListing': False}},
#      'isUserClaimingOwner': False,
#      'isUserConfirmedClaim': False,
#      'pgapt': 'ForSale',
#      'sgapt': 'For Sale (Broker)',
#      'shouldShowZestimateAsPrice': False,
#      'has3DModel': False,
#      'hasVideo': False,
#      'isHomeRec': False,
#      'hasAdditionalAttributions': True,
#      'isFeaturedListing': False,
#      'isShowcaseListing': False,
#      'listingType': '',
#      'isFavorite': False,
#      'visited': False,
#      'brokerName': 'Hoffman Realtors LLC',
#      'timeOnZillow': 14468000,
#      'isPaidBuilderNewConstruction': False},
#     {'zpid': '2073822445',
#      'palsId': '17001_12524303',
#      'rawHomeStatusCd': 'ForSale',
#      'marketingStatusSimplifiedCd': 'For Sale by Agent',
#      'imgSrc': 'https://photos.zillowstatic.com/fp/a8409b47bbe466679da7d719eeeceb29-p_e.jpg',
#      'hasImage': True,
#      'detailUrl': '/homedetails/4950-S-Chicago-Beach-Dr-4A-Chicago-IL-60615/2073822445_zpid/',
#      'statusType': 'FOR_SALE',
#      'statusText': 'Active',
#      'price': '$350,000',
#      'priceLabel': '$350K',
#      'address': '4950 S Chicago Beach Dr #4A, Chicago, IL 60615',
#      'addressState': 'IL',
#      'shouldShowRequestOnPrice': False,
#      'beds': 4,
#      'baths': 4.0,
#      'area': 4197,
#      'latLong': {'latitude': 41.804607, 'longitude': -87.58447},
#      'flexFieldText': 'High ceilings',
#      'contentType': 'homeInsight',
#      'hdpData': {'homeInfo': {'zpid': 2073822445,
#        'streetAddress': '4950 S Chicago Beach Dr #4A',
#        'zipcode': '60615',
#        'city': 'Chicago',
#        'state': 'IL',
#        'latitude': 41.804607,
#        'longitude': -87.58447,
#        'price': 350000.0,
#        'bathrooms': 4.0,
#        'bedrooms': 4.0,
#        'livingArea': 4197.0,
#        'homeType': 'CONDO',
#        'homeStatus': 'FOR_SALE',
#        'daysOnZillow': 8,
#        'isFeatured': False,
#        'shouldHighlight': False,
#        'listing_sub_type': {'is_FSBA': True},
#        'isUnmappable': False,
#        'isPreforeclosureAuction': False,
#        'homeStatusForHDP': 'FOR_SALE',
#        'priceForHDP': 350000.0,
#        'timeOnZillow': 755764000,
#        'isNonOwnerOccupied': True,
#        'isPremierBuilder': False,
#        'isZillowOwned': False,
#        'currency': 'USD',
#        'country': 'USA',
#        'unit': '# 4A',
#        'isShowcaseListing': False}},
#      'isUserClaimingOwner': False,
#      'isUserConfirmedClaim': False,
#      'pgapt': 'ForSale',
#      'sgapt': 'For Sale (Broker)',
#      'shouldShowZestimateAsPrice': False,
#      'has3DModel': False,
#      'hasVideo': False,
#      'isHomeRec': False,
#      'hasAdditionalAttributions': True,
#      'isFeaturedListing': False,
#      'isShowcaseListing': False,
#      'listingType': '',
#      'isFavorite': False,
#      'visited': False,
#      'brokerName': 'Coldwell Banker Realty',
#      'timeOnZillow': 755764000,
#      'isPaidBuilderNewConstruction': False},
#     {'imgSrc': 'https://photos.zillowstatic.com/fp/f52cba46876814fbcdb3838ebf707516-p_e.jpg',
#      'hasImage': True,
#      'detailUrl': '/b/3300-n-lake-shore-dr-chicago-il-5XmQSw/',
#      'statusType': 'FOR_SALE',
#      'statusText': 'For Rent',
#      'price': 'From $299,000',
#      'address': '3300 N Lake Shore Dr, Chicago, IL',
#      'addressState': 'IL',
#      'shouldShowRequestOnPrice': False,
#      'minBeds': 2,
#      'minBaths': 1.0,
#      'minArea': 1800,
#      'lotId': 1001712729,
#      'latLong': {'latitude': 41.942604, 'longitude': -87.64038},
#      'flexFieldText': 'Well maintained building',
#      'contentType': 'homeInsight',
#      'buildingId': '41.942604--87.64038',
#      'isBuilding': True,
#      'canSaveBuilding': False,
#      'has3DModel': False,
#      'isHomeRec': False,
#      'hasAdditionalAttributions': False,
#      'isFeaturedListing': False,
#      'isShowcaseListing': False,
#      'listingType': '',
#      'isFavorite': False,
#      'timeOnZillow': 534079000,
#      'unitCount': 2,
#      'listPriceIncludesRequiredMonthlyFees': False,
#      'isPaidBuilderNewConstruction': False},
#     {'zpid': '2117368476',
#      'palsId': '17001_12501839',
#      'rawHomeStatusCd': 'ForSale',
#      'marketingStatusSimplifiedCd': 'For Sale by Agent',
#      'imgSrc': 'https://photos.zillowstatic.com/fp/bb961be597dd0d4826b47fad282e5bb5-p_e.jpg',
#      'hasImage': True,
#      'detailUrl': '/homedetails/1641-N-Kedzie-Ave-Chicago-IL-60647/2117368476_zpid/',
#      'statusType': 'FOR_SALE',
#      'statusText': 'Active',
#      'price': '$390,000',
#      'priceLabel': '$390K',
#      'address': '1641 N Kedzie Ave, Chicago, IL 60647',
#      'addressState': 'IL',
#      'shouldShowRequestOnPrice': False,
#      'beds': 4,
#      'baths': 2.0,
#      'area': 1277,
#      'latLong': {'latitude': 41.911373, 'longitude': -87.70641},
#      'flexFieldText': 'Price cut: $9,900 (11/12)',
#      'contentType': 'priceCut',
#      'hdpData': {'homeInfo': {'zpid': 2117368476,
#        'streetAddress': '1641 N Kedzie Ave',
#        'zipcode': '60647',
#        'city': 'Chicago',
#        'state': 'IL',
#        'latitude': 41.911373,
#        'longitude': -87.70641,
#        'price': 390000.0,
#        'datePriceChanged': 1762934400000,
#        'bathrooms': 2.0,
#        'bedrooms': 4.0,
#        'livingArea': 1277.0,
#        'homeType': 'SINGLE_FAMILY',
#        'homeStatus': 'FOR_SALE',
#        'daysOnZillow': 46,
#        'isFeatured': False,
#        'shouldHighlight': False,
#        'listing_sub_type': {'is_FSBA': True},
#        'priceReduction': '$9,900 (Nov 12)',
#        'isUnmappable': False,
#        'isPreforeclosureAuction': False,
#        'homeStatusForHDP': 'FOR_SALE',
#        'priceForHDP': 390000.0,
#        'priceChange': -9900,
#        'timeOnZillow': 3987654000,
#        'isNonOwnerOccupied': True,
#        'isPremierBuilder': False,
#        'isZillowOwned': False,
#        'currency': 'USD',
#        'country': 'USA',
#        'taxAssessedValue': 450000.0,
#        'lotAreaValue': 2600.0,
#        'lotAreaUnit': 'sqft',
#        'isShowcaseListing': False}},
#      'isUserClaimingOwner': False,
#      'isUserConfirmedClaim': False,
#      'pgapt': 'ForSale',
#      'sgapt': 'For Sale (Broker)',
#      'shouldShowZestimateAsPrice': False,
#      'has3DModel': False,
#      'hasVideo': False,
#      'isHomeRec': False,
#      'hasAdditionalAttributions': True,
#      'isFeaturedListing': False,
#      'isShowcaseListing': False,
#      'listingType': '',
#      'isFavorite': False,
#      'visited': False,
#      'brokerName': 'Cloud Gate Realty LLC',
#      'timeOnZillow': 3987654000,
#      'isPaidBuilderNewConstruction': False}],
#    'relaxedResults': [],
#    'relaxedMapResults': [],
#    'resultsHash': '23f99c8b',
#    'showForYouCount': 0,
#    'relaxedResultsHash': '1',
#    'resultsCommingled': True,
#    'restrictedListingCount': 7},
#   'searchList': {'expansionDistance': 0,
#    'staticBaseUrl': None,
#    'zeroResultResponse': {'shouldShowZeroResultMessage': False,
#     'shouldShowFilterSuggestionBoxes': False,
#     'filterRemovalSuggestions': None},
#    'pagination': {'nextUrl': '/chicago-il/2_p/'},
#    'adsConfig': {'navAdSlot': 'zillow_phone_mweb/search_results_1/buy_general/search_1',
#     'targets': {'guid': 'd1bb6194-19b4-4f03-97fc-62958721ba5e',
#      'vers': 'constellation_dynamic,srp_ad_target_refactor',
#      'premieragent': 'no',
#      'state': 'IL',
#      'dma': '78',
#      'cnty': 'Cook',
#      'city': 'Chicago',
#      'mlat': '41.83367018839145',
#      'mlong': '-87.731942',
#      'listtp': 'buy_general',
#      'searchtp': 'city'},
#     'needsUpdate': True,
#     'restrictedAds': False},
#    'totalResultCount': 5365,
#    'resultsPerPage': 41,
#    'totalPages': 20,
#    'limitSearchResultsCount': None,
#    'listResultsTitle': 'Chicago IL Real Estate & Homes For Sale',
#    'resultContexts': [{'ssid': 17,
#      'context': 'Based on information submitted to the MLS GRID as of 2025. All data is obtained from various sources and may not have been verified by broker or MLS GRID. Supplied Open House Information is subject to change without notice. All information should be independently reviewed and verified for accuracy. Properties may or may not be listed by the office/agent presenting the information.  [Click here for more information](/mls-disclaimers/#17)\n\n',
#      'contextImage': 'https://photos.zillowstatic.com/fp/1b0fc53ffc89ea17e1e382976aca4421-zillow_web_95_35.jpg'},
#     {'ssid': 7306,
#      'context': '',
#      'contextImage': 'https://photos.zillowstatic.com/fp/c83d30e1411cb465f7ebd2e77778ae29-zillow_web_95_35.jpg'}],
#    'pageRules': 'PropertySearchLookupResponseRules(isAdsRestricted=false, lowestLimitSearchResultsCount=null)',
#    'gdpUrl': 'https://www.zillow.com/graphql/',
#    'zgGraphUrl': '/zg-graph',
#    'shareConfig': {'captchaKey': '6Lf2nvMSAAAAAMQ5p6WlAfDEixMdOQgJsij-3_ud',
#     'csrfToken': 'r72O4NMsrMPSadUoD8fmDAfqaIRayYBv'}}},
#  'categoryTotals': {'cat1': {'totalResultCount': 5365},
#   'cat2': {'totalResultCount': 5365}}}

# %%
# view count of properies returned in request
num_of_properties = listing_response.json()["data"]["categoryTotals"]["cat1"]["totalResultCount"]
print("Count of properties:", num_of_properties)
# Out:
# Count of properties: 5365

# %%
listing_response.json()["data"]["cat1"]["searchResults"]['mapResults'][76]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipython-input-2627888083.py in <cell line: 0>()
# ----> 1 listing_response.json()["data"]["cat1"]["searchResults"]['mapResults'][76]
#
# IndexError: list index out of range

# %%
# view all listings
df_listings = pd.json_normalize(listing_response.json()["data"]["cat1"]["searchResults"]["mapResults"])
print("Number of rows:", len(df_listings))
print("Number of columns:", len(df_listings.columns))
df_listings.columns
# Out:
# Number of rows: 75
# Number of columns: 95
# Index(['zpid', 'palsId', 'rawHomeStatusCd', 'marketingStatusSimplifiedCd',
#        'imgSrc', 'hasImage', 'detailUrl', 'statusType', 'statusText', 'price',
#        'priceLabel', 'address', 'addressState', 'shouldShowRequestOnPrice',
#        'beds', 'baths', 'area', 'flexFieldText', 'contentType',
#        'isUserClaimingOwner', 'isUserConfirmedClaim', 'pgapt', 'sgapt',
#        'shouldShowZestimateAsPrice', 'has3DModel', 'hasVideo', 'isHomeRec',
#        'hasAdditionalAttributions', 'isFeaturedListing', 'isShowcaseListing',
#        'listingType', 'isFavorite', 'visited', 'brokerName', 'timeOnZillow',
#        'isPaidBuilderNewConstruction', 'latLong.latitude', 'latLong.longitude',
#        'hdpData.homeInfo.zpid', 'hdpData.homeInfo.streetAddress',
#        'hdpData.homeInfo.zipcode', 'hdpData.homeInfo.city',
#        'hdpData.homeInfo.state', 'hdpData.homeInfo.latitude',
#        'hdpData.homeInfo.longitude', 'hdpData.homeInfo.price',
#        'hdpData.homeInfo.bathrooms', 'hdpData.homeInfo.bedrooms',
#        'hdpData.homeInfo.livingArea', 'hdpData.homeInfo.homeType',
#        'hdpData.homeInfo.homeStatus', 'hdpData.homeInfo.daysOnZillow',
#        'hdpData.homeInfo.isFeatured', 'hdpData.homeInfo.shouldHighlight',
#        'hdpData.homeInfo.listing_sub_type.is_FSBA',
#        'hdpData.homeInfo.isUnmappable',
#        'hdpData.homeInfo.isPreforeclosureAuction',
#        'hdpData.homeInfo.homeStatusForHDP', 'hdpData.homeInfo.priceForHDP',
#        'hdpData.homeInfo.timeOnZillow', 'hdpData.homeInfo.isNonOwnerOccupied',
#        'hdpData.homeInfo.isPremierBuilder', 'hdpData.homeInfo.isZillowOwned',
#        'hdpData.homeInfo.currency', 'hdpData.homeInfo.country',
#        'hdpData.homeInfo.taxAssessedValue', 'hdpData.homeInfo.unit',
#        'hdpData.homeInfo.isShowcaseListing', 'hdpData.homeInfo.lotAreaValue',
#        'hdpData.homeInfo.lotAreaUnit', 'hdpData.homeInfo.datePriceChanged',
#        'hdpData.homeInfo.priceReduction', 'hdpData.homeInfo.priceChange',
#        'hdpData.homeInfo.listing_sub_type.is_openHouse',
#        'hdpData.homeInfo.openHouse',
#        'hdpData.homeInfo.open_house_info.open_house_showing',
#        'hdpData.homeInfo.zestimate', 'hdpData.homeInfo.rentZestimate',
#        'minBeds', 'minBaths', 'minArea', 'lotId', 'buildingId', 'isBuilding',
#        'canSaveBuilding', 'unitCount', 'listPriceIncludesRequiredMonthlyFees',
#        'lotAreaString', 'hdpData.homeInfo.isRentalWithBasePrice',
#        'hdpData.homeInfo.listing_sub_type.is_forAuction', 'streetViewURL',
#        'streetViewMetadataURL', 'hdpData.homeInfo.listing_sub_type.is_newHome',
#        'hdpData.homeInfo.newConstructionType',
#        'hdpData.homeInfo.listing_sub_type.is_bankOwned'],
#       dtype='object')

# %%
# view price
px.histogram(df_listings, x="hdpData.homeInfo.price", title="Sales Price Histogram")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="9c45d699-419b-4c5d-ae27-1047ecdf95b6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9c45d699-419b-4c5d-ae27-1047ecdf95b6")) {                    Plotly.newPlot(                        "9c45d699-419b-4c5d-ae27-1047ecdf95b6",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"hdpData.homeInfo.price=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":[475000.0,149900.0,500000.0,950000.0,429900.0,325000.0,270000.0,135000.0,550000.0,335000.0,497000.0,579900.0,995000.0,749900.0,299900.0,1699000.0,560000.0,1525000.0,700000.0,325000.0,335000.0,18500000.0,null,235000.0,715000.0,195000.0,260000.0,360000.0,820000.0,null,550000.0,575000.0,495000.0,38000.0,0.0,50000.0,30000.0,389900.0,474900.0,89900.0,535000.0,4995000.0,820000.0,45000.0,null,519000.0,999900.0,null,445000.0,null,325000.0,475000.0,519000.0,324900.0,695000.0,495000.0,779000.0,625000.0,235000.0,740000.0,274900.0,899999.0,585000.0,487000.0,230000.0,665000.0,314900.0,44000.0,45000.0,null,489900.0,279900.0,350000.0,null,390000.0],"xaxis":"x","yaxis":"y","type":"histogram"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":" ...

# %%
# view zestimate
px.histogram(df_listings, x="hdpData.homeInfo.zestimate", title="Zestimate Histogram")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="48a6b391-4d77-492c-9d34-df13e49f35cb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("48a6b391-4d77-492c-9d34-df13e49f35cb")) {                    Plotly.newPlot(                        "48a6b391-4d77-492c-9d34-df13e49f35cb",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"hdpData.homeInfo.zestimate=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":[null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,1668000.0,null,null,null,324800.0,333500.0,null,null,null,null,192500.0,null,null,null,null,null,null,null,null,null,null,null,null,null,null,527200.0,null,null,null,null,519700.0,null,null,439500.0,null,null,null,null,null,682600.0,null,763400.0,null,null,null,275300.0,null,582500.0,486100.0,231100.0,null,null,null,null,null,null,282000.0,null,null,null],"xaxis":"x","yaxis":"y","type":"histogram"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlin ...

# %%
# view rent zestimate
px.box(df_listings, x="hdpData.homeInfo.rentZestimate", title="Rent Zestimate Box Plot")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="d666c81d-1be4-4c67-a52d-442f521400fc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d666c81d-1be4-4c67-a52d-442f521400fc")) {                    Plotly.newPlot(                        "d666c81d-1be4-4c67-a52d-442f521400fc",                        [{"alignmentgroup":"True","hovertemplate":"hdpData.homeInfo.rentZestimate=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"h","showlegend":false,"x":[null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,2798.0,null,null,null,2284.0,3404.0,null,null,null,null,1694.0,null,null,null,null,null,null,null,null,1266.0,null,null,null,null,null,7063.0,null,null,null,null,null,null,null,2044.0,null,null,null,null,null,4086.0,null,5344.0,null,null,null,2022.0,null,null,3615.0,1848.0,null,null,null,null,null,null,2435.0,null,null,null],"x0":" ","xaxis":"x","y0":" ","yaxis":"y","type":"box"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpo ...

# %% [markdown]
# ### <font color="green">2. Rental Property Listings For Rent</font>

# %%
# zillow search url
rent_listing_url = "https://www.zillow.com/tampa-fl/rentals/?searchQueryState=%7B%22pagination%22%3A%7B%7D%2C%22usersSearchTerm%22%3A%22Tampa%2C%20FL%22%2C%22mapBounds%22%3A%7B%22west%22%3A-82.69632304150392%2C%22east%22%3A-82.2122379584961%2C%22south%22%3A27.743327003864252%2C%22north%22%3A28.2453440906427%7D%2C%22regionSelection%22%3A%5B%7B%22regionId%22%3A41176%2C%22regionType%22%3A6%7D%5D%2C%22isMapVisible%22%3Atrue%2C%22filterState%22%3A%7B%22sort%22%3A%7B%22value%22%3A%22priorityscore%22%7D%2C%22fsba%22%3A%7B%22value%22%3Afalse%7D%2C%22fsbo%22%3A%7B%22value%22%3Afalse%7D%2C%22nc%22%3A%7B%22value%22%3Afalse%7D%2C%22cmsn%22%3A%7B%22value%22%3Afalse%7D%2C%22auc%22%3A%7B%22value%22%3Afalse%7D%2C%22fore%22%3A%7B%22value%22%3Afalse%7D%2C%22pmf%22%3A%7B%22value%22%3Afalse%7D%2C%22pf%22%3A%7B%22value%22%3Afalse%7D%2C%22fr%22%3A%7B%22value%22%3Atrue%7D%2C%22beds%22%3A%7B%22min%22%3A3%2C%22max%22%3A3%7D%2C%22baths%22%3A%7B%22min%22%3A2%7D%2C%22apco%22%3A%7B%22value%22%3Afalse%7D%2C%22apa%22%3A%7B%22value%22%3Afalse%7D%2C%22con%22%3A%7B%22value%22%3Afalse%7D%2C%22tow%22%3A%7B%22value%22%3Afalse%7D%7D%2C%22isListVisible%22%3Atrue%2C%22mapZoom%22%3A11%7D"

# get listings
rent_listing_response = get_listings(api_key, rent_listing_url)

# %%
# view all keys
print(rent_listing_response.json().keys())

# check if request is successful
print("Request success:", rent_listing_response.json()["is_success"])

# view count of properies returned in request
num_of_properties = rent_listing_response.json()["data"]["categoryTotals"]["cat1"]["totalResultCount"]
print("Count of properties:", num_of_properties)
# Out:
# dict_keys(['is_success', 'data', 'message', 'info'])
# Request success: True
# Count of properties: 399

# %%
# view all listings
df_rent_listings = pd.json_normalize(rent_listing_response.json()["data"]["cat1"]["searchResults"]["mapResults"])
print("Number of rows:", len(df_rent_listings))
print("Number of columns:", len(df_rent_listings.columns))
df_rent_listings
# Out:
# Number of rows: 75
# Number of columns: 81
#           zpid                                             palsId  \
# 0     45100344  100066001_9557829aeb2ea8c7c2a66616113f287d3eb3...
# 1     45102953  100066001_ad40befc54e4a8f1b81b4122cef96420847b...
# 2     45056651  100066001_b655c53aef5f614f2b2d7fd2401bcbf6bd77...
# 3     44860141  100066001_36e58e804d5dce638daee02027d09cd91b7b...
# 4     45111954  100066001_afc4b264f7579a2dcdc323f3c9e2f2a0c662...
# ..         ...                                                ...
# 70    44933684  100066001_ba40ca3239c5199b3b79a4d8b7bb497b993f...
# 71    45104650  100066001_da740ea16539585233c8ff5c25148db6c2c0...
# 72    44869515  100066001_d066e5410b623788eb90139b0b6c652ea51c...
# 73  2060822423  100066001_729dc2da8b6b58ddb75976a877f537572e7c...
# 74    58433223  100066001_56c70f25c081e0af8388783868b683cda1eb...
#
#    rawHomeStatusCd marketingStatusSimplifiedCd  \
# 0          ForRent                    For Rent
# 1          ForRent                    For Rent
# 2          ForRent                    For Rent
# 3          ForRent                    For Rent
# 4          ForRent                    For Rent
# ..             ...                         ...
# 70         ForRent                    For Rent
# 71         ForRent                    For Rent
# 72         ForRent                    For Rent
# 73         ForRent                    For Rent
# 74         ForRent                    For Rent
#
#                                                imgSrc  hasImage  \
# 0   https://photos.zillowstatic.com/fp/75036ef4123...      True
# 1   https://photos.zillowstatic.com/fp/632a6fce324...      True
# 2   https://photos.zillowstatic.com/fp/c0d4be21d75...      True
# 3   https://photos.zillowstatic.com/fp/d3cd951afa1...      True
# 4   https://photos.zillowstatic.com/fp/43500018024...      True
# ..                                                ...       ...
# 70  https://photos.zillowstatic.com/fp/f7ed579cf0c...      True
# 71  https://photos.zillowstatic.com/fp/a4af4f30a9a...      True
# 72  https://photos.zillowstatic.com/fp/ae4e8a6b7ff...      True
# 73  https://photos.zillowstatic.com/fp/678225e7984...      True
# 74  https://photos.zillowstatic.com/fp/6b61b94d886...      True
#
#                                             detailUrl statusType  \
# 0   /homedetails/2510-E-28th-Ave-Tampa-FL-33605/45...   FOR_RENT
# 1   /homedetails/1321-W-Nassau-St-Tampa-FL-33607/4...   FOR_RENT
# 2   /homedetails/4012-W-San-Juan-St-Tampa-FL-33629...   FOR_RENT
# 3   /homedetails/8709-Huntfield-St-Tampa-FL-33635/...   FOR_RENT
# 4   /homedetails/501-Columbia-Dr-Tampa-FL-33606/45...   FOR_RENT
# ..                                                ...        ...
# 70  /homedetails/5614-Kenny-Dr-Tampa-FL-33617/4493...   FOR_RENT
# 71  /homedetails/2509-W-Grace-St-Tampa-FL-33607/45...   FOR_RENT
# 72  /homedetails/6529-Seafairer-Dr-Tampa-FL-33615/...   FOR_RENT
# 73  /homedetails/10214-N-Blvd-Tampa-FL-33612/20608...   FOR_RENT
# 74  /homedetails/5817-Mohr-Loop-Tampa-FL-33615/584...   FOR_RENT
#
#         statusText      price priceLabel                              address  \
# 0   House for rent  $1,950/mo      $2.0K     2510 E 28th Ave, Tampa, FL 33605
# 1   House for rent  $3,000/mo      $3.0K    1321 W Nassau St, Tampa, FL 33607
# 2   House for rent  $3,900/mo      $3.9K  4012 W San Juan St, Tampa, FL 33629
# 3   House for rent  $3,025/mo      $3.0K   8709 Huntfield St, Tampa, FL 33635
# 4   House for rent  $7,000/mo      $7.0K     501 Columbia Dr, Tampa, FL 33606
# ..             ...        ...        ...                                  ...
# 70  House for rent  $2,700/mo      $2.7K       5614 Kenny Dr, Tampa, FL 33617
# 71  House for rent  $2,750/mo      $2.8K     2509 W Grace St, Tampa, FL 33607
# 72  House for rent  $2,649/mo      $2.6K   6529 Seafairer Dr, Tampa, FL 33615
# 73  House for rent  $2,010/mo      $2.0K        10214 N Blvd, Tampa, FL 33612
# 74  House for rent  $2,490/mo      $2.5K      5817 Mohr Loop, Tampa, FL 33615
#
#    addressState  shouldShowRequestOnPrice  beds  baths  area  \
# 0            FL                     False     3    2.0  1250
# 1            FL                     False     3    2.0  1276
# 2            FL                     False     3    2.0  1200
# 3            FL                     False     3    2.0  1588
# 4            FL                     False     3    3.0  1890
# ..          ...                       ...   ...    ...   ...
# 70           FL                     False     3    2.0  2101
# 71           FL                     False     3    2.0  1444
# 72           FL                     False     3    2.0  1718
# 73           FL                     False     3    2.0  1132
# 74           FL                     False     3    2.0  1530
#
#     isUserClaimingOwner  isUserConfirmedClaim    pgapt     sgapt  \
# 0                 False                 False  ForRent  For Rent
# 1                 False                 False  ForRent  For Rent
# 2                 False                 False  ForRent  For Rent
# 3                 False                 False  ForRent  For Rent
# 4                 False                 False  ForRent  For Rent
# ..                  ...                   ...      ...       ...
# 70                False                 False  ForRent  For Rent
# 71                False                 False  ForRent  For Rent
# 72                False                 False  ForRent  For Rent
# 73                False                 False  ForRent  For Rent
# 74                False                 False  ForRent  For Rent
#
#     shouldShowZestimateAsPrice  has3DModel  hasVideo  isHomeRec  \
# 0                        False       False     False      False
# 1                        False       False     False      False
# 2                        False       False     False      False
# 3                        False       False     False      False
# 4                        False       False     False      False
# ..                         ...         ...       ...        ...
# 70                       False       False     False      False
# 71                       False       False     False      False
# 72                       False       False     False      False
# 73                       False        True     False      False
# 74                       False        True     False      False
#
#     hasAdditionalAttributions  isFeaturedListing  isShowcaseListing  \
# 0                       False               True              False
# 1                       False               True              False
# 2                       False               True              False
# 3                       False               True              False
# 4                       False               True              False
# ..                        ...                ...                ...
# 70                      False               True              False
# 71                      False               True              False
# 72                      False               True              False
# 73                      False               True              False
# 74                      False               True              False
#
#    listingType  isFavorite     availabilityDate  visited  timeOnZillow  \
# 0                    False  2025-12-04 00:00:00    False     367504000
# 1                    False  2025-12-05 00:00:00    False     266324000
# 2                    False  2026-02-01 00:00:00    False     298928000
# 3                    False  2025-12-01 00:00:00    False    2717757000
# 4                    False  2025-12-15 00:00:00    False     619179000
# ..         ...         ...                  ...      ...           ...
# 70                   False                  NaN    False    2981645000
# 71                   False  2025-11-20 00:00:00    False    2996176000
# 72                   False                  NaN    False     410430000
# 73                   False  2025-12-16 00:00:00    False    2506966000
# 74                   False  2025-11-13 00:00:00    False    2447674000
#
#    rentalMarketingSubType                                marketingTreatments  \
# 0                 unknown                        [paid, zillowRentalManager]
# 1                 unknown                        [paid, zillowRentalManager]
# 2                 unknown                        [paid, zillowRentalManager]
# 3                 unknown                        [paid, zillowRentalManager]
# 4                 unknown                        [paid, zillowRentalManager]
# ..                    ...                                                ...
# 70                unknown                        [paid, zillowRentalManager]
# 71                unknown  [trustedListing, paid, singleFamilyPaid, feedC...
# 72                unknown  [trustedListing, paid, singleFamilyPaid, feedC...
# 73                unknown  [trustedListing, paid, singleFamilyPaid, feedC...
# 74                unknown  [trustedListing, paid, singleFamilyPaid, feedC...
#
#     isPaidBuilderNewConstruction  latLong.latitude  latLong.longitude  \
# 0                          False         27.976164         -82.430916
# 1                          False         27.953663         -82.474236
# 2                          False         27.918220         -82.511180
# 3                          False         28.035177         -82.599470
# 4                          False         27.923702         -82.450460
# ..                           ...               ...                ...
# 70                         False         28.016527         -82.391190
# 71                         False         27.953047         -82.485954
# 72                         False         28.010508         -82.605880
# 73                         False         28.042260         -82.467810
# 74                         False         28.003020         -82.586380
#
#       listCardRecommendation.flexFieldRecommendations  hdpData.homeInfo.zpid  \
# 0   [{'displayString': '4 days ago', 'contentType'...               45100344
# 1   [{'displayString': '3 days ago', 'contentType'...               45102953
# 2   [{'displayString': '3 days ago', 'contentType'...               45056651
# 3   [{'displayString': 'Apply instantly', 'content...               44860141
# 4   [{'displayString': '7 days ago', 'contentType'...               45111954
# ..                                                ...                    ...
# 70                                                NaN               44933684
# 71                                                NaN               45104650
# 72  [{'displayString': '4 days ago', 'contentType'...               44869515
# 73  [{'displayString': '3D Tour', 'contentType': '...             2060822423
# 74  [{'displayString': '3D Tour', 'contentType': '...               58433223
#
#    hdpData.homeInfo.streetAddress hdpData.homeInfo.zipcode  \
# 0                 2510 E 28th Ave                    33605
# 1                1321 W Nassau St                    33607
# 2              4012 W San Juan St                    33629
# 3               8709 Huntfield St                    33635
# 4                 501 Columbia Dr                    33606
# ..                            ...                      ...
# 70                  5614 Kenny Dr                    33617
# 71                2509 W Grace St                    33607
# 72              6529 Seafairer Dr                    33615
# 73                   10214 N Blvd                    33612
# 74                 5817 Mohr Loop                    33615
#
#    hdpData.homeInfo.city hdpData.homeInfo.state  hdpData.homeInfo.latitude  \
# 0                  Tampa                     FL                  27.976164
# 1                  Tampa                     FL                  27.953663
# 2                  Tampa                     FL                  27.918220
# 3                  Tampa                     FL                  28.035177
# 4                  Tampa                     FL                  27.923702
# ..                   ...                    ...                        ...
# 70                 Tampa                     FL                  28.016527
# 71                 Tampa                     FL                  27.953047
# 72                 Tampa                     FL                  28.010508
# 73                 Tampa                     FL                  28.042260
# 74                 Tampa                     FL                  28.003020
#
#     hdpData.homeInfo.longitude  hdpData.homeInfo.price  \
# 0                   -82.430916                  1950.0
# 1                   -82.474236                  3000.0
# 2                   -82.511180                  3900.0
# 3                   -82.599470                  3025.0
# 4                   -82.450460                  7000.0
# ..                         ...                     ...
# 70                  -82.391190                  2700.0
# 71                  -82.485954                  2750.0
# 72                  -82.605880                  2649.0
# 73                  -82.467810                  2010.0
# 74                  -82.586380                  2490.0
#
#     hdpData.homeInfo.bathrooms  hdpData.homeInfo.bedrooms  \
# 0                          2.0                        3.0
# 1                          2.0                        3.0
# 2                          2.0                        3.0
# 3                          2.0                        3.0
# 4                          3.0                        3.0
# ..                         ...                        ...
# 70                         2.0                        3.0
# 71                         2.0                        3.0
# 72                         2.0                        3.0
# 73                         2.0                        3.0
# 74                         2.0                        3.0
#
#     hdpData.homeInfo.livingArea hdpData.homeInfo.homeType  \
# 0                        1250.0             SINGLE_FAMILY
# 1                        1276.0             SINGLE_FAMILY
# 2                        1200.0             SINGLE_FAMILY
# 3                        1588.0             SINGLE_FAMILY
# 4                        1890.0             SINGLE_FAMILY
# ..                          ...                       ...
# 70                       2101.0             SINGLE_FAMILY
# 71                       1444.0             SINGLE_FAMILY
# 72                       1718.0             SINGLE_FAMILY
# 73                       1132.0             SINGLE_FAMILY
# 74                       1530.0             SINGLE_FAMILY
#
#    hdpData.homeInfo.homeStatus  hdpData.homeInfo.daysOnZillow  \
# 0                     FOR_RENT                              4
# 1                     FOR_RENT                              3
# 2                     FOR_RENT                              3
# 3                     FOR_RENT                             31
# 4                     FOR_RENT                              7
# ..                         ...                            ...
# 70                    FOR_RENT                             34
# 71                    FOR_RENT                             34
# 72                    FOR_RENT                              4
# 73                    FOR_RENT                             29
# 74                    FOR_RENT                             28
#
#     hdpData.homeInfo.isFeatured  hdpData.homeInfo.shouldHighlight  \
# 0                          True                             False
# 1                          True                             False
# 2                          True                             False
# 3                          True                             False
# 4                          True                             False
# ..                          ...                               ...
# 70                         True                             False
# 71                         True                             False
# 72                         True                             False
# 73                         True                             False
# 74                         True                             False
#
#     hdpData.homeInfo.isRentalWithBasePrice  hdpData.homeInfo.zestimate  \
# 0                                    False                    270500.0
# 1                                    False                    495800.0
# 2                                    False                    570600.0
# 3                                    False                    345400.0
# 4                                    False                   1193300.0
# ..                                     ...                         ...
# 70                                   False                    509700.0
# 71                                   False                    453900.0
# 72                                   False                    405300.0
# 73                                   False                    313600.0
# 74                                   False                    354400.0
#
#     hdpData.homeInfo.rentZestimate  hdpData.homeInfo.isUnmappable  \
# 0                             2044                          False
# 1                             2489                          False
# 2                             2509                          False
# 3                             2641                          False
# 4                             6699                          False
# ..                             ...                            ...
# 70                            2948                          False
# 71                            2984                          False
# 72                            2110                          False
# 73                            2304                          False
# 74                            2481                          False
#
#     hdpData.homeInfo.isPreforeclosureAuction  \
# 0                                      False
# 1                                      False
# 2                                      False
# 3                                      False
# 4                                      False
# ..                                       ...
# 70                                     False
# 71                                     False
# 72                                     False
# 73                                     False
# 74                                     False
#
#    hdpData.homeInfo.homeStatusForHDP  hdpData.homeInfo.priceForHDP  \
# 0                           FOR_RENT                        1950.0
# 1                           FOR_RENT                        3000.0
# 2                           FOR_RENT                        3900.0
# 3                           FOR_RENT                        3025.0
# 4                           FOR_RENT                        7000.0
# ..                               ...                           ...
# 70                          FOR_RENT                        2700.0
# 71                          FOR_RENT                        2750.0
# 72                          FOR_RENT                        2649.0
# 73                          FOR_RENT                        2010.0
# 74                          FOR_RENT                        2490.0
#
#     hdpData.homeInfo.timeOnZillow  hdpData.homeInfo.isNonOwnerOccupied  \
# 0                       367504000                                 True
# 1                       266324000                                 True
# 2                       298928000                                 True
# 3                      2717757000                                 True
# 4                       619179000                                 True
# ..                            ...                                  ...
# 70                     2981645000                                 True
# 71                     2996176000                                 True
# 72                      410430000                                 True
# 73                     2506966000                                 True
# 74                     2447674000                                 True
#
#     hdpData.homeInfo.isPremierBuilder  hdpData.homeInfo.isZillowOwned  \
# 0                               False                           False
# 1                               False                           False
# 2                               False                           False
# 3                               False                           False
# 4                               False                           False
# ..                                ...                             ...
# 70                              False                           False
# 71                              False                           False
# 72                              False                           False
# 73                              False                           False
# 74                              False                           False
#
#    hdpData.homeInfo.currency hdpData.homeInfo.country  \
# 0                        USD                      USA
# 1                        USD                      USA
# 2                        USD                      USA
# 3                        USD                      USA
# 4                        USD                      USA
# ..                       ...                      ...
# 70                       USD                      USA
# 71                       USD                      USA
# 72                       USD                      USA
# 73                       USD                      USA
# 74                       USD                      USA
#
#     hdpData.homeInfo.taxAssessedValue  hdpData.homeInfo.isShowcaseListing  \
# 0                            210810.0                               False
# 1                            372569.0                               False
# 2                            379041.0                               False
# 3                            347679.0                               False
# 4                            740281.0                               False
# ..                                ...                                 ...
# 70                           288845.0                               False
# 71                           393594.0                               False
# 72                           326551.0                               False
# 73                                NaN                               False
# 74                           293142.0                               False
#
#     factsAndFeatures.fullBathroomCount  factsAndFeatures.hasFireplace  \
# 0                                    2                          False
# 1                                    2                          False
# 2                                    2                          False
# 3                                    2                          False
# 4                                    2                          False
# ..                                 ...                            ...
# 70                                   2                          False
# 71                                   2                          False
# 72                                   2                          False
# 73                                   2                          False
# 74                                   2                          False
#
#     factsAndFeatures.hasAirConditioning  factsAndFeatures.hasSpa  \
# 0                                 False                    False
# 1                                 False                    False
# 2                                 False                    False
# 3                                 False                    False
# 4                                 False                    False
# ..                                  ...                      ...
# 70                                False                    False
# 71                                False                    False
# 72                                False                    False
# 73                                False                    False
# 74                                False                    False
#
#     factsAndFeatures.hasPool  factsAndFeatures.halfBathroomCount  \
# 0                      False                                 NaN
# 1                      False                                 NaN
# 2                      False                                 NaN
# 3                      False                                 NaN
# 4                      False                                 1.0
# ..                       ...                                 ...
# 70                     False                                 NaN
# 71                     False                                 0.0
# 72                     False                                 0.0
# 73                     False                                 0.0
# 74                     False                                 0.0
#
#     hdpData.homeInfo.datePriceChanged hdpData.homeInfo.priceReduction  \
# 0                                 NaN                             NaN
# 1                                 NaN                             NaN
# 2                                 NaN                             NaN
# 3                                 NaN                             NaN
# 4                                 NaN                             NaN
# ..                                ...                             ...
# 70                                NaN                             NaN
# 71                       1.763194e+12                    $15 (Nov 15)
# 72                       1.764922e+12                     $46 (Dec 5)
# 73                       1.764576e+12                     $50 (Dec 1)
# 74                       1.764058e+12                    $40 (Nov 25)
#
#     hdpData.homeInfo.priceChange  hdpData.homeInfo.lotAreaValue  \
# 0                            NaN                            NaN
# 1                            NaN                            NaN
# 2                            NaN                            NaN
# 3                            NaN                            NaN
# 4                            NaN                            NaN
# ..                           ...                            ...
# 70                           NaN                            NaN
# 71                         -15.0                        4748.04
# 72                         -46.0                            NaN
# 73                         -50.0                            NaN
# 74                         -40.0                            NaN
#
#    hdpData.homeInfo.lotAreaUnit
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
# ..                          ...
# 70                          NaN
# 71                         sqft
# 72                          NaN
# 73                          NaN
# 74                          NaN
#
# [75 rows x 81 columns]

# %%
# view price
px.box(df_rent_listings, x="hdpData.homeInfo.price", title="Rental Price Box Plot")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="088a47aa-686a-43f6-a79b-2e842d31a701" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("088a47aa-686a-43f6-a79b-2e842d31a701")) {                    Plotly.newPlot(                        "088a47aa-686a-43f6-a79b-2e842d31a701",                        [{"alignmentgroup":"True","hovertemplate":"hdpData.homeInfo.price=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"h","showlegend":false,"x":[1950.0,3000.0,3900.0,3025.0,7000.0,2400.0,2300.0,2995.0,2500.0,2400.0,2495.0,4000.0,4200.0,2795.0,2500.0,3645.0,2549.0,4500.0,2800.0,2889.0,1745.0,2050.0,3250.0,2875.0,2450.0,3800.0,2850.0,1850.0,1999.0,2067.0,5750.0,2249.0,2449.0,2295.0,8500.0,2650.0,2195.0,2620.0,2300.0,2450.0,2499.0,2150.0,2530.0,3100.0,2200.0,5200.0,4750.0,2749.0,2249.0,1780.0,2315.0,2800.0,2500.0,2195.0,3300.0,1795.0,2405.0,2204.0,2700.0,2245.0,1945.0,2165.0,2595.0,2895.0,2100.0,2055.0,2249.0,2046.0,2560.0,2229.0,2700.0,2750.0,2649.0,2010.0,2490.0],"x0":" ","xaxis":"x","y0":" ","yaxis":"y","type":"box"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parc ...

# %%
# view rent zestimate
px.box(df_rent_listings, x="hdpData.homeInfo.rentZestimate", title="Rent Zestimate Box Plot")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="8056765c-4d4d-40ef-b77e-6d939b2826e2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8056765c-4d4d-40ef-b77e-6d939b2826e2")) {                    Plotly.newPlot(                        "8056765c-4d4d-40ef-b77e-6d939b2826e2",                        [{"alignmentgroup":"True","hovertemplate":"hdpData.homeInfo.rentZestimate=%{x}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"h","showlegend":false,"x":[10311.0,2499.0,1999.0,2999.0,2300.0,1999.0,2314.0,2400.0,1951.0,2210.0,3298.0,2019.0,2109.0,2300.0,2157.0,1995.0,2167.0,2499.0,2534.0,2400.0,2053.0,2864.0,1999.0,2996.0,2298.0,2662.0,1732.0,6610.0,1980.0,2440.0,2894.0,3940.0,2813.0,3399.0,3354.0,2499.0,2981.0,2558.0,3149.0,2999.0,2456.0,4128.0,2400.0,2250.0,2885.0,2385.0,2499.0,1999.0,1999.0,3681.0,1581.0,2434.0,1800.0,2121.0,2125.0,2999.0,2570.0,2799.0,2799.0,1950.0,null,1963.0,null,null,1949.0,2334.0,2749.0,2100.0,1462.0,8529.0,1800.0,3187.0,2969.0,2834.0,2199.0,1965.0,2400.0,2914.0,2475.0,2287.0,2141.0,3829.0,2565.0,2860.0,2606.0,2995.0,2128.0,10110.0,2811.0,2527.0,2499.0,4273.0,2129.0,1995.0,null,2578.0,null,2600.0,2199.0,2594.0,1841.0,3884.0,null,3951.0,2400.0,3284.0,2755.0,2996.0,4522.0,3373.0,2546.0,3499.0,2055.0,4439.0,2456.0,3056.0,2446.0,2806.0,4396.0,3417.0,3499.0,null,1997.0,null,2962.0,2197.0,8180.0,3184.0,2199.0,2163.0,11327.0,3832.0,4780.0,null,2425.0,3905.0,null,null,null,2279.0,1999.0,2499.0,3175.0,7367.0,null,2851.0,2499.0,null,1995.0,null,2870.0,null,null,2466.0,2652.0,2499.0,3379.0,null,null,2813.0,2281.0,null,1999.0,null,null,7579.0,2300.0,2297.0,3164.0,2920.0,2228.0,2047.0,3426.0,null,null,3650.0,2437.0,null,2058.0,null,2499.0],"x0":" ","xaxis":"x","y0":" ","yaxis":"y","type":"box"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{" ...

# %% [markdown]
# ### <font color="green">3. Property Details</font>

# %%
# property unique id
zpid = "99616959"

# get property detail
prop_detail_response = get_property_detail(api_key, zpid)

# %%
# view all keys
print(prop_detail_response.json().keys())

# check if request is successful
print("Request success:", prop_detail_response.json()["is_success"])
# Out:
# dict_keys(['is_success', 'data', 'message'])
# Request success: True

# %%
# view property details
df_prop = pd.json_normalize(prop_detail_response.json()['data'])
print("Number of rows:", len(df_prop))
print("Number of columns:", len(df_prop.columns))
df_prop
# Out:
# Number of rows: 1
# Number of columns: 602
#   listingDataSource      zpid   city state homeStatus  \
# 0           Phoenix  99616959  Tampa    FL   FOR_SALE
#
#    isListingClaimedByCurrentSignedInUser  isCurrentSignedInAgentResponsible  \
# 0                                  False                              False
#
#    bedrooms  bathrooms   price  yearBuilt   streetAddress zipcode  \
# 0         3          2  350000       2020  3611 Potter St   33605
#
#    isCurrentSignedInUserVerifiedOwner    regionString propertyUpdatePageLink  \
# 0                               False  Tampa FL 33605                   None
#
#   moveHomeMapLocationLink propertyEventLogLink editPropertyHistorylink  \
# 0                    None                 None                    None
#
#    isRentalListingOffMarket  \
# 0                      True
#
#                                               hdpUrl  \
# 0  /homedetails/3611-Potter-St-Tampa-FL-33605/996...
#
#                                         nearbyCities  \
# 0  [{'regionUrl': {'path': '/brandon-fl/'}, 'name...
#
#                                  nearbyNeighborhoods country  \
# 0  [{'regionUrl': {'path': '/east-tampa-tampa-fl/...     USA
#
#                                       nearbyZipcodes abbreviatedAddress  \
# 0  [{'regionUrl': {'path': '/tampa-fl-33604/'}, '...     3611 Potter St
#
#   building  isUndisclosedAddress boroughId providerListingID boroughSearchUrl  \
# 0     None                 False      None              None             None
#
#   communityUrl  isPremierBuilder  isZillowOwned       homeType currency  \
# 0         None             False          False  SINGLE_FAMILY      USD
#
#   listPriceLow  livingArea  livingAreaValue  zestimate newConstructionType  \
# 0         None        1630             1630     339553                None
#
#   zestimateLowPercent zestimateHighPercent  rentZestimate restimateLowPercent  \
# 0                   5                    5           2414                None
#
#   restimateHighPercent                                            schools  \
# 0                 None  [{'distance': 0.9, 'name': 'Potter Elementary ...
#
#   homeValues                                        nearbyHomes countyFIPS  \
# 0       None  [{'zpid': 45100276, 'miniCardPhotos': [{'url':...      12057
#
#                  parcelId                                         taxHistory  \
# 0  1929084NE000000000080A  [{'time': 1614257548865, 'taxPaid': 700.43, 't...
#
#                                         priceHistory  \
# 0  [{'date': '2023-02-04', 'time': 1675468800000,...
#
#                                                comps  \
# 0  [{'zpid': 45108843, 'miniCardPhotos': [{'url':...
#
#                                          description whatILove  \
# 0  WOW! What an amazing NEW BUILD with 3 bedrooms...      None
#
#   contingentListingType timeOnZillow  pageViewCount  favoriteCount  \
# 0                  None      28 days          22035           1218
#
#    daysOnZillow   latitude  longitude openHouseSchedule  \
# 0            28  27.976728 -82.432884                []
#
#                               desktopWebHdpImageLink  \
# 0  https://photos.zillowstatic.com/fp/ab2d93a3f55...
#
#                  brokerageName          timeZone pals  \
# 0  Keller Williams Tampa Prop.  America/New_York   []
#
#       listingAccountUserId                                       homeInsights  \
# 0  X1-ZUyq3nn6z9glc9_40okc  [{'insights': [{'modelId': 'v2-2', 'treatmentI...
#
#                                         sellingSoon listingProvider  \
# 0  [{'treatmentId': 'model_0', 'percentile': 0.81}]            None
#
#   isIncomeRestricted brokerId  ssid monthlyHoaFee  propertyTaxRate  \
# 0               None     None    24          None             1.06
#
#                                       hiResImageLink hdpTypeDimension  \
# 0  https://photos.zillowstatic.com/fp/ab2d93a3f55...          ForSale
#
#       mlsid propertyTypeDimension  \
# 0  T3424788         Single Family
#
#                                      mediumImageLink  \
# 0  https://photos.zillowstatic.com/fp/ab2d93a3f55...
#
#                               enhancedBrokerImageUrl  \
# 0  https://photos.zillowstatic.com/fp/e39375731b4...
#
#                                     responsivePhotos buildingId  \
# 0  [{'mixedSources': {'jpeg': [{'url': 'https://p...       None
#
#                                       virtualTourUrl  \
# 0  https://www.propertypanorama.com/instaview/ste...
#
#    hasApprovedThirdPartyVirtualTourUrl  photoCount livingAreaUnits  lotSize  \
# 0                                 True          50     Square Feet     5076
#
#    lotAreaValue lotAreaUnits postingProductType marketingName richMedia  \
# 0          5076  Square Feet           Standard          None      None
#
#    cityId  stateId zipPlusFour numberOfUnitsTotal  \
# 0   41176       14        1367               None
#
#   foreclosureDefaultFilingDate foreclosureAuctionFilingDate  \
# 0                         None                         None
#
#   foreclosureLoanDate foreclosureLoanOriginator foreclosureLoanAmount  \
# 0                None                      None                  None
#
#   foreclosurePriorSaleDate foreclosurePriorSaleAmount  \
# 0                     None                       None
#
#   foreclosureBalanceReportingDate foreclosurePastDueBalance  \
# 0                            None                      None
#
#   foreclosureUnpaidBalance foreclosureAuctionTime  \
# 0                     None                   None
#
#   foreclosureAuctionDescription foreclosureAuctionCity  \
# 0                          None                   None
#
#   foreclosureAuctionLocation foreclosureDate foreclosureAmount  \
# 0                       None            None              None
#
#   foreclosingBank foreclosureJudicialType datePostedString  \
# 0            None                Judicial       2023-01-27
#
#   foreclosureMoreInfo  hasBadGeocode  \
# 0                None          False
#
#                streetViewMetadataUrlMediaWallLatLong  \
# 0  https://maps.googleapis.com/maps/api/streetvie...
#
#                streetViewMetadataUrlMediaWallAddress  \
# 0  https://maps.googleapis.com/maps/api/streetvie...
#
#                  streetViewTileImageUrlMediumLatLong  \
# 0  https://maps.googleapis.com/maps/api/streetvie...
#
#                  streetViewTileImageUrlMediumAddress  \
# 0  https://maps.googleapis.com/maps/api/streetvie...
#
#                                 streetViewServiceUrl postingUrl  \
# 0  https://proxy.zillowapi.com/street-view-url?zp...       None
#
#    hasPublicVideo primaryPublicVideo richMediaVideos  \
# 0           False               None            None
#
#                                               photos  tourViewCount  \
# 0  [{'caption': '', 'mixedSources': {'jpeg': [{'u...              0
#
#   listingAccount listingFeedID livingAreaUnitsShort  priceChange  \
# 0           None          None                 sqft       -15000
#
#    priceChangeDate priceChangeDateString  hideZestimate  \
# 0    1675468800000            2023-02-04          False
#
#   comingSoonOnMarketDate  isPreforeclosureAuction  lastSoldPrice  \
# 0                   None                    False         263850
#
#    isHousingConnector                      responsivePhotosOriginalRatio  \
# 0               False  [{'caption': '', 'mixedSources': {'jpeg': [{'u...
#
#              streetViewMetadataUrlMapLightboxAddress  \
# 0  https://maps.googleapis.com/maps/api/streetvie...
#
#                                                thumb  isRecentStatusChange  \
# 0  [{'url': 'https://photos.zillowstatic.com/fp/a...                 False
#
#    isNonOwnerOccupied               county  isFeatured  \
# 0               False  Hillsborough County       False
#
#   rentalApplicationsAcceptedType listingTypeDimension  \
# 0               REQUEST_TO_APPLY    For Sale by Agent
#
#   featuredListingTypeDimension  brokerIdDimension keystoneHomeStatus  \
# 0                      organic  For Sale by Agent            ForSale
#
#   pageUrlFragment  isRentalsLeadCapMet  isPaidMultiFamilyBrokerId  \
# 0         ForSale                False                      False
#
#   address.streetAddress address.city address.state address.zipcode  \
# 0        3611 Potter St        Tampa            FL           33605
#
#   address.neighborhood address.community address.subdivision  \
# 0                 None              None                None
#
#    listing_sub_type.is_newHome  listing_sub_type.is_FSBO  \
# 0                        False                     False
#
#    listing_sub_type.is_FSBA  listing_sub_type.is_foreclosure  \
# 0                      True                            False
#
#    listing_sub_type.is_bankOwned  listing_sub_type.is_forAuction  \
# 0                          False                           False
#
#    listing_sub_type.is_comingSoon  listing_sub_type.is_pending  \
# 0                           False                        False
#
#    listing_sub_type.is_openHouse citySearchUrl.text citySearchUrl.path  \
# 0                          False     Homes in Tampa         /tampa-fl/
#
#   zipcodeSearchUrl.path apartmentsForRentInZipcodeSearchUrl.path  \
# 0      /tampa-fl-33605/              /tampa-fl-33605/apartments/
#
#   housesForRentInZipcodeSearchUrl.path neighborhoodRegion.name  \
# 0         /tampa-fl-33605/rent-houses/            College Hill
#
#   neighborhoodSearchUrl.path stateSearchUrl.path  \
# 0    /college-hill-tampa-fl/                /fl/
#
#            countySearchUrl.text      countySearchUrl.path adTargets.aamgnrc1  \
# 0  Homes in Hillsborough County  /hillsborough-county-fl/     3611 Potter St
#
#   adTargets.bd adTargets.fsbid adTargets.city adTargets.proptp adTargets.pid  \
# 0            3              24          Tampa              sfh      99616959
#
#   adTargets.lot adTargets.zestibuck adTargets.listtp adTargets.sqftrange  \
# 0             1            300-349k        buy_agent           1500-1999
#
#   adTargets.price adTargets.sqft adTargets.state adTargets.mlong  \
# 0          350000           1630              FL      -82.432884
#
#   adTargets.cnty adTargets.prange adTargets.zip adTargets.mlat adTargets.zusr  \
# 0   Hillsborough         350-399k         33605      27.976728           true
#
#   adTargets.price_band adTargets.yrblt adTargets.zestimate  \
# 0                 z300       2020-2029              339553
#
#   adTargets.premieragent adTargets.dma                        adTargets.guid  \
# 0                     no            54  2d0bab85-bb9e-4cea-83fc-58f3dd628fda
#
#   adTargets.ssid resoFacts.accessibilityFeatures resoFacts.additionalFeeInfo  \
# 0             24                            None                        None
#
#   resoFacts.associationFee resoFacts.associationAmenities  \
# 0                     None                           None
#
#   resoFacts.associationFee2 resoFacts.associationFeeIncludes  \
# 0                      None                             None
#
#   resoFacts.associationName resoFacts.associationName2  \
# 0                      None                       None
#
#   resoFacts.associationPhone resoFacts.associationPhone2  \
# 0                       None                        None
#
#    resoFacts.basementYN resoFacts.buildingName  \
# 0                 False                   None
#
#   resoFacts.buyerAgencyCompensation resoFacts.buyerAgencyCompensationType  \
# 0                                 2                                     %
#
#                        resoFacts.appliances  \
# 0  [Dishwasher, Disposal, Microwave, Range]
#
#                             resoFacts.atAGlanceFacts  \
# 0  [{'factLabel': 'Type', 'factValue': 'Single Fa...
#
#                                      resoFacts.attic  \
# 0  Built in Features, Eating Space In Kitchen, Hi...
#
#   resoFacts.availabilityDate resoFacts.basement  resoFacts.bathrooms  \
# 0                       None               None                    2
#
#    resoFacts.bathroomsFull  resoFacts.bathroomsHalf  \
# 0                        2                        0
#
#   resoFacts.bathroomsOneQuarter resoFacts.bathroomsPartial  \
# 0                          None                       None
#
#   resoFacts.bathroomsThreeQuarter  resoFacts.bedrooms resoFacts.bodyType  \
# 0                            None                   3               None
#
#    resoFacts.canRaiseHorses resoFacts.carportParkingCapacity  \
# 0                     False                             None
#
#   resoFacts.cityRegion resoFacts.commonWalls resoFacts.communityFeatures  \
# 0                Tampa                  None                        None
#
#   resoFacts.cooling  resoFacts.coveredParkingCapacity  \
# 0     [Central Air]                                 1
#
#   resoFacts.cropsIncludedYN resoFacts.developmentStatus  \
# 0                      None                        None
#
#   resoFacts.doorFeatures resoFacts.electric resoFacts.elevation  \
# 0                   None               None                None
#
#   resoFacts.elevationUnits resoFacts.entryLevel resoFacts.entryLocation  \
# 0                     None                 None                    None
#
#   resoFacts.exclusions resoFacts.fencing resoFacts.fireplaceFeatures  \
# 0                 None              None                        None
#
#   resoFacts.fireplaces resoFacts.flooring resoFacts.foundationArea  \
# 0                 None     [Carpet, Tile]                     None
#
#    resoFacts.furnished  resoFacts.garageParkingCapacity resoFacts.gas  \
# 0                False                                1          None
#
#   resoFacts.greenBuildingVerificationType resoFacts.greenEnergyEfficient  \
# 0                                    None          [Appliances, Windows]
#
#   resoFacts.greenIndoorAirQuality resoFacts.greenSustainability  \
# 0                            None                          None
#
#   resoFacts.greenWaterConservation  resoFacts.hasAssociation  \
# 0                             None                     False
#
#    resoFacts.hasAttachedGarage  resoFacts.hasAttachedProperty  \
# 0                         True                          False
#
#    resoFacts.hasCooling  resoFacts.hasCarport resoFacts.hasElectricOnProperty  \
# 0                  True                 False                            None
#
#    resoFacts.hasFireplace  resoFacts.hasGarage  resoFacts.hasHeating  \
# 0                   False                 True                  True
#
#    resoFacts.hasLandLease  resoFacts.hasOpenParking  resoFacts.hasSpa  \
# 0                   False                      True             False
#
#   resoFacts.hasPrivatePool  resoFacts.hasView resoFacts.hasWaterfrontView  \
# 0                     None              False                        None
#
#   resoFacts.heating resoFacts.highSchool resoFacts.highSchoolDistrict  \
# 0         [Central]         Middleton-HB                         None
#
#   resoFacts.hoaFee resoFacts.homeType resoFacts.horseAmenities  \
# 0             None       SingleFamily                     None
#
#   resoFacts.horseYN                         resoFacts.interiorFeatures  \
# 0              None  [Built-in Features, Eating Space In Kitchen, H...
#
#   resoFacts.irrigationWaterRightsAcres resoFacts.irrigationWaterRightsYN  \
# 0                                 None                              None
#
#   resoFacts.isSeniorCommunity resoFacts.landLeaseAmount  \
# 0                        None                      None
#
#   resoFacts.landLeaseExpirationDate resoFacts.laundryFeatures  \
# 0                              None  [Inside, Laundry Closet]
#
#   resoFacts.levels resoFacts.listingId resoFacts.lotFeatures  \
# 0              One                None            [City Lot]
#
#   resoFacts.lotSize resoFacts.mainLevelBathrooms resoFacts.mainLevelBedrooms  \
# 0        5,076 sqft                         None                        None
#
#   resoFacts.marketingType resoFacts.middleOrJuniorSchool  \
# 0                    None                      McLane-HB
#
#   resoFacts.middleOrJuniorSchoolDistrict resoFacts.municipality  \
# 0                                   None                   None
#
#   resoFacts.numberOfUnitsInCommunity resoFacts.offerReviewDate  \
# 0                               None                      None
#
#    resoFacts.onMarketDate resoFacts.openParkingCapacity  \
# 0           1674777600000                          None
#
#   resoFacts.otherEquipment resoFacts.otherFacts      resoFacts.otherParking  \
# 0                     None                   []  [Garage Dimensions: 13x18]
#
#   resoFacts.ownershipType  resoFacts.parkingCapacity  \
# 0                    None                          1
#
#         resoFacts.parkingFeatures     resoFacts.patioAndPorchFeatures  \
# 0  [Driveway, Garage Door Opener]  [Covered, Front Porch, Rear Porch]
#
#   resoFacts.poolFeatures  resoFacts.pricePerSquareFoot  \
# 0                   None                           215
#
#   resoFacts.roadSurfaceType resoFacts.roofType resoFacts.rooms  \
# 0          [Paved, Asphalt]            Shingle              []
#
#   resoFacts.securityFeatures resoFacts.sewer resoFacts.spaFeatures  \
# 0                       None  [Public Sewer]                  None
#
#   resoFacts.specialListingConditions  resoFacts.stories  \
# 0                               None                  1
#
#   resoFacts.storiesTotal       resoFacts.subdivisionName  \
# 0                   None  4ne | Robson Bros' Subdivision
#
#    resoFacts.totalActualRent              resoFacts.utilities resoFacts.view  \
# 0                          0  [Electricity Available, Public]             []
#
#   resoFacts.waterSource resoFacts.waterBodyName resoFacts.waterfrontFeatures  \
# 0              [Public]                    None                         None
#
#   resoFacts.waterView  resoFacts.waterViewYN   resoFacts.windowFeatures  \
# 0                None                  False  [Blinds, Storm Window(s)]
#
#    resoFacts.yearBuilt resoFacts.zoning resoFacts.zoningDescription  \
# 0                 2020            RM-16                        None
#
#   resoFacts.aboveGradeFinishedArea resoFacts.additionalParcelsDescription  \
# 0                             None                                   None
#
#   resoFacts.architecturalStyle resoFacts.belowGradeFinishedArea  \
# 0                  Traditional                             None
#
#   resoFacts.builderModel resoFacts.builderName resoFacts.buildingArea  \
# 0                   None          Domain Homes                  2,158
#
#   resoFacts.buildingAreaSource resoFacts.buildingFeatures  \
# 0                         None                       None
#
#   resoFacts.constructionMaterials  \
# 0  [Block, Cement Siding, Stucco]
#
#                           resoFacts.exteriorFeatures  \
# 0  [Hurricane Shutters, Lighting, Rain Gutters, S...
#
#   resoFacts.foundationDetails resoFacts.frontageLength resoFacts.frontageType  \
# 0                      [Slab]                     None                   None
#
#    resoFacts.hasAdditionalParcels  resoFacts.hasPetsAllowed  \
# 0                           False                      True
#
#   resoFacts.hasRentControl  resoFacts.hasHomeWarranty resoFacts.inclusions  \
# 0                     None                      False                 None
#
#   resoFacts.incomeIncludes  resoFacts.isNewConstruction  \
# 0                     None                        False
#
#   resoFacts.listingTerms resoFacts.livingAreaRange  \
# 0                   None                      None
#
#   resoFacts.livingAreaRangeUnits resoFacts.livingArea  \
# 0                           None           1,630 sqft
#
#   resoFacts.lotSizeDimensions resoFacts.numberOfUnitsVacant  \
# 0                    47 x 108                          None
#
#   resoFacts.otherStructures resoFacts.ownership   resoFacts.parcelNumber  \
# 0                      None          Fee Simple  A0829194NE00000000008.0
#
#   resoFacts.propertyCondition  resoFacts.propertySubType  \
# 0                        None  [Single Family Residence]
#
#   resoFacts.structureType resoFacts.topography resoFacts.vegetation  \
# 0                    None                 None                 None
#
#   resoFacts.woodedArea resoFacts.yearBuiltEffective  \
# 0                 None                         None
#
#                                resoFacts.virtualTour  \
# 0  https://www.propertypanorama.com/instaview/ste...
#
#   resoFacts.elementarySchool resoFacts.elementarySchoolDistrict  \
# 0                  Potter-HB                               None
#
#   resoFacts.listAOR attributionInfo.listingAgreement attributionInfo.mlsName  \
# 0              None                             None    Stellar MLS / MFRMLS
#
#   attributionInfo.agentEmail attributionInfo.agentLicenseNumber  \
# 0       km@tampahometalk.com                               None
#
#   attributionInfo.agentName attributionInfo.agentPhoneNumber  \
# 0          Katrina Madewell                     813-212-8300
#
#   attributionInfo.attributionTitle   attributionInfo.brokerName  \
# 0             Listing Provided by:  Keller Williams Tampa Prop.
#
#   attributionInfo.brokerPhoneNumber  \
# 0                      813-264-7754
#
#   attributionInfo.buyerAgentMemberStateLicense attributionInfo.buyerAgentName  \
# 0                                         None                           None
#
#   attributionInfo.buyerBrokerageName attributionInfo.coAgentLicenseNumber  \
# 0                               None                                 None
#
#   attributionInfo.coAgentName attributionInfo.coAgentNumber  \
# 0                        None                          None
#
#   attributionInfo.lastChecked attributionInfo.lastUpdated  \
# 0         2023-02-25 04:44:04         2023-02-03 16:27:26
#
#                       attributionInfo.listingOffices  \
# 0  [{'associatedOfficeType': 'listOffice', 'offic...
#
#                        attributionInfo.listingAgents  \
# 0  [{'associatedAgentType': 'listAgent', 'memberF...
#
#                        attributionInfo.mlsDisclaimer attributionInfo.mlsId  \
# 0  IDX information is provided exclusively for pe...              T3424788
#
#                         attributionInfo.providerLogo  \
# 0  https://photos.zillowstatic.com/fp/e39375731b4...
#
#                          attributionInfo.infoString3  \
# 0  https://photos.zillowstatic.com/fp/e39375731b4...
#
#   attributionInfo.infoString5  \
# 0                813-212-8300
#
#                         attributionInfo.infoString10  \
# 0  IDX information is provided exclusively for pe...
#
#   attributionInfo.infoString16 attributionInfo.trueStatus  \
# 0         km@tampahometalk.com                       None
#
#   homeRecommendations.blendedRecs homeRecommendations.displayShort  \
# 0                              []
#
#   parentRegion.name  listingMetadata.mustAttributeOfficeNameBeforeAgentName  \
# 0      College Hill                                              False
#
#    listingMetadata.mustDisplayAttributionListAgentEmail  \
# 0                                              False
#
#    listingMetadata.mustDisplayAttributionListAgentPhone  \
# 0                                               True
#
#    listingMetadata.mustDisplayAttributionListingOfficePhone  \
# 0                                               True
#
#    listingMetadata.mustDisplayDisclaimerBelowAttribution  \
# 0                                               True
#
#   listingMetadata.mustHighlightAgentName  \
# 0                                   None
#
#    listingMetadata.mustHighlightListOfficeName  \
# 0                                        False
#
#    listingMetadata.mustMakeListingAgentContactable  \
# 0                                            False
#
#    listingMetadata.isAdsRestricted  listingMetadata.FlexibleLayoutAB  \
# 0                            False                              True
#
#    listingMetadata.FlexibleLayoutB  listingMetadata.FlexibleLayoutC  \
# 0                             True                             True
#
#    listingMetadata.FlexibleLayoutD  listingMetadata.FlexibleLayoutE  \
# 0                             True                             True
#
#    listingMetadata.FlexibleLayoutF  listingMetadata.FlexibleLayoutG  \
# 0                            False                            False
#
#    listingMetadata.FlexibleLayoutH  listingMetadata.FlexibleLayoutI  \
# 0                             True                             True
#
#    listingMetadata.FlexibleLayoutJ  listingMetadata.FlexibleLayoutK  \
# 0                            False                             True
#
#    listingMetadata.FlexibleLayoutL  listingMetadata.FlexibleLayoutM  \
# 0                            False                             True
#
#    listingMetadata.FlexibleLayoutN  listingMetadata.FlexibleLayoutO  \
# 0                             True                             True
#
#    listingMetadata.FlexibleLayoutP  listingMetadata.FlexibleLayoutQ  \
# 0                             True                            False
#
#    listingMetadata.FlexibleLayoutR  listingMetadata.FlexibleLayoutS  \
# 0                             True                             True
#
#    listingMetadata.FlexibleLayoutT  listingMetadata.FlexibleLayoutU  \
# 0                            False                            False
#
#    listingMetadata.FlexibleLayoutV  listingMetadata.FlexibleLayoutW  \
# 0                            False                            False
#
#    listingMetadata.FlexibleLayoutX  listingMetadata.FlexibleLayoutY  \
# 0                            False                            False
#
#    listingMetadata.FlexibleLayoutZ  listingMetadata.FlexibleLayoutAA  \
# 0                            False                              True
#
#    listingMetadata.passwordRequiredForZestimateMarketAnalysis  \
# 0                                              False
#
#    listingMetadata.canShowAutomatedValuationDisplay  \
# 0                                              True
#
#    listingMetadata.canShowTaxHistory  listingMetadata.canShowPriceHistory  \
# 0                               True                                 True
#
#    listingMetadata.canShowUserGeneratedContent  \
# 0                                         True
#
#    listingMetadata.hidePriceAdjustmentFlexField  \
# 0                                         False
#
#    listingMetadata.canCommingleComparables  \
# 0                                     True
#
#    listingMetadata.canShowComparables  \
# 0                                True
#
#    listingMetadata.isSuperTrafficOptimized  \
# 0                                    False
#
#    listingMetadata.mustDisplayFeedLogoInContactBox  \
# 0                                            False
#
#    listingMetadata.canShowCroppedPhotos  listingMetadata.canShowNonIDXMedia  \
# 0                                  True                                True
#
#    listingMetadata.canShowOnMap  listingMetadata.comminglingCategory  \
# 0                          True                                 True
#
#   listingMetadata.mustHighlightMlsId  listingMetadata.mustHighlightMlsStatus  \
# 0                               None                                   False
#
#    listingMetadata.mustHighlightMarketingType  \
# 0                                       False
#
#    listingMetadata.canShowZillowLogoInHeader  \
# 0                                       True
#
#    listingMetadata.canShowPrequalifiedLinkInChip  \
# 0                                           True
#
#    listingMetadata.comminglingCategoryIsRulesApplicable  \
# 0                                               True
#
#    mortgageRates.fifteenYearFixedRate  mortgageRates.thirtyYearFixedRate  \
# 0                                5.84                              6.659
#
#    mortgageRates.arm5Rate  tourEligibility.isPropertyTourEligible  \
# 0                   5.848                                    True
#
#    tourEligibility.propertyTourOptions.isFinal  \
# 0                                         True
#
#   tourEligibility.propertyTourOptions.tourAvailability  \
# 0  [{'date': '2023-02-25', 'status': 'AVAILABLE',...
#
#   tourEligibility.propertyTourOptions.tourType  \
# 0                                     STANDARD
#
#    contactFormRenderData.data.agent_module.agent_reason  \
# 0                                                  3
#
#   contactFormRenderData.data.agent_module.badge_type  \
# 0                                      Listing Agent
#
#   contactFormRenderData.data.agent_module.business_name  \
# 0                        Keller Williams Tampa Prop.
#
#   contactFormRenderData.data.agent_module.display_name  \
# 0                                   Katrina Madewell
#
#   contactFormRenderData.data.agent_module.encoded_zuid  \
# 0                            X1-ZUyq3nn6z9glc9_40okc
#
#   contactFormRenderData.data.agent_module.first_name  \
# 0                                            Katrina
#
#    contactFormRenderData.data.agent_module.image_data.height  \
# 0                                                 60
#
#   contactFormRenderData.data.agent_module.image_data.url  \
# 0  https://photos.zillowstatic.com/h_n/IS9dk5rj6a...
#
#    contactFormRenderData.data.agent_module.image_data.width  \
# 0                                                 60
#
#   contactFormRenderData.data.agent_module.phone  \
# 0                                          None
#
#   contactFormRenderData.data.agent_module.profile_url  \
# 0                         /profile/Katrina-Madewell/
#
#    contactFormRenderData.data.agent_module.rating_average  \
# 0                                                4.9
#
#    contactFormRenderData.data.agent_module.recent_sales  \
# 0                                                  0
#
#    contactFormRenderData.data.agent_module.review_count  \
# 0                                                 33
#
#   contactFormRenderData.data.agent_module.reviews_url  \
# 0                 /profile/Katrina-Madewell/#reviews
#
#   contactFormRenderData.data.agent_module.services_offered  \
# 0                                   [1, 2, 3, 6, 33]
#
#   contactFormRenderData.data.agent_module.write_review_url  \
# 0          /reviews/write/?s=X1-ZUyq3nn6z9glc9_40okc
#
#    contactFormRenderData.data.agent_module.zpro  \
# 0                                         False
#
#       contactFormRenderData.data.authentication.hmac  \
# 0  0494b77003b1b2660e4753bd60c3b275917f8553f292bc...
#
#   contactFormRenderData.data.authentication.request_id  \
# 0                   42da3242b50b11ed89a50aa7a12f95a5
#
#    contactFormRenderData.data.brokerage_info_must_be_shown  \
# 0                                              False
#
#   contactFormRenderData.data.contact_button_text  \
# 0                                  Contact Agent
#
#        contactFormRenderData.data.contact_recipients  \
# 0  [{'agent_reason': 1, 'badge_type': 'Premier Ag...
#
#   contactFormRenderData.data.cv_27.bal_checkboxes  \
# 0                                            0100
#
#   contactFormRenderData.data.cv_27.brokerage_product  \
# 0                                                 00
#
#   contactFormRenderData.data.cv_27.field_flags  \
# 0                                            1
#
#   contactFormRenderData.data.cv_27.form_identifier  \
# 0                                        opaque_la
#
#   contactFormRenderData.data.cv_27.mortgage_flags  \
# 0                                            1100
#
#   contactFormRenderData.data.desktop_phone_number  \
# 0                                            None
#
#    contactFormRenderData.data.display_options.is_opaque_eligible  \
# 0                                               True
#
#          contactFormRenderData.data.displayed_agents  \
# 0  [{'agent_reason': 1, 'badge_type': 'Premier Ag...
#
#         contactFormRenderData.data.displayed_lenders  \
# 0  [{'agent_encoded_zuid': 'X1-ZUxivwe8qcaz9l_9bp...
#
#   contactFormRenderData.data.fallback_form.contact_recipients  \
# 0                                                 []
#
#   contactFormRenderData.data.fallback_form.cv_27.bal_checkboxes  \
# 0                                               0000
#
#   contactFormRenderData.data.fallback_form.cv_27.brokerage_product  \
# 0                                                 00
#
#   contactFormRenderData.data.fallback_form.cv_27.field_flags  \
# 0                                                  0
#
#   contactFormRenderData.data.fallback_form.cv_27.form_identifier  \
# 0                                    agent_directory
#
#   contactFormRenderData.data.fallback_form.cv_27.mortgage_flags  \
# 0                                                  0
#
#     contactFormRenderData.data.fallback_form.footers  \
# 0  [{'external': False, 'text': 'Visit profession...
#
#   contactFormRenderData.data.fallback_form.hidden_fields  \
# 0                                                 []
#
#    contactFormRenderData.data.fallback_form.subtitle  \
# 0  Visit our professional directory to find an ag...
#
#   contactFormRenderData.data.fallback_form.title  \
# 0                                  Contact Agent
#
#    contactFormRenderData.data.fallback_form.tour_eligible  \
# 0                                              False
#
#   contactFormRenderData.data.fallback_form.variant  \
# 0                                  agent_directory
#
#             contactFormRenderData.data.hidden_fields  \
# 0  [{'name': 'variant', 'value': 'opaque'}, {'nam...
#
#    contactFormRenderData.data.hide_textarea  \
# 0                                     False
#
#    contactFormRenderData.data.info_box_visible  \
# 0                                         True
#
#    contactFormRenderData.data.keller_williams  \
# 0                                       False
#
#    contactFormRenderData.data.lender_details.preapproval.checked  \
# 0                                              False
#
#   contactFormRenderData.data.lender_details.preapproval.label  \
# 0                       I want financing information
#
#   contactFormRenderData.data.lender_details.preapproval.message_when_checked  \
# 0        A Zillow confirmed lender will contact you.
#
#    contactFormRenderData.data.lender_details.preapproval_info.property_value  \
# 0                                             350000
#
#   contactFormRenderData.data.lender_details.preapproval_info.state_abbr  \
# 0                                                 FL
#
#   contactFormRenderData.data.lender_details.preapproval_info.zipcode  \
# 0                                              33605
#
#    contactFormRenderData.data.listing.direct_connect.tour_eligible  \
# 0                                              False
#
#   contactFormRenderData.data.listing.one_advisor  \
# 0                                           None
#
#    contactFormRenderData.data.listing.supports_unselected_leads  \
# 0                                               True
#
#    contactFormRenderData.data.opaque_la   contactFormRenderData.data.pixel_id  \
# 0                                  True  6c7ae8c3-0b20-4dfa-94ab-7b8d91120c11
#
#                 contactFormRenderData.data.pixel_url  \
# 0  https://www.zillowstatic.com/contact-pixel/Chl...
#
#    contactFormRenderData.data.premier_agent_preferred_property  \
# 0                                               True
#
#   contactFormRenderData.data.region_phone_number.areacode  \
# 0                                                813
#
#   contactFormRenderData.data.region_phone_number.number  \
# 0                                               0209
#
#   contactFormRenderData.data.region_phone_number.prefix  \
# 0                                                213
#
#   contactFormRenderData.data.request_trace.xpi  \
# 0                                         None
#
#   contactFormRenderData.data.request_trace.xsi  \
# 0                             25d440e66374f905
#
#   contactFormRenderData.data.request_trace.xti  \
# 0             88a6e12b6f473555f0cda414549b8d3e
#
#    contactFormRenderData.data.tcpa contactFormRenderData.data.text_area.name  \
# 0                             True                                   message
#
#           contactFormRenderData.data.text_area.value  \
# 0  I am interested in 3611 Potter St, Tampa, FL 3...
#
#               contactFormRenderData.data.text_fields  \
# 0  [{'input_type': 'text', 'name': 'name', 'patte...
#
#   contactFormRenderData.data.title  \
# 0                    Contact Agent
#
#    contactFormRenderData.data.tour_config.useFoundation  \
# 0                                               True
#
#    contactFormRenderData.data.tour_eligible  \
# 0                                     False
#
#   contactFormRenderData.data.variant  ZoDsFsUpsellTop.display  \
# 0                             opaque                     True
#
#   ZoDsFsUpsellTop.displayCategory ZoDsFsUpsellTop.displayAttributes.leadType  \
# 0                property-zipcode                                   MORTGAGE
#
#   ZoDsFsUpsellTop.treatment ZoDsFsUpsellTop.surfaceId  \
# 0                   RTBP_ON                     fshdp
#
#   ZoDsFsUpsellTop.placementId  \
# 0                     wow-top
#
#                               ZoDsFsUpsellTop.reason  \
# 0  Upsell displaying is based on the zipcode of t...
#
#                   onsiteMessage.eventId  \
# 0  d62fb3ce-c0a4-462b-b184-7b65a1d8a7ca
#
#                               onsiteMessage.messages  \
# 0  [{'skipDisplayReason': None, 'shouldDisplay': ...
#
#    foreclosureTypes.isBankOwned  foreclosureTypes.isForeclosedNFS  \
# 0                         False                             False
#
#    foreclosureTypes.isPreforeclosure  foreclosureTypes.isAnyForeclosure  \
# 0                              False                              False
#
#    foreclosureTypes.wasNonRetailAuction  foreclosureTypes.wasForeclosed  \
# 0                                 False                           False
#
#   foreclosureTypes.wasREO foreclosureTypes.wasDefault  \
# 0                    None                        None
#
#                                    staticMap.sources  listingSubType.isFSBA  \
# 0  [{'width': 192, 'url': 'https://maps.googleapi...                   True
#
#    listingSubType.isFSBO  listingSubType.isPending  listingSubType.isNewHome  \
# 0                  False                     False                     False
#
#    listingSubType.isForeclosure  listingSubType.isBankOwned  \
# 0                         False                       False
#
#    listingSubType.isForAuction  listingSubType.isOpenHouse  \
# 0                        False                       False
#
#    listingSubType.isComingSoon postingContact.name postingContact.photo  \
# 0                        False    Katrina Madewell                 None
#
#   vrModel.vrModelGuid vrModel.revisionId  \
# 0                None               None
#
#                    thirdPartyVirtualTour.externalUrl  \
# 0  https://www.propertypanorama.com/instaview/ste...
#
#   thirdPartyVirtualTour.lightboxUrl thirdPartyVirtualTour.staticUrl  \
# 0                              None                            None
#
#   thirdPartyVirtualTour.providerKey  thirdPartyVirtualTour.approved  \
# 0                              None                            True
#
#   topNavJson.topnav.json.logo.text topNavJson.topnav.json.logo.href  \
# 0               Zillow Real Estate                                /
#
#                 topNavJson.topnav.json.main.sections  \
# 0  [{'link': {'text': 'Buy', 'href': '/homes/', '...
#
#    topNavJson.topnav.json.agent  \
# 0                         False
#
#            topNavJson.topnav.json.marketing.sections  \
# 0  [{'link': {'text': 'Manage Rentals', 'href': '...
#
#             topNavJson.topnav.json.regLogin.sections  \
# 0  [{'link': {'text': 'Sign in', 'href': '/user/a...
#
#                 topNavJson.topnav.json.help.sections  \
# 0  [{'link': {'text': 'Help', 'href': 'https://zi...
#
#   topNavJson.topnav.json.common.home.text  \
# 0                      Zillow Real Estate
#
#   topNavJson.topnav.json.common.home.href  \
# 0                                       /
#
#   topNavJson.topnav.json.common.advertise.text  \
# 0                                    Advertise
#
#   topNavJson.topnav.json.common.advertise.href  \
# 0                                  /advertise/
#
#   topNavJson.topnav.json.common.login.text  \
# 0                                  Sign in
#
#   topNavJson.topnav.json.common.login.href  \
# 0                        /user/acct/login/
#
#   topNavJson.topnav.json.common.register.text  \
# 0                                        Join
#
#   topNavJson.topnav.json.common.register.href  \
# 0                        /user/acct/register/
#
#                                   topNavJson.core.js  \
# 0  https://s.zillowstatic.com/s3/pfs/core-8903757...
#
#                               formattedChip.location  selfTour.hasSelfTour
# 0  [{'fullValue': '3611 Potter St'}, {'fullValue'...                 False

# %%
print("Street address:", df_prop["streetAddress"].iloc[0])
print("City:", df_prop["city"].iloc[0])
print("State:", df_prop["state"].iloc[0])
print("Home status:", df_prop["homeStatus"].iloc[0])
print("Bedrooms:", df_prop["bedrooms"].iloc[0])
print("Bathrooms:", df_prop["bathrooms"].iloc[0])
print("Year built:", df_prop["yearBuilt"].iloc[0])
print("Zestimate: ${:,}".format(df_prop["zestimate"].iloc[0]))
print("Rent zestimate: ${:,}".format(df_prop["rentZestimate"].iloc[0]))
print("Description:")
df_prop["description"].iloc[0]
# Out:
# Street address: 3611 Potter St
# City: Tampa
# State: FL
# Home status: FOR_SALE
# Bedrooms: 3
# Bathrooms: 2
# Year built: 2020
# Zestimate: $339,553
# Rent zestimate: $2,414
# Description:
# 'WOW! What an amazing NEW BUILD with 3 bedrooms, 2 bathrooms, 1 car garage, fully fenced backyard and an incredible kitchen. Fall in love with the gorgeous landscaping in your front yard and a front porch with exterior lighting. As soon as you go inside immediately cherish the openness and TILED great room with your living room to your right, kitchen in the middle including GRANITE COUNTERTOPS, real wood cabinets, WALK-IN PANTRY with wire shelving racks and STAINLESS STEEL APPLIANCES. As you go farther inside, to your left you can find the TILED dining room with BLINDS and a new light fixture. Following the TILE FLOOR into the hallway on the right appreciate your washer and dryer in a closet, tucked away until it’s laundry day. As you keep going through the hallway you can find the CARPETED master bedroom with a WALK IN CLOSET, blinds and on the side is your TILED master bathroom with DUAL SINKS, granite countertops, real wood cabinets, and a stand up shower. As you exit the master bedroom straight ahead you can find the other TILED bathroom including granite countertops, real wood cabinets, and a tub with shower. Adjacent to the bathroom you can find two CARPETED bedrooms with blinds, and two closet doors. Some additional features include NO HOA, windows are double insulated, hybrid hot water heater, and a security system. If you like to be outdoors you’re in luck you can find multiple parks nearby, McKay Bay, Hillsborough Bay, Lowry Park, Tampa Riverwalk, and so much more! Even if being outside isn’t for you there’s lots to do indoors close by including The Florida Aquarium, several museums, International mall and other malls, bowling and tons more! Also some roads close by for quick commute include the Suncoast, US-41, I-4, and the Selmon Expressway.'

# %% [markdown]
# #### Comparables

# %%
# view comparables
df_c = pd.DataFrame(df_prop["comps"].iloc[0])
df_c
# Out:
#          zpid                                     miniCardPhotos   price  \
# 0    45108843  [{'url': 'https://photos.zillowstatic.com/fp/d...  325000
# 1    45100317  [{'url': 'https://photos.zillowstatic.com/fp/2...  394995
# 2    45108732  [{'url': 'https://photos.zillowstatic.com/fp/f...  329999
# 3    45099808  [{'url': 'https://photos.zillowstatic.com/fp/4...  299995
# 4  2059031409  [{'url': 'https://photos.zillowstatic.com/fp/6...  419999
# 5    45082438  [{'url': 'https://photos.zillowstatic.com/fp/7...  339900
# 6    45108845  [{'url': 'https://photos.zillowstatic.com/fp/6...  345000
# 7    45099406  [{'url': 'https://photos.zillowstatic.com/fp/f...  369000
# 8    45093593  [{'url': 'https://photos.zillowstatic.com/fp/e...  350000
# 9    68576588  [{'url': 'https://photos.zillowstatic.com/fp/b...  359900
#
#   currency  bedrooms  bathrooms  livingArea  livingAreaValue livingAreaUnits  \
# 0      USD         3          1        1064             1064     Square Feet
# 1      USD         3          3        1523             1523     Square Feet
# 2      USD         3          2        1092             1092     Square Feet
# 3      USD         3          2        1396             1396     Square Feet
# 4      USD         3          2        1607             1607     Square Feet
# 5      USD         3          2        1456             1456     Square Feet
# 6      USD         3          2        1187             1187     Square Feet
# 7      USD         3          2        1858             1858     Square Feet
# 8      USD         2          1        1040             1040     Square Feet
# 9      USD         3          2        1200             1200     Square Feet
#
#   livingAreaUnitsShort                                 listingMetadata  \
# 0                 sqft  {'comminglingCategoryIsRulesApplicable': True}
# 1                 sqft  {'comminglingCategoryIsRulesApplicable': True}
# 2                 sqft  {'comminglingCategoryIsRulesApplicable': True}
# 3                 sqft  {'comminglingCategoryIsRulesApplicable': True}
# 4                 sqft  {'comminglingCategoryIsRulesApplicable': True}
# 5                 sqft  {'comminglingCategoryIsRulesApplicable': True}
# 6                 sqft  {'comminglingCategoryIsRulesApplicable': True}
# 7                 sqft  {'comminglingCategoryIsRulesApplicable': True}
# 8                 sqft  {'comminglingCategoryIsRulesApplicable': True}
# 9                 sqft  {'comminglingCategoryIsRulesApplicable': True}
#
#    lotSize  lotAreaValue lotAreaUnits  \
# 0     3500   3500.000000  Square Feet
# 1     2450   2450.000000  Square Feet
# 2    30491      0.700000        Acres
# 3    12675      0.290978        Acres
# 4     5200   5200.000000  Square Feet
# 5    11100      0.254821        Acres
# 6     5300   5300.000000  Square Feet
# 7    10400  10400.000000  Square Feet
# 8     5100   5100.000000  Square Feet
# 9     5750   5750.000000  Square Feet
#
#                                              address  \
# 0  {'streetAddress': '1801 E 18th Ave', 'city': '...
# 1  {'streetAddress': '3618 N 25th St', 'city': 'T...
# 2  {'streetAddress': '2904 Sanchez St', 'city': '...
# 3  {'streetAddress': '3716 N 35th St', 'city': 'T...
# 4  {'streetAddress': '2803 N 33rd St', 'city': 'T...
# 5  {'streetAddress': '1608 E Sitka St', 'city': '...
# 6  {'streetAddress': '1822 E 17th Ave', 'city': '...
# 7  {'streetAddress': '3513 N 10th St', 'city': 'T...
# 8  {'streetAddress': '204 W Chelsea St', 'city': ...
# 9  {'streetAddress': '2908 12th St', 'city': 'Tam...
#
#                                        formattedChip   latitude  longitude  \
# 0  {'location': [{'fullValue': '1801 E 18th Ave'}...  27.968065 -82.438710
# 1  {'location': [{'fullValue': '3618 N 25th St'},...  27.977478 -82.431564
# 2  {'location': [{'fullValue': '2904 Sanchez St'}...  27.968900 -82.442340
# 3  {'location': [{'fullValue': '3716 N 35th St'},...  27.979225 -82.421130
# 4  {'location': [{'fullValue': '2803 N 33rd St'},...  27.968510 -82.423010
# 5  {'location': [{'fullValue': '1608 E Sitka St'}...  28.021452 -82.441956
# 6  {'location': [{'fullValue': '1822 E 17th Ave'}...  27.967752 -82.438150
# 7  {'location': [{'fullValue': '3513 N 10th St'},...  27.976995 -82.449180
# 8  {'location': [{'fullValue': '204 W Chelsea St'...  27.984964 -82.461300
# 9  {'location': [{'fullValue': '2908 12th St'}, {...  27.969185 -82.447260
#
#   homeStatus       homeType  \
# 0   FOR_SALE  SINGLE_FAMILY
# 1   FOR_SALE  SINGLE_FAMILY
# 2   FOR_SALE  SINGLE_FAMILY
# 3   FOR_SALE  SINGLE_FAMILY
# 4   FOR_SALE  SINGLE_FAMILY
# 5   FOR_SALE  SINGLE_FAMILY
# 6   FOR_SALE  SINGLE_FAMILY
# 7   FOR_SALE  SINGLE_FAMILY
# 8   FOR_SALE  SINGLE_FAMILY
# 9   FOR_SALE  SINGLE_FAMILY
#
#                                               hdpUrl  \
# 0  /homedetails/1801-E-18th-Ave-Tampa-FL-33605/45...
# 1  /homedetails/3618-N-25th-St-Tampa-FL-33605/451...
# 2  /homedetails/2904-Sanchez-St-Tampa-FL-33605/45...
# 3  /homedetails/3716-N-35th-St-Tampa-FL-33610/450...
# 4  /homedetails/2803-N-33rd-St-Tampa-FL-33605/205...
# 5  /homedetails/1608-E-Sitka-St-Tampa-FL-33604/45...
# 6  /homedetails/1822-E-17th-Ave-Tampa-FL-33605/45...
# 7  /homedetails/3513-N-10th-St-Tampa-FL-33605/450...
# 8  /homedetails/204-W-Chelsea-St-Tampa-FL-33603/4...
# 9  /homedetails/2908-12th-St-Tampa-FL-33605/68576...
#
#                                     listing_sub_type providerListingID  \
# 0  {'is_newHome': False, 'is_forAuction': False, ...              None
# 1  {'is_newHome': True, 'is_forAuction': False, '...              None
# 2  {'is_newHome': False, 'is_forAuction': False, ...              None
# 3  {'is_newHome': False, 'is_forAuction': False, ...              None
# 4  {'is_newHome': True, 'is_forAuction': False, '...              None
# 5  {'is_newHome': False, 'is_forAuction': False, ...              None
# 6  {'is_newHome': False, 'is_forAuction': False, ...              None
# 7  {'is_newHome': False, 'is_forAuction': False, ...              None
# 8  {'is_newHome': False, 'is_forAuction': False, ...              None
# 9  {'is_newHome': False, 'is_forAuction': False, ...              None
#
#                                      attributionInfo  isPremierBuilder state  \
# 0  {'mlsId': 'T3430530', 'mlsName': None, 'provid...             False    FL
# 1  {'mlsId': 'T3429831', 'mlsName': None, 'provid...             False    FL
# 2  {'mlsId': '821464', 'mlsName': None, 'provider...             False    FL
# 3  {'mlsId': 'T3430083', 'mlsName': None, 'provid...             False    FL
# 4  {'mlsId': 'U8191744', 'mlsName': None, 'provid...             False    FL
# 5  {'mlsId': 'T3426989', 'mlsName': None, 'provid...             False    FL
# 6  {'mlsId': 'T3427190', 'mlsName': None, 'provid...             False    FL
# 7  {'mlsId': 'T3418765', 'mlsName': None, 'provid...             False    FL
# 8  {'mlsId': 'T3430342', 'mlsName': None, 'provid...             False    FL
# 9  {'mlsId': 'T3417938', 'mlsName': None, 'provid...             False    FL
#
#    isZillowOwned newConstructionType
# 0          False                None
# 1          False        BUILDER_SPEC
# 2          False                None
# 3          False                None
# 4          False        BUILDER_SPEC
# 5          False                None
# 6          False                None
# 7          False                None
# 8          False                None
# 9          False                None

# %% [markdown]
# #### Tax History

# %%
# view tax history
df_tax_hist = pd.DataFrame(df_prop["taxHistory"].iloc[0])
df_tax_hist
# Out:
#              time  taxPaid  taxIncreaseRate  value  valueIncreaseRate
# 0   1614257548865   700.43         1.694998  35532           2.991014
# 1   1582635148865   259.90         0.029225   8903           0.099951
# 2   1551099148865   252.52         0.000000   8094          -0.509365
# 3   1519563148865   252.52         0.212290  16497           1.166667
# 4   1488027148865   208.30         0.450759   7614           0.252097
# 5   1456404748865   143.58         0.065055   6081           0.100036
# 6   1424868748865   134.81         0.212975   5528           0.100100
# 7   1393332748865   111.14         0.000000   5025           0.100044
# 8   1361796748865   111.14         0.129357   4568           0.000000
# 9   1330174348865    98.41         0.031660   4568           0.033952
# 10  1298638348865    95.39        -0.194613   4418          -0.199928
# 11  1267102348865   118.44        -0.689370   5522          -0.687528
# 12  1235566348865   381.29        -0.387466  17672          -0.384615
# 13  1203943948865   622.48        -0.060393  28717          -0.071429
# 14  1172407948865   662.49         0.279605  30926           0.400000
# 15  1140871948865   517.73         0.617754  22090           0.666667
# 16  1109335948865   320.03         0.000000  13254           0.500000
# 17  1077713548865      NaN         0.000000   8836           0.428618
# 18  1046177548865      NaN         0.000000   6185           0.000000
# 19  1014641548865      NaN         0.000000   6185          -0.020896
# 20   983105548865      NaN         0.000000   6317           0.000000
# 21   951483148865      NaN         0.000000   6317           0.000000

# %% [markdown]
# #### Price History

# %%
# view price history
df_price_hist = pd.DataFrame(df_prop["priceHistory"].iloc[0])
df_price_hist
# Out:
#           date           time   price  pricePerSquareFoot  priceChangeRate  \
# 0   2023-02-04  1675468800000  350000                 215        -0.041096
# 1   2023-01-27  1674777600000  365000                 224         0.383362
# 2   2023-01-02  1672617600000    2400                   1         0.000000
# 3   2022-12-05  1670198400000    2400                   1         0.200000
# 4   2021-12-16  1639612800000    2000                   1         0.000000
# 5   2021-12-14  1639440000000    2000                   1        -0.047619
# 6   2021-12-06  1638748800000    2100                   1        -0.045455
# 7   2021-10-15  1634256000000    2200                   1         0.000000
# 8   2021-09-30  1632960000000    2200                   1         0.000000
# 9   2021-05-25  1621900800000  263850                 162         0.000474
# 10  2021-04-09  1617926400000  263725                 162         0.000000
# 11  2020-10-12  1602460800000  263725                 162         0.000000
#
#               event                         source  \
# 0      Price change           Stellar MLS / MFRMLS
# 1   Listed for sale           Stellar MLS / MFRMLS
# 2   Listing removed                        HotPads
# 3   Listed for rent          Zillow Rental Manager
# 4   Listing removed  Zillow Rental Network Premium
# 5      Price change  Zillow Rental Network Premium
# 6   Listed for rent  Zillow Rental Network Premium
# 7   Listing removed  Zillow Rental Network Premium
# 8   Listed for rent  Zillow Rental Network Premium
# 9              Sold           Stellar MLS / MFRMLS
# 10     Pending sale           Stellar MLS / MFRMLS
# 11  Listed for sale              DOMAIN REALTY LLC
#
#                                            buyerAgent sellerAgent  \
# 0                                                None        None
# 1                                                None        None
# 2                                                None        None
# 3                                                None        None
# 4                                                None        None
# 5                                                None        None
# 6                                                None        None
# 7                                                None        None
# 8                                                None        None
# 9   {'photo': {'url': 'https://photos.zillowstatic...        None
# 10                                               None        None
# 11                                               None        None
#
#     showCountyLink  postingIsRental  \
# 0            False            False
# 1            False            False
# 2            False             True
# 3            False             True
# 4            False             True
# 5            False             True
# 6            False             True
# 7            False             True
# 8            False             True
# 9            False            False
# 10           False            False
# 11           False            False
#
#                                       attributeSource
# 0   {'infoString1': 'T3424788', 'infoString2': 'St...
# 1   {'infoString1': 'T3424788', 'infoString2': 'St...
# 2   {'infoString1': '8da539eb3daa58a1532a386a012f2...
# 3   {'infoString1': None, 'infoString2': 'Zillow R...
# 4   {'infoString1': None, 'infoString2': 'Zillow R...
# 5   {'infoString1': None, 'infoString2': 'Zillow R...
# 6   {'infoString1': None, 'infoString2': 'Zillow R...
# 7   {'infoString1': None, 'infoString2': 'Zillow R...
# 8   {'infoString1': None, 'infoString2': 'Zillow R...
# 9   {'infoString1': 'T3270295', 'infoString2': 'St...
# 10  {'infoString1': 'T3270295', 'infoString2': 'St...
# 11  {'infoString1': None, 'infoString2': 'DOMAIN R...

# %% [markdown]
# ### <font color="green">4. Locate ZPID by Address</font>

# %%
street = "12315 N Oakleaf Ave"
city = "Tampa"
state = "FL"
# zip_code = "33612" #[optional]

zpid_response = get_zpid(api_key, street, city, state, zip_code=None)

# %%
zpid_response.json()["is_success"]
# Out:
# True

# %%
# view response, top possible zpids
pd.DataFrame(zpid_response.json()["data"])
# Out:
#        zpid                                                url
# 0  44905318  https://www.zillow.com/homedetails/12315-N-Oak...
# 1  44905319  https://www.zillow.com/homedetails/12319-N-Oak...
# 2  44905317  https://www.zillow.com/homedetails/12311-N-Oak...
# 3  44905324  https://www.zillow.com/homedetails/12315-Woodl...
# 4  44905320  https://www.zillow.com/homedetails/1714-Round-...

# %%
print("Zpid:", zpid_response.json()["data"][0]["zpid"])
# Out:
# Zpid: 44905318

# %% [markdown]
# ### <font color="green">5. FSBO (For Sale By Owner) Listings</font>

# %%
fsbo_url = "https://www.zillow.com/tampa-fl/?searchQueryState=%7B%22usersSearchTerm%22%3A%22Tampa%2C%20FL%22%2C%22mapBounds%22%3A%7B%22west%22%3A-82.85425150830079%2C%22east%22%3A-82.05430949169923%2C%22south%22%3A27.749100096033082%2C%22north%22%3A28.239597518118032%7D%2C%22regionSelection%22%3A%5B%7B%22regionId%22%3A41176%2C%22regionType%22%3A6%7D%5D%2C%22isMapVisible%22%3Atrue%2C%22filterState%22%3A%7B%22sort%22%3A%7B%22value%22%3A%22globalrelevanceex%22%7D%2C%22ah%22%3A%7B%22value%22%3Atrue%7D%2C%22fsba%22%3A%7B%22value%22%3Afalse%7D%2C%22nc%22%3A%7B%22value%22%3Afalse%7D%2C%22cmsn%22%3A%7B%22value%22%3Afalse%7D%2C%22auc%22%3A%7B%22value%22%3Afalse%7D%2C%22fore%22%3A%7B%22value%22%3Afalse%7D%2C%22tow%22%3A%7B%22value%22%3Afalse%7D%2C%22mf%22%3A%7B%22value%22%3Afalse%7D%2C%22con%22%3A%7B%22value%22%3Afalse%7D%2C%22apco%22%3A%7B%22value%22%3Afalse%7D%2C%22land%22%3A%7B%22value%22%3Afalse%7D%2C%22apa%22%3A%7B%22value%22%3Afalse%7D%2C%22manu%22%3A%7B%22value%22%3Afalse%7D%2C%22price%22%3A%7B%22max%22%3A1000000%7D%2C%22mp%22%3A%7B%22max%22%3A5155%7D%7D%2C%22isListVisible%22%3Atrue%2C%22mapZoom%22%3A11%2C%22category%22%3A%22cat2%22%2C%22pagination%22%3A%7B%7D%7D"

# %%
fspo_response = get_listings(api_key, fsbo_url)

# %%
# view count of properies returned in request
num_of_properties = fspo_response.json()["data"]["categoryTotals"]["cat2"]["totalResultCount"]
print("Count of properties:", num_of_properties)
# Out:
# Count of properties: 20

# %%
# view all listings
df_fsbo_listings = pd.json_normalize(fspo_response.json()["data"]["cat2"]["searchResults"]["mapResults"])
print("Number of rows:", len(df_fsbo_listings))
print("Number of columns:", len(df_fsbo_listings.columns))
df_fsbo_listings
# Out:
# Number of rows: 20
# Number of columns: 67
#           zpid     price priceLabel  beds  baths  area statusType  \
# 0   2076754227  $265,000      $265K     2    3.0  1568   FOR_SALE
# 1     45092182  $515,000      $515K     3    2.0  1655   FOR_SALE
# 2   2138562422  $360,000      $360K     3    3.0  1526   FOR_SALE
# 3     45081822  $435,000      $435K     4    4.0  2266   FOR_SALE
# 4     45037717  $304,900      $305K     3    2.0  1161   FOR_SALE
# 5     60618071  $625,000      $625K     4    3.0  2605   FOR_SALE
# 6     45092695  $279,900      $280K     2    1.0   864   FOR_SALE
# 7     45041202  $550,000      $550K     4    2.0  2449   FOR_SALE
# 8     44885527  $300,000      $300K     2    2.0   934   FOR_SALE
# 9     45085863  $350,000      $350K     3    3.0  1438   FOR_SALE
# 10    45096441  $485,000      $485K     2    2.0  1200   FOR_SALE
# 11   332364004  $429,750      $430K     3    2.0  2080   FOR_SALE
# 12    44962307  $479,000      $479K     3    2.0  1996   FOR_SALE
# 13    45101047  $425,000      $425K     3    1.0  1548   FOR_SALE
# 14    45041679  $625,000      $625K     3    3.0  2281   FOR_SALE
# 15    45056583  $424,900      $425K     2    1.0  1060   FOR_SALE
# 16    45070498  $495,000      $495K     3    2.0  1244   FOR_SALE
# 17    45052705  $685,000      $685K     3    2.0  1746   FOR_SALE
# 18  2128448620  $649,900      $650K     0    2.0  2762   FOR_SALE
# 19  2075221652  $970,000      $970K     3    4.0  1868   FOR_SALE
#
#            statusText  isFavorite  isUserClaimingOwner  isUserConfirmedClaim  \
# 0   For sale by owner       False                False                 False
# 1   For sale by owner       False                False                 False
# 2   For sale by owner       False                False                 False
# 3   For sale by owner       False                False                 False
# 4   For sale by owner       False                False                 False
# 5   For sale by owner       False                False                 False
# 6   For sale by owner       False                False                 False
# 7   For sale by owner       False                False                 False
# 8   For sale by owner       False                False                 False
# 9   For sale by owner       False                False                 False
# 10  For sale by owner       False                False                 False
# 11  For sale by owner       False                False                 False
# 12  For sale by owner       False                False                 False
# 13  For sale by owner       False                False                 False
# 14  For sale by owner       False                False                 False
# 15  For sale by owner       False                False                 False
# 16  For sale by owner       False                False                 False
# 17  For sale by owner       False                False                 False
# 18  For sale by owner       False                False                 False
# 19  For sale by owner       False                False                 False
#
#                                                imgSrc  hasImage  visited  \
# 0   https://photos.zillowstatic.com/fp/a2d81866c8e...      True    False
# 1   https://photos.zillowstatic.com/fp/2c2a6744073...      True    False
# 2   https://photos.zillowstatic.com/fp/3108eba6a12...      True    False
# 3   https://photos.zillowstatic.com/fp/bb7bfd2dd3c...      True    False
# 4   https://photos.zillowstatic.com/fp/9f719807213...      True    False
# 5   https://photos.zillowstatic.com/fp/f2ba5ba9c50...      True    False
# 6   https://photos.zillowstatic.com/fp/f2bdcc17de4...      True    False
# 7   https://photos.zillowstatic.com/fp/de9f4550d6b...      True    False
# 8   https://photos.zillowstatic.com/fp/86aa1137bf4...      True    False
# 9   https://photos.zillowstatic.com/fp/95f2f9aac8b...      True    False
# 10  https://photos.zillowstatic.com/fp/37eb64ad8da...      True    False
# 11  https://photos.zillowstatic.com/fp/9377df5078f...      True    False
# 12  https://photos.zillowstatic.com/fp/37d494da39d...      True    False
# 13  https://photos.zillowstatic.com/fp/f3b6ea3d37b...      True    False
# 14  https://photos.zillowstatic.com/fp/2ec4ac90231...      True    False
# 15  https://photos.zillowstatic.com/fp/d4ae69329db...      True    False
# 16  https://photos.zillowstatic.com/fp/44a6721a349...      True    False
# 17  https://photos.zillowstatic.com/fp/5a209ac9699...      True    False
# 18  https://photos.zillowstatic.com/fp/933d9d49942...      True    False
# 19  https://photos.zillowstatic.com/fp/fe24b0a63b1...      True    False
#
#    listingType  variableData  shouldShowZestimateAsPrice  \
# 0                        NaN                       False
# 1                        NaN                       False
# 2                        NaN                       False
# 3                        NaN                       False
# 4                        NaN                       False
# 5                        NaN                       False
# 6                        NaN                       False
# 7                        NaN                       False
# 8                        NaN                       False
# 9                        NaN                       False
# 10                       NaN                       False
# 11                       NaN                       False
# 12                       NaN                       False
# 13                       NaN                       False
# 14                       NaN                       False
# 15                       NaN                       False
# 16                       NaN                       False
# 17                       NaN                       False
# 18                       NaN                       False
# 19                       NaN                       False
#
#                                             detailUrl    pgapt  \
# 0   /homedetails/3747-Winward-Lakes-Dr-Tampa-FL-33...  ForSale
# 1   /homedetails/5905-N-Suwanee-Ave-Tampa-FL-33604...  ForSale
# 2   /homedetails/20112-Heron-Crossing-Dr-Tampa-FL-...  ForSale
# 3   /homedetails/2014-E-Broad-St-Tampa-FL-33610/45...  ForSale
# 4   /homedetails/1504-W-Hollywood-St-Tampa-FL-3360...  ForSale
# 5   /homedetails/17312-Chenango-Ln-Tampa-FL-33647/...  ForSale
# 6   /homedetails/816-E-Wilder-Ave-Tampa-FL-33603/4...  ForSale
# 7   /homedetails/2115-W-Dallas-Ave-Tampa-FL-33603/...  ForSale
# 8   /homedetails/2720-Midtimes-Dr-Tampa-FL-33618/4...  ForSale
# 9   /homedetails/3906-E-Louisiana-Ave-Tampa-FL-336...  ForSale
# 10  /homedetails/43-Hamilton-Heath-Dr-Tampa-FL-336...  ForSale
# 11  /homedetails/5026-W-Ingraham-St-Tampa-FL-33616...  ForSale
# 12  /homedetails/9325-Hampshire-Park-Dr-Tampa-FL-3...  ForSale
# 13  /homedetails/2702-W-Abdella-St-Tampa-FL-33607/...  ForSale
# 14  /homedetails/4604-Wishart-Blvd-Tampa-FL-33603/...  ForSale
# 15  /homedetails/3016-S-Manhattan-Ave-Tampa-FL-336...  ForSale
# 16  /homedetails/6718-S-Sheridan-Rd-Tampa-FL-33611...  ForSale
# 17  /homedetails/3918-W-Watrous-Ave-Tampa-FL-33629...  ForSale
# 18  /homedetails/301-S-22nd-St-Tampa-FL-33605/2128...  ForSale
# 19  /homedetails/204-S-Tampania-Ave-2-Tampa-FL-336...  ForSale
#
#                 sgapt  has3DModel  hasVideo  isHomeRec address  \
# 0   For Sale By Owner       False     False      False      --
# 1   For Sale By Owner       False     False      False      --
# 2   For Sale By Owner       False     False      False      --
# 3   For Sale By Owner       False     False      False      --
# 4   For Sale By Owner       False     False      False      --
# 5   For Sale By Owner       False     False      False      --
# 6   For Sale By Owner       False     False      False      --
# 7   For Sale By Owner       False     False      False      --
# 8   For Sale By Owner       False     False      False      --
# 9   For Sale By Owner       False      True      False      --
# 10  For Sale By Owner       False     False      False      --
# 11  For Sale By Owner       False     False      False      --
# 12  For Sale By Owner       False     False      False      --
# 13  For Sale By Owner       False     False      False      --
# 14  For Sale By Owner       False     False      False      --
# 15  For Sale By Owner       False     False      False      --
# 16  For Sale By Owner       False     False      False      --
# 17  For Sale By Owner       False     False      False      --
# 18  For Sale By Owner       False     False      False      --
# 19  For Sale By Owner       False     False      False      --
#
#     hasAdditionalAttributions  isFeaturedListing availabilityDate  \
# 0                       False              False             None
# 1                       False              False             None
# 2                       False              False             None
# 3                       False              False             None
# 4                       False              False             None
# 5                       False              False             None
# 6                       False              False             None
# 7                       False              False             None
# 8                       False              False             None
# 9                       False              False             None
# 10                      False              False             None
# 11                      False              False             None
# 12                      False              False             None
# 13                      False              False             None
# 14                      False              False             None
# 15                      False              False             None
# 16                      False              False             None
# 17                      False              False             None
# 18                      False              False             None
# 19                      False              False             None
#
#     latLong.latitude  latLong.longitude  hdpData.homeInfo.zpid  \
# 0          27.876034         -82.505650             2076754227
# 1          28.001055         -82.458140               45092182
# 2          28.159235         -82.387210             2138562422
# 3          28.016432         -82.435326               45081822
# 4          28.019226         -82.474960               45037717
# 5          28.128172         -82.384895               60618071
# 6          27.992610         -82.451940               45092695
# 7          27.988577         -82.481705               45041202
# 8          28.102764         -82.488120               44885527
# 9          27.989887         -82.415560               45085863
# 10         28.018715         -82.449290               45096441
# 11         27.861937         -82.530815              332364004
# 12         28.129007         -82.338460               44962307
# 13         27.970207         -82.487130               45101047
# 14         27.984886         -82.481190               45041679
# 15         27.918673         -82.517630               45056583
# 16         27.870771         -82.497480               45070498
# 17         27.931807         -82.509530               45052705
# 18         27.947040         -82.434920             2128448620
# 19         27.943295         -82.486070             2075221652
#
#    hdpData.homeInfo.zipcode hdpData.homeInfo.city hdpData.homeInfo.state  \
# 0                     33611                 Tampa                     FL
# 1                     33604                 Tampa                     FL
# 2                     33647                 Tampa                     FL
# 3                     33610                 Tampa                     FL
# 4                     33604                 Tampa                     FL
# 5                     33647                 Tampa                     FL
# 6                     33603                 Tampa                     FL
# 7                     33603                 Tampa                     FL
# 8                     33618                 Tampa                     FL
# 9                     33610                 Tampa                     FL
# 10                    33604                 Tampa                     FL
# 11                    33616                 Tampa                     FL
# 12                    33647                 Tampa                     FL
# 13                    33607                 Tampa                     FL
# 14                    33603                 Tampa                     FL
# 15                    33629                 Tampa                     FL
# 16                    33611                 Tampa                     FL
# 17                    33629                 Tampa                     FL
# 18                    33605                 Tampa                     FL
# 19                    33609                 Tampa                     FL
#
#     hdpData.homeInfo.latitude  hdpData.homeInfo.longitude  \
# 0                   27.876034                  -82.505650
# 1                   28.001055                  -82.458140
# 2                   28.159235                  -82.387210
# 3                   28.016432                  -82.435326
# 4                   28.019226                  -82.474960
# 5                   28.128172                  -82.384895
# 6                   27.992610                  -82.451940
# 7                   27.988577                  -82.481705
# 8                   28.102764                  -82.488120
# 9                   27.989887                  -82.415560
# 10                  28.018715                  -82.449290
# 11                  27.861937                  -82.530815
# 12                  28.129007                  -82.338460
# 13                  27.970207                  -82.487130
# 14                  27.984886                  -82.481190
# 15                  27.918673                  -82.517630
# 16                  27.870771                  -82.497480
# 17                  27.931807                  -82.509530
# 18                  27.947040                  -82.434920
# 19                  27.943295                  -82.486070
#
#     hdpData.homeInfo.price  hdpData.homeInfo.bathrooms  \
# 0                 265000.0                         3.0
# 1                 515000.0                         2.0
# 2                 360000.0                         3.0
# 3                 435000.0                         4.0
# 4                 304900.0                         2.0
# 5                 625000.0                         3.0
# 6                 279900.0                         1.0
# 7                 550000.0                         2.0
# 8                 300000.0                         2.0
# 9                 350000.0                         3.0
# 10                485000.0                         2.0
# 11                429750.0                         2.0
# 12                479000.0                         2.0
# 13                425000.0                         1.0
# 14                625000.0                         3.0
# 15                424900.0                         1.0
# 16                495000.0                         2.0
# 17                685000.0                         2.0
# 18                649900.0                         2.0
# 19                970000.0                         4.0
#
#     hdpData.homeInfo.bedrooms  hdpData.homeInfo.livingArea  \
# 0                         2.0                       1568.0
# 1                         3.0                       1655.0
# 2                         3.0                       1526.0
# 3                         4.0                       2266.0
# 4                         3.0                       1161.0
# 5                         4.0                       2605.0
# 6                         2.0                        864.0
# 7                         4.0                       2449.0
# 8                         2.0                        934.0
# 9                         3.0                       1438.0
# 10                        2.0                       1200.0
# 11                        3.0                       2080.0
# 12                        3.0                       1996.0
# 13                        3.0                       1548.0
# 14                        3.0                       2281.0
# 15                        2.0                       1060.0
# 16                        3.0                       1244.0
# 17                        3.0                       1746.0
# 18                        0.0                       2762.0
# 19                        3.0                       1868.0
#
#    hdpData.homeInfo.homeType hdpData.homeInfo.homeStatus  \
# 0              SINGLE_FAMILY                    FOR_SALE
# 1              SINGLE_FAMILY                    FOR_SALE
# 2              SINGLE_FAMILY                    FOR_SALE
# 3              SINGLE_FAMILY                    FOR_SALE
# 4              SINGLE_FAMILY                    FOR_SALE
# 5              SINGLE_FAMILY                    FOR_SALE
# 6              SINGLE_FAMILY                    FOR_SALE
# 7              SINGLE_FAMILY                    FOR_SALE
# 8              SINGLE_FAMILY                    FOR_SALE
# 9              SINGLE_FAMILY                    FOR_SALE
# 10             SINGLE_FAMILY                    FOR_SALE
# 11             SINGLE_FAMILY                    FOR_SALE
# 12             SINGLE_FAMILY                    FOR_SALE
# 13             SINGLE_FAMILY                    FOR_SALE
# 14             SINGLE_FAMILY                    FOR_SALE
# 15             SINGLE_FAMILY                    FOR_SALE
# 16             SINGLE_FAMILY                    FOR_SALE
# 17             SINGLE_FAMILY                    FOR_SALE
# 18             SINGLE_FAMILY                    FOR_SALE
# 19             SINGLE_FAMILY                    FOR_SALE
#
#     hdpData.homeInfo.daysOnZillow  hdpData.homeInfo.isFeatured  \
# 0                              -1                        False
# 1                              -1                        False
# 2                              -1                        False
# 3                              -1                        False
# 4                              -1                        False
# 5                              -1                        False
# 6                              -1                        False
# 7                              -1                        False
# 8                              -1                        False
# 9                              -1                        False
# 10                             -1                        False
# 11                             -1                        False
# 12                             -1                        False
# 13                             -1                        False
# 14                             -1                        False
# 15                             -1                        False
# 16                             -1                        False
# 17                             -1                        False
# 18                             -1                        False
# 19                             -1                        False
#
#     hdpData.homeInfo.shouldHighlight  hdpData.homeInfo.rentZestimate  \
# 0                              False                            2799
# 1                              False                            2833
# 2                              False                            2199
# 3                              False                            2709
# 4                              False                            1997
# 5                              False                            3494
# 6                              False                            1727
# 7                              False                            2937
# 8                              False                            1663
# 9                              False                            2075
# 10                             False                            1900
# 11                             False                            2496
# 12                             False                            2499
# 13                             False                            2665
# 14                             False                            3085
# 15                             False                            2411
# 16                             False                            2499
# 17                             False                            3913
# 18                             False                            1635
# 19                             False                            4142
#
#     hdpData.homeInfo.listing_sub_type.is_FSBO  hdpData.homeInfo.isUnmappable  \
# 0                                        True                          False
# 1                                        True                          False
# 2                                        True                          False
# 3                                        True                          False
# 4                                        True                          False
# 5                                        True                          False
# 6                                        True                          False
# 7                                        True                          False
# 8                                        True                          False
# 9                                        True                          False
# 10                                       True                          False
# 11                                       True                          False
# 12                                       True                          False
# 13                                       True                          False
# 14                                       True                          False
# 15                                       True                          False
# 16                                       True                          False
# 17                                       True                          False
# 18                                       True                          False
# 19                                       True                          False
#
#     hdpData.homeInfo.isPreforeclosureAuction  \
# 0                                      False
# 1                                      False
# 2                                      False
# 3                                      False
# 4                                      False
# 5                                      False
# 6                                      False
# 7                                      False
# 8                                      False
# 9                                      False
# 10                                     False
# 11                                     False
# 12                                     False
# 13                                     False
# 14                                     False
# 15                                     False
# 16                                     False
# 17                                     False
# 18                                     False
# 19                                     False
#
#    hdpData.homeInfo.homeStatusForHDP  hdpData.homeInfo.priceForHDP  \
# 0                           FOR_SALE                      265000.0
# 1                           FOR_SALE                      515000.0
# 2                           FOR_SALE                      360000.0
# 3                           FOR_SALE                      435000.0
# 4                           FOR_SALE                      304900.0
# 5                           FOR_SALE                      625000.0
# 6                           FOR_SALE                      279900.0
# 7                           FOR_SALE                      550000.0
# 8                           FOR_SALE                      300000.0
# 9                           FOR_SALE                      350000.0
# 10                          FOR_SALE                      485000.0
# 11                          FOR_SALE                      429750.0
# 12                          FOR_SALE                      479000.0
# 13                          FOR_SALE                      425000.0
# 14                          FOR_SALE                      625000.0
# 15                          FOR_SALE                      424900.0
# 16                          FOR_SALE                      495000.0
# 17                          FOR_SALE                      685000.0
# 18                          FOR_SALE                      649900.0
# 19                          FOR_SALE                      970000.0
#
#     hdpData.homeInfo.isNonOwnerOccupied  hdpData.homeInfo.isPremierBuilder  \
# 0                                  True                              False
# 1                                  True                              False
# 2                                  True                              False
# 3                                  True                              False
# 4                                  True                              False
# 5                                  True                              False
# 6                                  True                              False
# 7                                  True                              False
# 8                                  True                              False
# 9                                  True                              False
# 10                                 True                              False
# 11                                 True                              False
# 12                                 True                              False
# 13                                 True                              False
# 14                                 True                              False
# 15                                 True                              False
# 16                                 True                              False
# 17                                 True                              False
# 18                                 True                              False
# 19                                 True                              False
#
#     hdpData.homeInfo.isZillowOwned hdpData.homeInfo.currency  \
# 0                            False                       USD
# 1                            False                       USD
# 2                            False                       USD
# 3                            False                       USD
# 4                            False                       USD
# 5                            False                       USD
# 6                            False                       USD
# 7                            False                       USD
# 8                            False                       USD
# 9                            False                       USD
# 10                           False                       USD
# 11                           False                       USD
# 12                           False                       USD
# 13                           False                       USD
# 14                           False                       USD
# 15                           False                       USD
# 16                           False                       USD
# 17                           False                       USD
# 18                           False                       USD
# 19                           False                       USD
#
#    hdpData.homeInfo.country  hdpData.homeInfo.lotAreaValue  \
# 0                       USA                    4000.000000
# 1                       USA                    6969.000000
# 2                       USA                    3850.000000
# 3                       USA                    6337.000000
# 4                       USA                    8712.000000
# 5                       USA                       0.359986
# 6                       USA                    6969.000000
# 7                       USA                       0.261685
# 8                       USA                    6534.000000
# 9                       USA                    8258.000000
# 10                      USA                    5662.000000
# 11                      USA                    4791.000000
# 12                      USA                   10454.000000
# 13                      USA                   10018.000000
# 14                      USA                    7300.000000
# 15                      USA                    5000.000000
# 16                      USA                    6325.000000
# 17                      USA                       0.250000
# 18                      USA                    9147.000000
# 19                      USA                    3223.000000
#
#    hdpData.homeInfo.lotAreaUnit  hdpData.homeInfo.zestimate  \
# 0                          sqft                         NaN
# 1                          sqft                    383600.0
# 2                          sqft                    349500.0
# 3                          sqft                    434600.0
# 4                          sqft                    285500.0
# 5                         acres                    614800.0
# 6                          sqft                    258600.0
# 7                         acres                    522900.0
# 8                          sqft                    272200.0
# 9                          sqft                    288700.0
# 10                         sqft                    339800.0
# 11                         sqft                    425500.0
# 12                         sqft                    460100.0
# 13                         sqft                    320100.0
# 14                         sqft                    616500.0
# 15                         sqft                    428500.0
# 16                         sqft                    392400.0
# 17                        acres                    561800.0
# 18                         sqft                         NaN
# 19                         sqft                    734900.0
#
#     hdpData.homeInfo.taxAssessedValue  variableData.type  variableData.text  \
# 0                                 NaN                NaN                NaN
# 1                            239827.0                NaN                NaN
# 2                                 NaN                NaN                NaN
# 3                            232709.0       TIME_ON_INFO        8 hours ago
# 4                            137868.0                NaN                NaN
# 5                            364025.0                NaN                NaN
# 6                            111213.0    PRICE_REDUCTION   $15,000 (Feb 11)
# 7                            322281.0                NaN                NaN
# 8                            156446.0                NaN                NaN
# 9                            184696.0  VIDEO_WALKTHROUGH  Video Walkthrough
# 10                           186700.0                NaN                NaN
# 11                           242822.0                NaN                NaN
# 12                           258127.0                NaN                NaN
# 13                           201720.0                NaN                NaN
# 14                           394655.0    PRICE_REDUCTION    $40,000 (Jan 9)
# 15                           208098.0    PRICE_REDUCTION   $14,100 (Jan 11)
# 16                           219785.0                NaN                NaN
# 17                           342645.0                NaN                NaN
# 18                                NaN                NaN                NaN
# 19                                NaN                NaN                NaN
#
#    variableData.data.isFresh  hdpData.homeInfo.datePriceChanged  \
# 0                        NaN                                NaN
# 1                        NaN                                NaN
# 2                        NaN                                NaN
# 3                      False                                NaN
# 4                        NaN                                NaN
# 5                        NaN                                NaN
# 6                        NaN                       1.676102e+12
# 7                        NaN                                NaN
# 8                        NaN                                NaN
# 9                        NaN                                NaN
# 10                       NaN                                NaN
# 11                       NaN                                NaN
# 12                       NaN                                NaN
# 13                       NaN                                NaN
# 14                       NaN                       1.673251e+12
# 15                       NaN                       1.673424e+12
# 16                       NaN                                NaN
# 17                       NaN                                NaN
# 18                       NaN                                NaN
# 19                       NaN                                NaN
#
#    hdpData.homeInfo.priceReduction  hdpData.homeInfo.priceChange  \
# 0                              NaN                           NaN
# 1                              NaN                           NaN
# 2                              NaN                           NaN
# 3                              NaN                           NaN
# 4                              NaN                           NaN
# 5                              NaN                           NaN
# 6                 $15,000 (Feb 11)                      -15000.0
# 7                              NaN                           NaN
# 8                              NaN                           NaN
# 9                              NaN                           NaN
# 10                             NaN                           NaN
# 11                             NaN                           NaN
# 12                             NaN                           NaN
# 13                             NaN                           NaN
# 14                 $40,000 (Jan 9)                      -40000.0
# 15                $14,100 (Jan 11)                      -14100.0
# 16                             NaN                           NaN
# 17                             NaN                           NaN
# 18                             NaN                           NaN
# 19                             NaN                           NaN
#
#     hdpData.homeInfo.videoCount hdpData.homeInfo.unit
# 0                           NaN                   NaN
# 1                           NaN                   NaN
# 2                           NaN                   NaN
# 3                           NaN                   NaN
# 4                           NaN                   NaN
# 5                           NaN                   NaN
# 6                           NaN                   NaN
# 7                           NaN                   NaN
# 8                           NaN                   NaN
# 9                           1.0                   NaN
# 10                          NaN                   NaN
# 11                          NaN                   NaN
# 12                          NaN                   NaN
# 13                          NaN                   NaN
# 14                          NaN                   NaN
# 15                          NaN                   NaN
# 16                          NaN                   NaN
# 17                          NaN                   NaN
# 18                          NaN                   NaN
# 19                          NaN                   # 2

# %%
# view price
px.box(df_fsbo_listings, x="hdpData.homeInfo.price", title="Sales Price Histogram")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="53111da3-b3e0-4f67-ae61-58d3cd03c14b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("53111da3-b3e0-4f67-ae61-58d3cd03c14b")) {                    Plotly.newPlot(                        "53111da3-b3e0-4f67-ae61-58d3cd03c14b",                        [{"alignmentgroup":"True","hovertemplate":"hdpData.homeInfo.price=%{x}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"h","showlegend":false,"x":[265000.0,515000.0,360000.0,435000.0,304900.0,625000.0,279900.0,550000.0,300000.0,350000.0,485000.0,429750.0,479000.0,425000.0,625000.0,424900.0,495000.0,685000.0,649900.0,970000.0],"x0":" ","xaxis":"x","y0":" ","yaxis":"y","type":"box"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatte ...

# %% [markdown]
# #### <font color="purple">Get Owner Phone Number</font>

# %%
# select a sample fspo property from the dataframe
fsbo_single_listing = "45081822" # zpid

# %%
# get property detail
fsbo_prop_detail_response = get_property_detail(api_key, fsbo_single_listing)

# view property details
df_fsbo_prop = pd.json_normalize(fsbo_prop_detail_response.json()['data'])
print("Number of rows:", len(df_fsbo_prop))
print("Number of columns:", len(df_fsbo_prop.columns))
df_fsbo_prop
# Out:
# Number of rows: 1
# Number of columns: 607
#   listingDataSource      zpid   city state homeStatus  \
# 0            Legacy  45081822  Tampa    FL   FOR_SALE
#
#    isListingClaimedByCurrentSignedInUser  isCurrentSignedInAgentResponsible  \
# 0                                  False                              False
#
#    bedrooms  bathrooms   price  yearBuilt    streetAddress zipcode  \
# 0         4          4  435000       1958  2014 E Broad St   33610
#
#    isCurrentSignedInUserVerifiedOwner    regionString propertyUpdatePageLink  \
# 0                               False  Tampa FL 33610                   None
#
#   moveHomeMapLocationLink propertyEventLogLink editPropertyHistorylink  \
# 0                    None                 None                    None
#
#    isRentalListingOffMarket  \
# 0                     False
#
#                                               hdpUrl  \
# 0  /homedetails/2014-E-Broad-St-Tampa-FL-33610/45...
#
#                                         nearbyCities  \
# 0  [{'regionUrl': {'path': '/brandon-fl/'}, 'name...
#
#                                  nearbyNeighborhoods country  \
# 0  [{'regionUrl': {'path': '/east-tampa-tampa-fl/...     USA
#
#                                       nearbyZipcodes abbreviatedAddress  \
# 0  [{'regionUrl': {'path': '/tampa-fl-33604/'}, '...    2014 E Broad St
#
#   building  isUndisclosedAddress boroughId providerListingID boroughSearchUrl  \
# 0     None                 False      None              None             None
#
#   communityUrl  isPremierBuilder  isZillowOwned       homeType currency  \
# 0         None             False          False  SINGLE_FAMILY      USD
#
#   listPriceLow  livingArea  livingAreaValue  zestimate newConstructionType  \
# 0         None        2266             2266     434600                None
#
#   zestimateLowPercent zestimateHighPercent  rentZestimate restimateLowPercent  \
# 0                  14                   14           2709                None
#
#   restimateHighPercent                                            schools  \
# 0                 None  [{'distance': 0.6, 'name': 'Foster Elementary ...
#
#   homeValues                                        nearbyHomes countyFIPS  \
# 0       None  [{'zpid': 45081821, 'miniCardPhotos': [{'url':...      12057
#
#                  parcelId                                         taxHistory  \
# 0  19283046M000008000160A  [{'time': 1614390212583, 'taxPaid': 985.15, 't...
#
#                                         priceHistory  \
# 0  [{'date': '2023-02-26', 'time': 1677369600000,...
#
#                                                comps  \
# 0  [{'zpid': 45096690, 'miniCardPhotos': [{'url':...
#
#                                          description  \
# 0  This 2266 square foot single family home has 4...
#
#                                            whatILove contingentListingType  \
# 0  Master br is like having your own apt upstairs...                  None
#
#   timeOnZillow  pageViewCount  favoriteCount  daysOnZillow   latitude  \
# 0      8 hours            198              3             0  28.016432
#
#    longitude openHouseSchedule  \
# 0 -82.435326                []
#
#                               desktopWebHdpImageLink brokerageName  \
# 0  https://photos.zillowstatic.com/fp/bb7bfd2dd3c...          None
#
#            timeZone pals     listingAccountUserId  \
# 0  America/New_York   []  X1-ZUyv311lcu5hc9_11xcg
#
#                                         homeInsights sellingSoon  \
# 0  [{'insights': [{'modelId': 'z-model-0-nrt-tags...          []
#
#    isIncomeRestricted brokerId  ssid monthlyHoaFee  propertyTaxRate  \
# 0               False     None  None          None             1.06
#
#                                       hiResImageLink hdpTypeDimension mlsid  \
# 0  https://photos.zillowstatic.com/fp/bb7bfd2dd3c...          ForSale
#
#   propertyTypeDimension                                    mediumImageLink  \
# 0         Single Family  https://photos.zillowstatic.com/fp/bb7bfd2dd3c...
#
#   enhancedBrokerImageUrl                                   responsivePhotos  \
# 0                   None  [{'mixedSources': {'jpeg': [{'url': 'https://p...
#
#   buildingId virtualTourUrl  hasApprovedThirdPartyVirtualTourUrl  photoCount  \
# 0       None           None                                False          23
#
#   livingAreaUnits  lotSize  lotAreaValue lotAreaUnits postingProductType  \
# 0     Square Feet     6337          6337  Square Feet           Standard
#
#   marketingName richMedia  cityId  stateId zipPlusFour numberOfUnitsTotal  \
# 0          None      None   41176       14        1028               None
#
#   foreclosureDefaultFilingDate foreclosureAuctionFilingDate  \
# 0                         None                         None
#
#   foreclosureLoanDate foreclosureLoanOriginator foreclosureLoanAmount  \
# 0                None                      None                  None
#
#   foreclosurePriorSaleDate foreclosurePriorSaleAmount  \
# 0                     None                       None
#
#   foreclosureBalanceReportingDate foreclosurePastDueBalance  \
# 0                            None                      None
#
#   foreclosureUnpaidBalance foreclosureAuctionTime  \
# 0                     None                   None
#
#   foreclosureAuctionDescription foreclosureAuctionCity  \
# 0                          None                   None
#
#   foreclosureAuctionLocation foreclosureDate foreclosureAmount  \
# 0                       None            None              None
#
#   foreclosingBank foreclosureJudicialType datePostedString  \
# 0            None                Judicial       2023-02-26
#
#   foreclosureMoreInfo  hasBadGeocode  \
# 0                None          False
#
#                streetViewMetadataUrlMediaWallLatLong  \
# 0  https://maps.googleapis.com/maps/api/streetvie...
#
#                streetViewMetadataUrlMediaWallAddress  \
# 0  https://maps.googleapis.com/maps/api/streetvie...
#
#                  streetViewTileImageUrlMediumLatLong  \
# 0  https://maps.googleapis.com/maps/api/streetvie...
#
#                  streetViewTileImageUrlMediumAddress  \
# 0  https://maps.googleapis.com/maps/api/streetvie...
#
#                                 streetViewServiceUrl postingUrl  \
# 0  https://proxy.zillowapi.com/street-view-url?zp...       None
#
#    hasPublicVideo primaryPublicVideo richMediaVideos  \
# 0           False               None            None
#
#                                               photos  tourViewCount  \
# 0  [{'caption': 'Newly Pianted  New MetalRoof', '...              0
#
#   listingAccount listingFeedID livingAreaUnitsShort priceChange  \
# 0           None          None                 sqft        None
#
#   priceChangeDate priceChangeDateString  hideZestimate comingSoonOnMarketDate  \
# 0            None                  None          False                   None
#
#    isPreforeclosureAuction  lastSoldPrice  isHousingConnector  \
# 0                    False          75000               False
#
#                        responsivePhotosOriginalRatio  \
# 0  [{'caption': 'Newly Pianted  New MetalRoof', '...
#
#              streetViewMetadataUrlMapLightboxAddress  \
# 0  https://maps.googleapis.com/maps/api/streetvie...
#
#                                                thumb  isRecentStatusChange  \
# 0  [{'url': 'https://photos.zillowstatic.com/fp/b...                 False
#
#    isNonOwnerOccupied               county  isFeatured  \
# 0               False  Hillsborough County       False
#
#   rentalApplicationsAcceptedType listingTypeDimension  \
# 0               REQUEST_TO_APPLY    For Sale by Owner
#
#   featuredListingTypeDimension  brokerIdDimension keystoneHomeStatus  \
# 0                      organic  For Sale by Owner     ForSaleByOwner
#
#   pageUrlFragment  isRentalsLeadCapMet  isPaidMultiFamilyBrokerId  \
# 0         ForSale                False                      False
#
#   address.streetAddress address.city address.state address.zipcode  \
# 0       2014 E Broad St        Tampa            FL           33610
#
#   address.neighborhood address.community address.subdivision  \
# 0                 None              None                None
#
#    listing_sub_type.is_newHome  listing_sub_type.is_FSBO  \
# 0                        False                      True
#
#    listing_sub_type.is_FSBA  listing_sub_type.is_foreclosure  \
# 0                     False                            False
#
#    listing_sub_type.is_bankOwned  listing_sub_type.is_forAuction  \
# 0                          False                           False
#
#    listing_sub_type.is_comingSoon  listing_sub_type.is_pending  \
# 0                           False                        False
#
#    listing_sub_type.is_openHouse citySearchUrl.text citySearchUrl.path  \
# 0                          False     Homes in Tampa         /tampa-fl/
#
#   zipcodeSearchUrl.path apartmentsForRentInZipcodeSearchUrl.path  \
# 0      /tampa-fl-33610/              /tampa-fl-33610/apartments/
#
#   housesForRentInZipcodeSearchUrl.path neighborhoodRegion.name  \
# 0         /tampa-fl-33610/rent-houses/    Old Seminole Heights
#
#         neighborhoodSearchUrl.path stateSearchUrl.path  \
# 0  /old-seminole-heights-tampa-fl/                /fl/
#
#            countySearchUrl.text      countySearchUrl.path adTargets.aamgnrc1  \
# 0  Homes in Hillsborough County  /hillsborough-county-fl/    2014 E Broad St
#
#   adTargets.bd adTargets.city adTargets.proptp adTargets.pid adTargets.lot  \
# 0            4          Tampa              sfh      45081822             2
#
#   adTargets.zestibuck adTargets.listtp adTargets.sqftrange adTargets.price  \
# 0            400-449k        buy_owner           2000-2499          435000
#
#   adTargets.sqft adTargets.state adTargets.mlong adTargets.cnty  \
# 0           2266              FL      -82.435326   Hillsborough
#
#   adTargets.prange adTargets.zip adTargets.mlat adTargets.zusr  \
# 0         400-449k         33610      28.016432           true
#
#   adTargets.price_band adTargets.yrblt adTargets.zestimate adTargets.tflag  \
# 0                 z400       1940-1959              434600         verizon
#
#   adTargets.premieragent adTargets.dma                        adTargets.guid  \
# 0                     no            54  727aefc0-bbfa-4cf0-b08f-534759f6a0c9
#
#   adTargets.ssid resoFacts.accessibilityFeatures resoFacts.additionalFeeInfo  \
# 0           None                            None                        None
#
#   resoFacts.associationFee resoFacts.associationAmenities  \
# 0                     None                           None
#
#   resoFacts.associationFee2 resoFacts.associationFeeIncludes  \
# 0                      None                             None
#
#   resoFacts.associationName resoFacts.associationName2  \
# 0                      None                       None
#
#   resoFacts.associationPhone resoFacts.associationPhone2  \
# 0                       None                        None
#
#    resoFacts.basementYN resoFacts.buildingName  \
# 0                 False                   None
#
#   resoFacts.buyerAgencyCompensation resoFacts.buyerAgencyCompensationType  \
# 0                              None                                  None
#
#                                 resoFacts.appliances  \
# 0  [Dishwasher, Dryer, Garbage disposal, Microwav...
#
#                             resoFacts.atAGlanceFacts resoFacts.attic  \
# 0  [{'factLabel': 'Type', 'factValue': 'SingleFam...            None
#
#   resoFacts.availabilityDate resoFacts.basement  resoFacts.bathrooms  \
# 0                       None               None                    4
#
#    resoFacts.bathroomsFull  resoFacts.bathroomsHalf  \
# 0                        2                        1
#
#    resoFacts.bathroomsOneQuarter resoFacts.bathroomsPartial  \
# 0                              0                       None
#
#    resoFacts.bathroomsThreeQuarter  resoFacts.bedrooms resoFacts.bodyType  \
# 0                                1                   4               None
#
#    resoFacts.canRaiseHorses resoFacts.carportParkingCapacity  \
# 0                     False                             None
#
#   resoFacts.cityRegion resoFacts.commonWalls resoFacts.communityFeatures  \
# 0                Tampa                  None                          []
#
#   resoFacts.cooling resoFacts.coveredParkingCapacity  \
# 0   [Central, Wall]                             None
#
#   resoFacts.cropsIncludedYN resoFacts.developmentStatus  \
# 0                      None                        None
#
#   resoFacts.doorFeatures resoFacts.electric resoFacts.elevation  \
# 0                   None               None                None
#
#   resoFacts.elevationUnits resoFacts.entryLevel resoFacts.entryLocation  \
# 0                     None                 None                    None
#
#   resoFacts.exclusions resoFacts.fencing resoFacts.fireplaceFeatures  \
# 0                 None              None                        None
#
#   resoFacts.fireplaces resoFacts.flooring resoFacts.foundationArea  \
# 0                 None   [Tile, Laminate]                     None
#
#    resoFacts.furnished resoFacts.garageParkingCapacity resoFacts.gas  \
# 0                False                            None          None
#
#   resoFacts.greenBuildingVerificationType resoFacts.greenEnergyEfficient  \
# 0                                    None                           None
#
#   resoFacts.greenIndoorAirQuality resoFacts.greenSustainability  \
# 0                            None                          None
#
#   resoFacts.greenWaterConservation resoFacts.hasAssociation  \
# 0                             None                     None
#
#   resoFacts.hasAttachedGarage  resoFacts.hasAttachedProperty  \
# 0                        None                          False
#
#    resoFacts.hasCooling resoFacts.hasCarport resoFacts.hasElectricOnProperty  \
# 0                  True                 None                            None
#
#    resoFacts.hasFireplace  resoFacts.hasGarage  resoFacts.hasHeating  \
# 0                    True                False                  True
#
#    resoFacts.hasLandLease resoFacts.hasOpenParking  resoFacts.hasSpa  \
# 0                   False                     None             False
#
#   resoFacts.hasPrivatePool  resoFacts.hasView resoFacts.hasWaterfrontView  \
# 0                     None              False                        None
#
#         resoFacts.heating resoFacts.highSchool resoFacts.highSchoolDistrict  \
# 0  [Other, Electric, Gas]                 None                 HILLSBOROUGH
#
#   resoFacts.hoaFee resoFacts.homeType resoFacts.horseAmenities  \
# 0             None       SingleFamily                     None
#
#   resoFacts.horseYN resoFacts.interiorFeatures  \
# 0              None                       None
#
#   resoFacts.irrigationWaterRightsAcres resoFacts.irrigationWaterRightsYN  \
# 0                                 None                              None
#
#   resoFacts.isSeniorCommunity resoFacts.landLeaseAmount  \
# 0                        None                      None
#
#   resoFacts.landLeaseExpirationDate resoFacts.laundryFeatures  \
# 0                              None                      None
#
#   resoFacts.levels resoFacts.listingId resoFacts.lotFeatures  \
# 0             None                None                  None
#
#   resoFacts.lotSize resoFacts.mainLevelBathrooms resoFacts.mainLevelBedrooms  \
# 0        6,337 sqft                         None                        None
#
#   resoFacts.marketingType resoFacts.middleOrJuniorSchool  \
# 0                    None                           None
#
#   resoFacts.middleOrJuniorSchoolDistrict resoFacts.municipality  \
# 0                           HILLSBOROUGH                   None
#
#   resoFacts.numberOfUnitsInCommunity resoFacts.offerReviewDate  \
# 0                               None                      None
#
#    resoFacts.onMarketDate resoFacts.openParkingCapacity  \
# 0           1677369600000                          None
#
#   resoFacts.otherEquipment resoFacts.otherFacts resoFacts.otherParking  \
# 0                     None                   []                   None
#
#   resoFacts.ownershipType  resoFacts.parkingCapacity  \
# 0                    None                          4
#
#   resoFacts.parkingFeatures resoFacts.patioAndPorchFeatures  \
# 0                        []                            None
#
#   resoFacts.poolFeatures  resoFacts.pricePerSquareFoot  \
# 0                   None                           192
#
#   resoFacts.roadSurfaceType resoFacts.roofType  \
# 0                      None        Composition
#
#                                      resoFacts.rooms  \
# 0  [{'area': None, 'description': None, 'dimensio...
#
#   resoFacts.securityFeatures resoFacts.sewer resoFacts.spaFeatures  \
# 0                       None            None                  None
#
#   resoFacts.specialListingConditions resoFacts.stories resoFacts.storiesTotal  \
# 0                               None              None                   None
#
#   resoFacts.subdivisionName resoFacts.totalActualRent resoFacts.utilities  \
# 0                      None                      None                None
#
#   resoFacts.view resoFacts.waterSource resoFacts.waterBodyName  \
# 0             []                  None                    None
#
#   resoFacts.waterfrontFeatures resoFacts.waterView resoFacts.waterViewYN  \
# 0                         None                                      None
#
#   resoFacts.windowFeatures  resoFacts.yearBuilt resoFacts.zoning  \
# 0                     None                 1958             None
#
#   resoFacts.zoningDescription resoFacts.aboveGradeFinishedArea  \
# 0                        None                             None
#
#   resoFacts.additionalParcelsDescription resoFacts.architecturalStyle  \
# 0                                   None                         None
#
#   resoFacts.belowGradeFinishedArea resoFacts.builderModel  \
# 0                             None                   None
#
#   resoFacts.builderName resoFacts.buildingArea resoFacts.buildingAreaSource  \
# 0                  None                   None                         None
#
#   resoFacts.buildingFeatures resoFacts.constructionMaterials  \
# 0                       None                       [masonry]
#
#   resoFacts.exteriorFeatures resoFacts.foundationDetails  \
# 0                   [Stucco]                          []
#
#   resoFacts.frontageLength resoFacts.frontageType  \
# 0                     None                   None
#
#    resoFacts.hasAdditionalParcels resoFacts.hasPetsAllowed  \
# 0                           False                     None
#
#   resoFacts.hasRentControl  resoFacts.hasHomeWarranty resoFacts.inclusions  \
# 0                     None                      False                 None
#
#   resoFacts.incomeIncludes  resoFacts.isNewConstruction  \
# 0                     None                        False
#
#   resoFacts.listingTerms resoFacts.livingAreaRange  \
# 0                   None                      None
#
#   resoFacts.livingAreaRangeUnits resoFacts.livingArea  \
# 0                           None           2,266 sqft
#
#   resoFacts.lotSizeDimensions resoFacts.numberOfUnitsVacant  \
# 0                        None                          None
#
#   resoFacts.otherStructures resoFacts.ownership  resoFacts.parcelNumber  \
# 0                      None                None  19283046M000008000160A
#
#   resoFacts.propertyCondition resoFacts.propertySubType  \
# 0                        None                      None
#
#   resoFacts.structureType resoFacts.topography resoFacts.vegetation  \
# 0             Split-level                 None                 None
#
#   resoFacts.woodedArea resoFacts.yearBuiltEffective resoFacts.virtualTour  \
# 0                 None                         None                  None
#
#   resoFacts.elementarySchool resoFacts.elementarySchoolDistrict  \
# 0                       None                       HILLSBOROUGH
#
#   resoFacts.listAOR attributionInfo.listingAgreement attributionInfo.mlsName  \
# 0              None                             None                    None
#
#   attributionInfo.agentEmail attributionInfo.agentLicenseNumber  \
# 0   joycedorrion@hotmail.com                               None
#
#   attributionInfo.agentName attributionInfo.agentPhoneNumber  \
# 0                      None                             None
#
#   attributionInfo.attributionTitle attributionInfo.brokerName  \
# 0                             None                       None
#
#   attributionInfo.brokerPhoneNumber  \
# 0                              None
#
#   attributionInfo.buyerAgentMemberStateLicense attributionInfo.buyerAgentName  \
# 0                                         None                           None
#
#   attributionInfo.buyerBrokerageName attributionInfo.coAgentLicenseNumber  \
# 0                               None                                 None
#
#   attributionInfo.coAgentName attributionInfo.coAgentNumber  \
# 0                        None                          None
#
#   attributionInfo.lastChecked attributionInfo.lastUpdated  \
# 0                        None                        None
#
#                       attributionInfo.listingOffices  \
# 0  [{'associatedOfficeType': 'listOffice', 'offic...
#
#   attributionInfo.listingAgents attributionInfo.mlsDisclaimer  \
# 0                            []                          None
#
#   attributionInfo.mlsId attributionInfo.providerLogo  \
# 0                                               None
#
#   attributionInfo.infoString3 attributionInfo.infoString5  \
# 0                        None                        None
#
#   attributionInfo.infoString10 attributionInfo.infoString16  \
# 0                         None     joycedorrion@hotmail.com
#
#   attributionInfo.trueStatus homeRecommendations.blendedRecs  \
# 0                       None                              []
#
#   homeRecommendations.displayShort     parentRegion.name  \
# 0                                   Old Seminole Heights
#
#    listingMetadata.mustAttributeOfficeNameBeforeAgentName  \
# 0                                              False
#
#    listingMetadata.mustDisplayAttributionListAgentEmail  \
# 0                                              False
#
#    listingMetadata.mustDisplayAttributionListAgentPhone  \
# 0                                              False
#
#    listingMetadata.mustDisplayAttributionListingOfficePhone  \
# 0                                              False
#
#    listingMetadata.mustDisplayDisclaimerBelowAttribution  \
# 0                                              False
#
#   listingMetadata.mustHighlightAgentName  \
# 0                                   None
#
#    listingMetadata.mustHighlightListOfficeName  \
# 0                                        False
#
#    listingMetadata.mustMakeListingAgentContactable  \
# 0                                            False
#
#    listingMetadata.isAdsRestricted  listingMetadata.FlexibleLayoutAB  \
# 0                            False                              True
#
#    listingMetadata.FlexibleLayoutB  listingMetadata.FlexibleLayoutC  \
# 0                             True                             True
#
#    listingMetadata.FlexibleLayoutD  listingMetadata.FlexibleLayoutE  \
# 0                             True                             True
#
#    listingMetadata.FlexibleLayoutF  listingMetadata.FlexibleLayoutG  \
# 0                            False                            False
#
#    listingMetadata.FlexibleLayoutH  listingMetadata.FlexibleLayoutI  \
# 0                             True                             True
#
#    listingMetadata.FlexibleLayoutJ  listingMetadata.FlexibleLayoutK  \
# 0                            False                            False
#
#    listingMetadata.FlexibleLayoutL  listingMetadata.FlexibleLayoutM  \
# 0                            False                             True
#
#    listingMetadata.FlexibleLayoutN  listingMetadata.FlexibleLayoutO  \
# 0                             True                             True
#
#    listingMetadata.FlexibleLayoutP  listingMetadata.FlexibleLayoutQ  \
# 0                            False                            False
#
#    listingMetadata.FlexibleLayoutR  listingMetadata.FlexibleLayoutS  \
# 0                            False                            False
#
#    listingMetadata.FlexibleLayoutT  listingMetadata.FlexibleLayoutU  \
# 0                            False                            False
#
#    listingMetadata.FlexibleLayoutV  listingMetadata.FlexibleLayoutW  \
# 0                            False                            False
#
#    listingMetadata.FlexibleLayoutX  listingMetadata.FlexibleLayoutY  \
# 0                            False                            False
#
#    listingMetadata.FlexibleLayoutZ  listingMetadata.FlexibleLayoutAA  \
# 0                            False                              True
#
#    listingMetadata.passwordRequiredForZestimateMarketAnalysis  \
# 0                                              False
#
#    listingMetadata.canShowAutomatedValuationDisplay  \
# 0                                              True
#
#    listingMetadata.canShowTaxHistory  listingMetadata.canShowPriceHistory  \
# 0                               True                                 True
#
#    listingMetadata.canShowUserGeneratedContent  \
# 0                                         True
#
#    listingMetadata.hidePriceAdjustmentFlexField  \
# 0                                         False
#
#    listingMetadata.canCommingleComparables  \
# 0                                     True
#
#    listingMetadata.canShowComparables  \
# 0                                True
#
#    listingMetadata.isSuperTrafficOptimized  \
# 0                                    False
#
#    listingMetadata.mustDisplayFeedLogoInContactBox  \
# 0                                            False
#
#    listingMetadata.canShowCroppedPhotos  listingMetadata.canShowNonIDXMedia  \
# 0                                  True                                True
#
#    listingMetadata.canShowOnMap  listingMetadata.comminglingCategory  \
# 0                          True                                 True
#
#   listingMetadata.mustHighlightMlsId  listingMetadata.mustHighlightMlsStatus  \
# 0                               None                                   False
#
#    listingMetadata.mustHighlightMarketingType  \
# 0                                       False
#
#    listingMetadata.canShowZillowLogoInHeader  \
# 0                                       True
#
#    listingMetadata.canShowPrequalifiedLinkInChip  \
# 0                                           True
#
#    listingMetadata.comminglingCategoryIsRulesApplicable  \
# 0                                              False
#
#        listingProvider.title listingProvider.disclaimerText  \
# 0  Listing Provided by Owner                           None
#
#   listingProvider.enhancedVideoURL listingProvider.enhancedDescriptionText  \
# 0                             None                                    None
#
#   listingProvider.showLogos listingProvider.logos  \
# 0                      None                    []
#
#    listingProvider.showNoContactInfoMessage listingProvider.agentName  \
# 0                                     False                      None
#
#   listingProvider.agentLicenseNumber listingProvider.postingWebsiteURL  \
# 0                               None                              None
#
#   listingProvider.postingWebsiteLinkText listingProvider.postingGroupName  \
# 0                    See listing website                             None
#
#   listingProvider.sourceText listingProvider.isZRMSourceText  \
# 0                       None                            None
#
#    mortgageRates.fifteenYearFixedRate  mortgageRates.thirtyYearFixedRate  \
# 0                               5.841                              6.714
#
#    mortgageRates.arm5Rate  tourEligibility.isPropertyTourEligible  \
# 0                   5.869                                   False
#
#    tourEligibility.propertyTourOptions.isFinal  \
# 0                                         True
#
#   tourEligibility.propertyTourOptions.tourAvailability  \
# 0                                                 []
#
#   tourEligibility.propertyTourOptions.tourType  \
# 0                                         NONE
#
#    contactFormRenderData.data.agent_module.agent_reason  \
# 0                                                  3
#
#   contactFormRenderData.data.agent_module.display_name  \
# 0                                     Property Owner
#
#   contactFormRenderData.data.agent_module.encoded_zuid  \
# 0                            X1-ZUyv311lcu5hc9_11xcg
#
#   contactFormRenderData.data.agent_module.first_name  \
# 0                                               None
#
#    contactFormRenderData.data.agent_module.image_data.height  \
# 0                                                 60
#
#   contactFormRenderData.data.agent_module.image_data.url  \
# 0  https://photos.zillowstatic.com/h_n/ISr90g0e6n...
#
#    contactFormRenderData.data.agent_module.image_data.width  \
# 0                                                 60
#
#   contactFormRenderData.data.agent_module.phone.areacode  \
# 0                                                813
#
#   contactFormRenderData.data.agent_module.phone.number  \
# 0                                               7777
#
#   contactFormRenderData.data.agent_module.phone.prefix  \
# 0                                                400
#
#       contactFormRenderData.data.authentication.hmac  \
# 0  b3595cfb2cfe719de118004d1d05aba00f7192aebd2a25...
#
#   contactFormRenderData.data.authentication.request_id  \
# 0                   2496d818b64011edaebe065d02c3362f
#
#    contactFormRenderData.data.brokerage_info_must_be_shown  \
# 0                                              False
#
#   contactFormRenderData.data.contact_button_text  \
# 0                                  Contact Agent
#
#        contactFormRenderData.data.contact_recipients  \
# 0  [{'agent_reason': 1, 'badge_type': 'Premier Ag...
#
#   contactFormRenderData.data.cv_27.bal_checkboxes  \
# 0                                            0100
#
#   contactFormRenderData.data.cv_27.brokerage_product  \
# 0                                                 00
#
#   contactFormRenderData.data.cv_27.field_flags  \
# 0                                            1
#
#   contactFormRenderData.data.cv_27.form_identifier  \
# 0                                        opaque_la
#
#   contactFormRenderData.data.cv_27.mortgage_flags  \
# 0                                            1200
#
#   contactFormRenderData.data.desktop_phone_number  \
# 0                                            None
#
#    contactFormRenderData.data.display_options.is_opaque_eligible  \
# 0                                              False
#
#          contactFormRenderData.data.displayed_agents  \
# 0  [{'agent_reason': 1, 'badge_type': 'Premier Ag...
#
#         contactFormRenderData.data.displayed_lenders  \
# 0  [{'agent_encoded_zuid': 'X1-ZU14lnnz1anljih_1h...
#
#   contactFormRenderData.data.fallback_form.contact_recipients  \
# 0                                                 []
#
#   contactFormRenderData.data.fallback_form.cv_27.bal_checkboxes  \
# 0                                               0000
#
#   contactFormRenderData.data.fallback_form.cv_27.brokerage_product  \
# 0                                                 00
#
#   contactFormRenderData.data.fallback_form.cv_27.field_flags  \
# 0                                                  0
#
#   contactFormRenderData.data.fallback_form.cv_27.form_identifier  \
# 0                                    agent_directory
#
#   contactFormRenderData.data.fallback_form.cv_27.mortgage_flags  \
# 0                                                  0
#
#     contactFormRenderData.data.fallback_form.footers  \
# 0  [{'external': False, 'text': 'Visit profession...
#
#   contactFormRenderData.data.fallback_form.hidden_fields  \
# 0                                                 []
#
#    contactFormRenderData.data.fallback_form.subtitle  \
# 0  Visit our professional directory to find an ag...
#
#   contactFormRenderData.data.fallback_form.title  \
# 0                                  Contact Agent
#
#    contactFormRenderData.data.fallback_form.tour_eligible  \
# 0                                              False
#
#   contactFormRenderData.data.fallback_form.variant  \
# 0                                  agent_directory
#
#             contactFormRenderData.data.hidden_fields  \
# 0  [{'name': 'variant', 'value': 'opaque'}, {'nam...
#
#    contactFormRenderData.data.hide_textarea  \
# 0                                     False
#
#    contactFormRenderData.data.info_box_visible  \
# 0                                         True
#
#    contactFormRenderData.data.keller_williams  \
# 0                                       False
#
#    contactFormRenderData.data.lender_details.preapproval.checked  \
# 0                                              False
#
#   contactFormRenderData.data.lender_details.preapproval.label  \
# 0                       I want financing information
#
#   contactFormRenderData.data.lender_details.preapproval.message_when_checked  \
# 0        A Zillow confirmed lender will contact you.
#
#    contactFormRenderData.data.lender_details.preapproval_info.property_value  \
# 0                                             435000
#
#   contactFormRenderData.data.lender_details.preapproval_info.state_abbr  \
# 0                                                 FL
#
#   contactFormRenderData.data.lender_details.preapproval_info.zipcode  \
# 0                                              33610
#
#    contactFormRenderData.data.listing.direct_connect.tour_eligible  \
# 0                                              False
#
#   contactFormRenderData.data.listing.one_advisor  \
# 0                                           None
#
#    contactFormRenderData.data.listing.supports_unselected_leads  \
# 0                                               True
#
#    contactFormRenderData.data.opaque_la   contactFormRenderData.data.pixel_id  \
# 0                                  True  689bd7e4-4f9c-4bb0-8444-4cfb42ae8372
#
#                 contactFormRenderData.data.pixel_url  \
# 0  https://www.zillowstatic.com/contact-pixel/b9U...
#
#    contactFormRenderData.data.premier_agent_preferred_property  \
# 0                                              False
#
#   contactFormRenderData.data.region_phone_number.areacode  \
# 0                                                813
#
#   contactFormRenderData.data.region_phone_number.number  \
# 0                                               3084
#
#   contactFormRenderData.data.region_phone_number.prefix  \
# 0                                                213
#
#   contactFormRenderData.data.request_trace.xpi  \
# 0                                         None
#
#   contactFormRenderData.data.request_trace.xsi  \
# 0                             1371d0ba6d0b6f81
#
#   contactFormRenderData.data.request_trace.xti  \
# 0             6c5abdcd466bf031c90adf8405531a99
#
#    contactFormRenderData.data.tcpa contactFormRenderData.data.text_area.name  \
# 0                             True                                   message
#
#           contactFormRenderData.data.text_area.value  \
# 0  I am interested in 2014 E Broad St, Tampa, FL ...
#
#               contactFormRenderData.data.text_fields  \
# 0  [{'input_type': 'text', 'name': 'name', 'patte...
#
#   contactFormRenderData.data.title  \
# 0                    Contact Agent
#
#    contactFormRenderData.data.tour_config.useFoundation  \
# 0                                               True
#
#    contactFormRenderData.data.tour_eligible  \
# 0                                     False
#
#   contactFormRenderData.data.variant  ZoDsFsUpsellTop.display  \
# 0                             opaque                     True
#
#   ZoDsFsUpsellTop.displayCategory ZoDsFsUpsellTop.displayAttributes.leadType  \
# 0                property-zipcode                                   MORTGAGE
#
#   ZoDsFsUpsellTop.treatment ZoDsFsUpsellTop.surfaceId  \
# 0                   RTBP_ON                     fshdp
#
#   ZoDsFsUpsellTop.placementId  \
# 0                     wow-top
#
#                               ZoDsFsUpsellTop.reason  \
# 0  Upsell displaying is based on the zipcode of t...
#
#                   onsiteMessage.eventId  \
# 0  b432c944-ee98-47d0-9676-7abb06c65d8f
#
#                               onsiteMessage.messages  \
# 0  [{'skipDisplayReason': None, 'shouldDisplay': ...
#
#    foreclosureTypes.isBankOwned  foreclosureTypes.isForeclosedNFS  \
# 0                         False                             False
#
#    foreclosureTypes.isPreforeclosure  foreclosureTypes.isAnyForeclosure  \
# 0                              False                              False
#
#    foreclosureTypes.wasNonRetailAuction  foreclosureTypes.wasForeclosed  \
# 0                                 False                           False
#
#   foreclosureTypes.wasREO foreclosureTypes.wasDefault  \
# 0                    None                        None
#
#                                    staticMap.sources  listingSubType.isFSBA  \
# 0  [{'width': 192, 'url': 'https://maps.googleapi...                  False
#
#    listingSubType.isFSBO  listingSubType.isPending  listingSubType.isNewHome  \
# 0                   True                     False                     False
#
#    listingSubType.isForeclosure  listingSubType.isBankOwned  \
# 0                         False                       False
#
#    listingSubType.isForAuction  listingSubType.isOpenHouse  \
# 0                        False                       False
#
#    listingSubType.isComingSoon postingContact.name postingContact.photo  \
# 0                        False                None                 None
#
#   vrModel.vrModelGuid vrModel.revisionId thirdPartyVirtualTour.externalUrl  \
# 0                None               None                              None
#
#   thirdPartyVirtualTour.lightboxUrl thirdPartyVirtualTour.staticUrl  \
# 0                              None                            None
#
#   thirdPartyVirtualTour.providerKey  thirdPartyVirtualTour.approved  \
# 0                              None                           False
#
#   topNavJson.topnav.json.logo.text topNavJson.topnav.json.logo.href  \
# 0               Zillow Real Estate                                /
#
#                 topNavJson.topnav.json.main.sections  \
# 0  [{'link': {'text': 'Buy', 'href': '/homes/', '...
#
#    topNavJson.topnav.json.agent  \
# 0                         False
#
#            topNavJson.topnav.json.marketing.sections  \
# 0  [{'link': {'text': 'Manage Rentals', 'href': '...
#
#             topNavJson.topnav.json.regLogin.sections  \
# 0  [{'link': {'text': 'Sign in', 'href': '/user/a...
#
#                 topNavJson.topnav.json.help.sections  \
# 0  [{'link': {'text': 'Help', 'href': 'https://zi...
#
#   topNavJson.topnav.json.common.home.text  \
# 0                      Zillow Real Estate
#
#   topNavJson.topnav.json.common.home.href  \
# 0                                       /
#
#   topNavJson.topnav.json.common.advertise.text  \
# 0                                    Advertise
#
#   topNavJson.topnav.json.common.advertise.href  \
# 0                                  /advertise/
#
#   topNavJson.topnav.json.common.login.text  \
# 0                                  Sign in
#
#   topNavJson.topnav.json.common.login.href  \
# 0                        /user/acct/login/
#
#   topNavJson.topnav.json.common.register.text  \
# 0                                        Join
#
#   topNavJson.topnav.json.common.register.href  \
# 0                        /user/acct/register/
#
#                                   topNavJson.core.js  \
# 0  https://s.zillowstatic.com/s3/pfs/core-8903757...
#
#                               formattedChip.location  selfTour.hasSelfTour
# 0  [{'fullValue': '2014 E Broad St'}, {'fullValue...                 False

# %%
# features
# phone number
df_fsbo_prop["phone_number"] = df_fsbo_prop.apply(lambda x:
  x["contactFormRenderData.data.agent_module.phone.areacode"] + '-' +
  x["contactFormRenderData.data.agent_module.phone.prefix"] + '-' +
  x["contactFormRenderData.data.agent_module.phone.number"], axis=1)
# full address
df_fsbo_prop["full_address"] = df_fsbo_prop.apply(lambda x:
  x["streetAddress"] + ', ' +
  x["city"] + ', ' +
  x["state"] + ' ' + x["zipcode"], axis=1)

print("The phone number for property address {} is {}".format(
    list(df_fsbo_prop["full_address"])[0],
    list(df_fsbo_prop["phone_number"])[0]))
# Out:
# The phone number for property address 2014 E Broad St, Tampa, FL 33610 is 813-400-7777

# %% [markdown]
# ### <font color="green">6. Canada Listings</font>
# *Coming soon*

# %% [markdown]
# # End Notebook
